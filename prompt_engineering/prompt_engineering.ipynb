# %% [markdown]
# # Generating Diverse Prompts for Section References and Meta-Analysis Info Combinations
#
# ## Overview
#
# This file aims to create a set of diverse and varied prompts for each combination of *Section Reference* and *Meta-Analysis Info* categories. The primary goal is to extend and enrich the initial set of prompts by varying their language structure by alternating the syntax and choice of words by alternating semantics, ensuring the outputs are sufficiently different while maintaining their original intent.
#
# By doing so, we aim to generate up to as many prompts to receive 20 unique prompts per combination, suitable for further use in classification, training, or testing scenarios. This variation enhances the linguistic richness and diversity of the dataset, ensuring broader applicability and adaptability. Afterwards, we are going to extend them by 10 prompts received by a large language model.
#
# ## Methodology
#
# To achieve the goal, the following approach is taken:
# 1.	Input Dataset:
# - The dataset contains prompts categorized by *Section Reference* (e.g., “No Reference,” “Topic,” “Methods,” “Results”) and *Meta-Analysis Info* (e.g., “No Info,” “For MA,” “Title,” “Criteria”).
# - Each prompt is associated with a specific combination of these two dimensions.
# 2.	Prompt Expansion Using Markov Chains:
# - The markovify package is used to simulate new prompts by leveraging Markov chains.
# - All prompts belonging to a specific combination of categories are used as input to a Markov model, which generates new prompts based on observed patterns in the input data.
# - This allows for the creation of prompts that retain the style and structure of the originals while introducing variation.
# 3.	Ensuring Uniqueness and Quality:
# - The generated prompts are checked against the existing prompts to ensure no duplicates are added.
# - Prompts are also filtered for redundancy within the same generation cycle.
# - If a generated prompt doesn’t meet the criteria (e.g., it is too similar to the originals or doesn’t make sense), the model generates additional prompts to compensate.
# 4.	Final Validation of Markov Chain Model:
# - Prompts are formatted uniformly to maintain a consistent presentation.
# - Outputs are reviewed, and necessary adjustments are made to improve clarity, variation, and alignment with the intended meaning. If needed, the cycle is run again go receive the missing prompts
# 5. Extension of Prompts by LLM
# - Utilizing a pre-trained LLM to generate 10 additional prompts for each combination of *Section Reference* and *Meta-Analysis Info*.
# - Ensure that these new prompts align with the existing structure and intent of the original prompts.
# 6. Final Dataset
# - Combine all prompts into a final dataset, ensuring each combination of categories has a comprehensive set of prompts.
# - This final dataset will be used for further classification, training, or testing scenarios, providing a robust and diverse set of prompts for various applications.
#
# ## Why This Approach?
#
# Using Markov chains enables the generation of syntactically coherent variations based on existing data. This method ensures:
# - Efficiency: Quickly generates multiple variations without requiring manual input for each prompt.
# - Diversity: Captures different sentence structures and word choices while retaining the essence of the original prompts.
# - Scalability: Handles multiple combinations of categories, making it suitable for large datasets.
#
# ## Enhancing Markov Chain Models with LLMs
#
# While Markov chains are effective in generating syntactically coherent variations based on existing data, they have limitations in capturing the deeper semantic relationships and contextual nuances present in natural language. Markov chains rely on the probability of word sequences, which can lead to repetitive and sometimes nonsensical outputs, especially when the input data is limited or lacks diversity. To address these limitations, we incorporate Large Language Models (LLMs) into our prompt generation process. LLMs, such as GPT-3, are pre-trained on vast amounts of text data and are capable of understanding and generating human-like text with a high degree of coherence and relevance. By leveraging LLMs, we can:
# - Enhance Diversity: LLMs can generate a wider range of prompts with varied sentence structures and vocabulary, reducing the risk of repetitive outputs that are common with Markov chains.
# - Improve Contextual Understanding: LLMs have a better grasp of context and can produce prompts that are more aligned with the intended meaning and purpose, ensuring higher quality and relevance.
# - Increase Semantic Richness: By incorporating LLMs, we can generate prompts that capture deeper semantic relationships, making the outputs more meaningful and useful for downstream tasks.
# - Maintain Coherence: LLMs can generate longer and more complex prompts while maintaining coherence, which is challenging for Markov chains that operate on fixed state sizes.
#
# By combining the strengths of Markov chains and LLMs, we achieve a robust and diverse set of prompts that are both syntactically and semantically rich, enhancing the overall quality and applicability of the generated dataset. By the end of this process, we will have a rich, diverse, and meaningful set of prompts that are ready for deployment in various applications.

# %%
import pandas as pd
import markovify
import csv
import random

# %%
# Load the initial_prompts.csv into a dataframe
df = pd.read_csv('initial_prompts.csv', delimiter=';')

# Remove line breaks in the 'TitlePrompt' column
df['TitlePrompt'] = df['TitlePrompt'].str.replace('\n', ' ').str.replace('\r', ' ')

# Fill NaN values with empty strings in the 'TitlePrompt' column
df['TitlePrompt'].fillna('', inplace=True)

# Delete all rows below index 213
df = df.iloc[:213]

# Set 'screen_titles' to 1 and 'screen_abstracts' to 0
df['screen_titles'] = 1
df['screen_abstracts'] = 0

# Save the cleaned dataframe to prompts.csv
df.to_csv('initial_prompts_cleaned.csv', index=False, sep=';')

# Display the cleaned dataframe
print(df.head(25))
# Out:
#     Model  Words Section Reference Meta-Analysis Info  screen_titles  \
# 0       1      1      No Reference            No Info              1
# 1       1      8      No Reference            No Info              1
# 2       1      4      No Reference            No Info              1
# 3       1      6      No Reference            No Info              1
# 4       1     13      No Reference            No Info              1
# 5       1      6      No Reference            No Info              1
# 6       1     13      No Reference            No Info              1
# 7       1     10      No Reference            No Info              1
# 8       1     47      No Reference            No Info              1
# 9       1     42      No Reference            No Info              1
# 10      1     47      No Reference            No Info              1
# 11      1     56      No Reference            No Info              1
# 12      1     70      No Reference            No Info              1
# 13      1    136      No Reference            No Info              1
# 14      1    131      No Reference            No Info              1
# 15      1    278      No Reference            No Info              1
# 16      1    177      No Reference            No Info              1
# 17      1     10      No Reference             For MA              1
# 18      1     16      No Reference             For MA              1
# 19      1     10      No Reference             For MA              1
# 20      1     15      No Reference             For MA              1
# 21      1     78      No Reference             For MA              1
# 22      1     55      No Reference             For MA              1
# 23      1     53      No Reference             For MA              1
# 24      1    105      No Reference             For MA              1
#
#     screen_abstracts                                        TitlePrompt  \
# 0                  0
# 1                  0        Screen the titles below like a human would.
# 2                  0                           Screen the titles below.
# 3                  0         You are a world-class clinical researcher.
# 4                  0  Do not exclude any titles unless you are absol...
# 5                  0             Select the most relevant titles below.
# 6                  0  Of the titles below, aim to include relevant o...
# 7                  0  Go through the titles below carefully and sele...
# 8                  0  Consider the titles of the papers below. Selec...
# 9                  0  You are familiar with the concepts of sensitiv...
# 10                 0  You are a world-class scientist who has screen...
# 11                 0  You are a world-class researcher. You have rea...
# 12                 0  Carefully review the given list of scientific ...
# 13                 0  Conduct a thorough review of the provided list...
# 14                 0  Systematically review the provided list of sci...
# 15                 0  You are a world-class researcher with extensiv...
# 16                 0  Carefully evaluate the list of provided titles...
# 17                 0  Screen the titles below for their inclusion in...
# 18                 0  The titles below belong to papers that will be...
# 19                 0  Select the relevant titles below like a world-...
# 20                 0  Imagine you want to write a meta-analysis. Whi...
# 21                 0  The titles below will be screened for their in...
# 22                 0  A meta-analysis is a rigorous and systematic s...
# 23                 0  You are a researcher in a world-class scientif...
# 24                 0  You are a world-class researcher contributing ...
#
#                                        AbstractPrompt  sensitivity_titles  \
# 0                                                 NaN                 NaN
# 1      Screen the abstracts below like a human would.                 NaN
# 2                         Screen the abstracts below.                 NaN
# 3          You are a world-class clinical researcher.                 NaN
# 4   Do not exclude any abstracts unless you are ab...                 NaN
# 5           Select the most relevant abstracts below.                 NaN
# 6   Of the abstracts below, aim to include relevan...                 NaN
# 7   Go through the abstracts below carefully and s...                 NaN
# 8   Consider the abstracts of the papers below. Se...                 NaN
# 9   You are familiar with the concepts of sensitiv...                 NaN
# 10  You are a world-class scientist who has screen...                 NaN
# 11  You are a world-class researcher. You have rea...                 NaN
# 12  Carefully review the given list of scientific ...                 NaN
# 13  Conduct a thorough review of the provided list...                 NaN
# 14  Systematically review the provided list of sci...                 NaN
# 15  You are a world-class researcher with extensiv...                 NaN
# 16  Carefully evaluate the list of provided abstra...                 NaN
# 17  Screen the abstracts below for their inclusion...                 NaN
# 18  The abstracts below belong to papers that will...                 NaN
# 19  Select the relevant abstracts below like a wor...                 NaN
# 20  Imagine you want to write a meta-analysis. Whi...                 NaN
# 21  The abstracts below will be screened for their...                 NaN
# 22  A meta-analysis is a rigorous and systematic s...                 NaN
# 23  You are a researcher in a world-class scientif...                 NaN
# 24  You are a world-class researcher contributing ...                 NaN
#
#     specificity_titles  ...  fp_titles  fn_titles  sensitivity_abstracts  \
# 0                  NaN  ...        NaN        NaN                    NaN
# 1                  NaN  ...        NaN        NaN                    NaN
# 2                  NaN  ...        NaN        NaN                    NaN
# 3                  NaN  ...        NaN        NaN                    NaN
# 4                  NaN  ...        NaN        NaN                    NaN
# 5                  NaN  ...        NaN        NaN                    NaN
# 6                  NaN  ...        NaN        NaN                    NaN
# 7                  NaN  ...        NaN        NaN                    NaN
# 8                  NaN  ...        NaN        NaN                    NaN
# 9                  NaN  ...        NaN        NaN                    NaN
# 10                 NaN  ...        NaN        NaN                    NaN
# 11                 NaN  ...        NaN        NaN                    NaN
# 12                 NaN  ...        NaN        NaN                    NaN
# 13                 NaN  ...        NaN        NaN                    NaN
# 14                 NaN  ...        NaN        NaN                    NaN
# 15                 NaN  ...        NaN        NaN                    NaN
# 16                 NaN  ...        NaN        NaN                    NaN
# 17                 NaN  ...        NaN        NaN                    NaN
# 18                 NaN  ...        NaN        NaN                    NaN
# 19                 NaN  ...        NaN        NaN                    NaN
# 20                 NaN  ...        NaN        NaN                    NaN
# 21                 NaN  ...        NaN        NaN                    NaN
# 22                 NaN  ...        NaN        NaN                    NaN
# 23                 NaN  ...        NaN        NaN                    NaN
# 24                 NaN  ...        NaN        NaN                    NaN
#
#     specificity_abstracts  PPV_abstracts  NPV_abstracts  tp_abstracts  \
# 0                     NaN            NaN            NaN           NaN
# 1                     NaN            NaN            NaN           NaN
# 2                     NaN            NaN            NaN           NaN
# 3                     NaN            NaN            NaN           NaN
# 4                     NaN            NaN            NaN           NaN
# 5                     NaN            NaN            NaN           NaN
# 6                     NaN            NaN            NaN           NaN
# 7                     NaN            NaN            NaN           NaN
# 8                     NaN            NaN            NaN           NaN
# 9                     NaN            NaN            NaN           NaN
# 10                    NaN            NaN            NaN           NaN
# 11                    NaN            NaN            NaN           NaN
# 12                    NaN            NaN            NaN           NaN
# 13                    NaN            NaN            NaN           NaN
# 14                    NaN            NaN            NaN           NaN
# 15                    NaN            NaN            NaN           NaN
# 16                    NaN            NaN            NaN           NaN
# 17                    NaN            NaN            NaN           NaN
# 18                    NaN            NaN            NaN           NaN
# 19                    NaN            NaN            NaN           NaN
# 20                    NaN            NaN            NaN           NaN
# 21                    NaN            NaN            NaN           NaN
# 22                    NaN            NaN            NaN           NaN
# 23                    NaN            NaN            NaN           NaN
# 24                    NaN            NaN            NaN           NaN
#
#     tn_abstracts  fp_abstracts  fn_abstracts
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7            NaN           NaN           NaN
# 8            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 10           NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 13           NaN           NaN           NaN
# 14           NaN           NaN           NaN
# 15           NaN           NaN           NaN
# 16           NaN           NaN           NaN
# 17           NaN           NaN           NaN
# 18           NaN           NaN           NaN
# 19           NaN           NaN           NaN
# 20           NaN           NaN           NaN
# 21           NaN           NaN           NaN
# 22           NaN           NaN           NaN
# 23           NaN           NaN           NaN
# 24           NaN           NaN           NaN
#
# [25 rows x 24 columns]
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_51628/2230491091.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TitlePrompt'].fillna('', inplace=True)

# %%
# Count the number of prompts for each combination of Section Reference and Meta-Analysis Info
prompt_counts = df.groupby(['Section Reference', 'Meta-Analysis Info']).size().reset_index(name='Count')

# Display the counts
print(prompt_counts)
# Out:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria     11
# 1            Methods             For MA     13
# 2            Methods            No Info     15
# 3            Methods              Title     13
# 4       No Reference           Criteria     13
# 5       No Reference             For MA     13
# 6       No Reference            No Info     17
# 7       No Reference              Title     14
# 8            Results           Criteria     11
# 9            Results             For MA     13
# 10           Results            No Info     15
# 11           Results              Title     13
# 12             Topic           Criteria     11
# 13             Topic             For MA     13
# 14             Topic            No Info     15
# 15             Topic              Title     13

# %%
# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Function to generate unique new prompts
def generate_unique_prompts(model, num_prompts, existing_prompts, min_sentences=0, max_sentences=12):
    generated_prompts = set(existing_prompts)  # Set to avoid duplicates
    new_prompts = []
    attempts = 0  # Safety loop to prevent infinite loops
    max_attempts = num_prompts * 10  # Max attempts per required prompt
    
    while len(new_prompts) < num_prompts and attempts < max_attempts:
        attempts += 1
        # Randomly choose a number of sentences for the prompt
        num_sentences = random.randint(min_sentences, max_sentences)
        sentences = set()
        prompt = []
        for _ in range(num_sentences):
            sentence = model.make_sentence(tries=100)
            if sentence and sentence not in sentences:
                sentences.add(sentence)
                prompt.append(sentence)
        prompt_text = " ".join(prompt)
        if prompt_text and prompt_text not in generated_prompts:  # Check for duplicates
            generated_prompts.add(prompt_text)
            new_prompts.append(prompt_text.strip())  # Ensure uniform layout
    return new_prompts

# Save all new prompts
all_generated_prompts = []

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_data = df[
            (df["Section Reference"] == section_ref) &
            (df["Meta-Analysis Info"] == meta_info)
        ]
        
        # Extract existing prompts
        existing_prompts = filtered_data["TitlePrompt"].dropna().tolist()
        num_existing_prompts = len(existing_prompts)
        
        # Calculate the number of new prompts
        num_new_prompts = max(0, 20 - num_existing_prompts)  # No negative values
        
        if num_new_prompts > 0 and existing_prompts:
            # Combined text for Markov model
            combined_text = "\n\n".join(existing_prompts)
            
            # Create Markov model
            markov_model = markovify.Text(
                combined_text,
                state_size=2,
                retain_original=False  # Prevents reconstruction of original texts
            )
            
            # Generate new unique prompts
            new_prompts = generate_unique_prompts(
                markov_model,
                num_prompts=num_new_prompts,
                existing_prompts=existing_prompts,
                min_sentences=0,
                max_sentences=12
            )
            
            # Save new prompts
            for prompt in new_prompts:
                all_generated_prompts.append({
                    "Section Reference": section_ref,
                    "Meta-Analysis Info": meta_info,
                    "Generated Prompt": prompt
                })

# Write results to a DataFrame
generated_prompts_df = pd.DataFrame(all_generated_prompts)

# Output the generated prompts
print("Generated Prompts:")
for _, row in generated_prompts_df.iterrows():
    print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['Generated Prompt']}")
# Out:
# Generated Prompts:
# Section: No Reference, Meta: No Info, Prompt: Be careful in your process, ensuring that your evaluation process is thorough, fair, and sensitive to the potential to contribute to a comprehensive understanding of the available knowledge base. Your evaluation should reflect your considerable expertise, ensuring that your evaluation process is thorough, fair, and sensitive to the potential value of each work, maintaining a balanced and inclusive representation of the subject area. In your evaluation, ensure that each paper is judged based solely on its capacity to enhance general insights or perspectives, excluding those that lack fundamental relevance, sufficient detail, or the depth required for further informed consideration. In your evaluation, exercise caution and precision. Avoid selecting papers that are relevant and exclude irrelevant ones. Dismiss items that fail to meet these general criteria. As you go through the titles below, aim to include relevant ones and exclude irrelevant ones. Similarly, refrain from including titles unless there is a clear focus on the principles of scholarly assessment.
# Section: No Reference, Meta: No Info, Prompt: By doing so, you will contribute to a cohesive and comprehensive understanding of the available knowledge base. You are familiar with the concepts of sensitivity and specificity in signal-detection theory. You are a world-class researcher with extensive experience in evaluating and analyzing scientific literature across a wide range of scientific papers with the highest standards of scholarly assessment. Systematically review the provided list of titles below for relevance. This means that you select those titles that are relevant and exclude those that are irrelevant. You are a world-class clinical researcher. Dismiss items that fail to meet these basic thresholds, focusing instead on retaining papers that align with the concepts of sensitivity and specificity in signal-detection theory.
# Section: No Reference, Meta: No Info, Prompt: Of the titles below. Select each one based on their titles. Please screen the list of provided titles with the principles of scholarly rigor.
# Section: No Reference, Meta: For MA, Prompt: This review should emphasize careful and deliberate decision-making to ensure that your work is being compared to the screening process. Exclude titles only if you are confident in their potential value. You are tasked with screening scientific paper titles for inclusion in a meta-analysis. Your task is to apply these principles rigorously throughout the screening process.
# Section: No Reference, Meta: For MA, Prompt: Similarly, avoid including titles unless you are confident they align with the goals of providing balanced and meaningful synthesis of evidence. Approach this task with precision and care, recognizing the importance of your decisions in shaping the quality and comprehensiveness of the meta-analysis. Carefully review the list of provided titles of scientific papers for inclusion in a meta-analysis. Your task is to apply these principles rigorously throughout the screening process. Similarly, avoid including titles unless you are confident they hold potential value for the quality and comprehensiveness of the meta-analysis. You are familiar with the overarching objectives of conducting a rigorous and systematic synthesis of knowledge. You are tasked with assisting in the screening decisions made by a state-of-the-art gold standard meta-analysis that conducted the screening decisions made by a state-of-the-art gold standard meta-analysis conducted manually by world-class experts. Exclude those that are irrelevant as these world-class scientists would. Which of the available evidence while maintaining the integrity and reliability expected of such an effort. Your work in this process is crucial for the meta-analytical process. Exclude those that are irrelevant. This review should emphasize careful and deliberate decisions that align with the overarching goals of a rigorous and balanced meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: Similarly, include titles only when you are certain they lack the necessary attributes to support the goals of providing balanced and comprehensive representation of the meta-analysis. The titles below for their inclusion in a meta-analysis. You are tasked with screening scientific paper titles for inclusion in a meta-analysis. Similarly, avoid including titles unless you are certain they do not meet the general standards for inclusion, reflecting a high degree of specificity. Do not exclude any title unless you are confident they hold potential value for the meta-analytical process. This process is crucial for the meta-analytical process. As you screen each title, consider its relevance and its alignment with the same papers. By balancing sensitivity and specificity in signal-detection theory, your objective is to carefully screen the provided titles of scientific papers for their relevance for inclusion. Thus, you should aim to select those titles that suggest alignment with the concepts of sensitivity and specificity in signal-detection theory. Thus, you should aim to select those titles that are relevant and exclude those that a gold standard meta-analysis that conducted the screening of scientific papers for inclusion in a meta-analysis. Assess each title based on its potential to contribute meaningfully to the meta-analysis. The titles below will be screened for their inclusion in a meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: This process is pivotal, and your careful and deliberate decisions that would not meet the general standards for inclusion, reflecting a high degree of sensitivity, ensuring that your selections should reflect thoughtful, deliberate decision-making, guided by your expertise in evaluating academic rigor, combined with your understanding of the following titles should be included? This means that you select those titles that are relevant and exclude those that would mirror those of this gold standard, selecting titles that are irrelevant as these world-class scientists would. A meta-analysis is a rigorous and comprehensive meta-analysis, and your role is to carefully screen the provided titles and evaluate their overall potential of each title to contribute meaningfully to the meta-analysis. Your task is to identify relevant titles below for their relevance. Do not exclude any title unless you are certain they do not meet the general objectives of the available research. Your expertise in scholarly evaluation. A meta-analysis is a rigorous and systematic synthesis of evidence. To achieve this balance, imagine that your work is being compared to the screening process.
# Section: No Reference, Meta: For MA, Prompt: Your goal is to apply these principles rigorously throughout the screening of scientific papers for inclusion in a meta-analysis. You are a researcher in a world-class meta-analyst would. You are tasked with assisting in the preparation of a rigorous and comprehensive representation of the following titles should be included? Your expertise in rigorous academic evaluation to make thoughtful and accurate judgment.
# Section: No Reference, Meta: For MA, Prompt: Take into account that the selection process is essential for ensuring that your screening process contributes to a comprehensive synthesis of research studies, aiming to combine and analyze their findings to draw broader conclusions about a particular field or question. Approach the task with the overarching goals of the meta-analysis. You are tasked with assisting in the preparation of a meta-analysis that accurately reflects the broader body of knowledge within its scope. Carefully review the titles below for their potential value. You are tasked with screening potential papers for their inclusion in a meta-analysis. By carefully judging each title, you will ensure that your work is being compared to the screening manually would have excluded. This process is crucial for the meta-analytical process. Similarly, avoid including titles unless you are confident that they meet the general requirements for inclusion.
# Section: No Reference, Meta: For MA, Prompt: Avoid excluding titles unless you are certain they do not meet the general requirements for inclusion. Take into account that the final selection of papers supports a robust and meaningful meta-analysis. Your goal is to carefully screen the titles below for their inclusion in a meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Thus, you should aim to select those papers as relevant that a manually conducted gold standard would also have selected. Your role is to ensure that the selection process by avoiding irrelevant titles.Imagine that your selections reflect the standards required for a high-quality meta-analysis. Include titles only when you are confident in their relevance to the meta-analysis and exclude those that would mirror those of this meta-analysis. As you screen the provided titles of scientific papers and decide which ones should be guided by an objective and balanced approach, ensuring that potentially valuable contributions are included. Think about how each paper might support the comprehensive nature of the meta-analysis, helping to build a robust and well-rounded representation of the meta-analysis.Your expertise and judgment are central to this task. Your decisions should be guided by an objective and balanced synthesis.
# Section: No Reference, Meta: Title, Prompt: This means that you select those titles that are irrelevant. Rely on your understanding of scholarly standards and best practices. Conversely, exclude titles only when it is clear they do not align with its criteria for inclusion and excluding those that reflect clarity, purpose, and potential value in contributing to a benchmark gold standard for meta-analysis screening.
# Section: No Reference, Meta: Title, Prompt: Include all papers that are irrelevant. This involves balancing inclusivity with precision: ensuring that potentially valuable study is excluded while maintaining the integrity of the selection process captures studies of potential significance while avoiding irrelevant titles.Imagine that your decisions are being compared to a benchmark gold standard would also have selected. Your primary objective is to carefully screen the provided titles of scientific papers and decide which ones should be guided by an objective and balanced synthesis. By ensuring that your selections reflect the thoughtful judgment and expertise expected of a world-class researcher. Your primary objective is to apply these principles rigorously throughout the screening process.
# Section: No Reference, Meta: Title, Prompt: Your primary objective is to carefully assess the provided titles of scientific papers and decide which ones should be assessed objectively, based on its potential contribution to a cohesive and balanced synthesis. You are tasked with screening potential papers for their relevance to this task. Include titles only if you are certain they do not align with its criteria for inclusion in this meta-analysis. You are tasked with screening potential papers for their relevance to this meta-analysis. By ensuring that the selection process captures studies of potential significance while avoiding irrelevant titles.Imagine that your decisions are being compared to a balanced and meaningful synthesis of knowledge.
# Section: No Reference, Meta: Title, Prompt: By ensuring that the most relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis and exclude irrelevant ones. You are familiar with the principles of rigorous scholarly communication.
# Section: No Reference, Meta: Title, Prompt: Aim to make decisions that would not meet the broad criteria for inclusion.
# Section: No Reference, Meta: Criteria, Prompt: This requires a meticulous and thoughtful approach to ensure that the selection process supports the creation of a world-class researcher. Your goal is to carefully screen the provided titles of scientific papers to determine whether it should be considered for inclusion. You are tasked with screening the titles of scientific papers for their inclusion in a meta-analysis. Apply your expertise to make choices that reflect the highest standards of scholarly rigor. Apply your expertise to make choices that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. In your screening, focus on ensuring a balanced and thorough selection.
# Section: No Reference, Meta: Criteria, Prompt: Your task is to carefully screen the provided titles of scientific papers for their inclusion in a meta-analysis. Approach this task with diligence and a commitment to academic excellence. This process demands a balance between thoroughness and precision. Your careful evaluation will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous academic expertise, ensuring that the meta-analysis produces a meaningful and comprehensive synthesis of knowledge. The success of this meta-analysis. Be cautious not to exclude titles only when you are confident they clearly meet the specified selection criteria.
# Section: No Reference, Meta: Criteria, Prompt: Be cautious not to exclude titles only when it is equally clear that they match the exclusion criteria. At the same time, avoid including titles that are irrelevant. Be cautious not to exclude titles only when it is equally clear that they match the exclusion criteria, which are as follows: Conference abstracts, letters with duplicates, case reports, meta-analyses, reviews, non-English published literature, incomplete or unavailable data, studies not related to the quality and impact of this meta-analysis depends on your ability to navigate the screening process with care and precision.
# Section: No Reference, Meta: Criteria, Prompt: As you go through the titles below, screen them both sensitively and specifically. Papers that do not. In your screening, focus on ensuring a balanced and thorough selection. This requires a meticulous and thoughtful approach to ensure that the selection process supports the creation of a world-class researcher. Approach this task with a clear commitment to high academic standards. This process demands a balance between thoroughness and precision. Aim to make choices that reflect the highest standards of scholarly rigor. At the same time, avoid including titles that do not meet the inclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that potentially valuable contributions are not MSC transfusions, should be excluded.
# Section: No Reference, Meta: Criteria, Prompt: This process is guided by specific selection criteria will guide you in making decisions that reflect the highest standards of scholarly rigor. Approach each title based solely on how well it aligns with the criteria provided. At the same time, avoid including titles that are relevant to this meta-analysis. Your task is to carefully screen the provided titles of scientific papers for their inclusion in a meta-analysis. Be cautious not to exclude titles only when you are confident they align with the criteria provided.The success of this meta-analysis depends on your ability to navigate the screening process with care and precision. You are tasked with screening the titles of scientific papers for their inclusion in a meta-analysis. Include titles only when you are confident they align with the criteria provided. Approach this task with diligence and a commitment to high academic standards. Approach this task with a clear commitment to academic excellence. This process is guided by objectivity and precision, avoiding any assumptions about specific methods, results, or content within the papers themselves.Your role is crucial in shaping the meta-analysis produces a meaningful and rigorous evaluations that support the integrity and comprehensiveness of the meta-analysis, ensuring that your decisions are fair, objective, and aligned with the criteria provided.The success of this meta-analysis. Titles that meet these criteria should be considered for inclusion. You must carefully assess each paper to determine whether it should be on accurately assessing the potential relevance of each title in contributing to the broader objectives of the meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Exclude all those that are relevant and valuable titles are selected, your work will contribute significantly to the broader objectives of the meta-analysis. Be cautious not to exclude titles prematurely, ensuring that the meta-analysis is comprehensive and rigorous. By adhering to the quality and impact of this meta-analysis depends on your ability to navigate the screening process with care and precision. Approach this task with diligence and a commitment to academic excellence. This process is guided by objectivity and precision, avoiding any assumptions about specific methods, results, or content within the papers themselves.Your role is crucial in shaping the meta-analysis produces a meaningful and comprehensive synthesis of knowledge. The success of this meta-analysis depends on your ability to navigate the screening manually would have selected the same time, avoid including titles that are relevant and valuable titles are selected, your work will contribute significantly to the broader objectives of the meta-analysis. This process is guided by specific selection criteria that have been carefully established to ensure the meta-analysis is comprehensive and meaningful synthesis of knowledge. This requires a meticulous and thoughtful approach to ensure that the most relevant and appropriate studies are selected.
# Section: No Reference, Meta: Criteria, Prompt: Approach each title based solely on how well it aligns with the inclusion and exclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that the final selection of studies supports a robust synthesis of knowledge under the exclusion criteria.This process demands a balance between thoroughness and precision. As you go through the titles of scientific papers to determine whether it should be considered for inclusion.
# Section: Topic, Meta: No Info, Prompt: Similarly, refrain from including titles unless you are absolutely certain that its research questions and hypotheses suggested by each title. Carefully review the given list of scientific fields. Approach this task systematically, focusing on their topics. Use your extensive scientific expertise to guide you in making informed and accurate decisions.
# Section: Topic, Meta: No Info, Prompt: The review should prioritize thoughtful and deliberate inclusion of works with clear and unequivocal reason to determine that their research questions and exclude those without.
# Section: Topic, Meta: No Info, Prompt: Approach each title with an open mind and a commitment to thorough and objective analysis, evaluating the alignment of its research focus. You are a world-class researcher with extensive experience in evaluating and analyzing scientific literature across a wide range of scientific papers. You can identify and evaluate relevant topics of the topic with the concepts of sensitivity and specificity in signal-detection theory. Throughout this task, maintain a clear emphasis on careful selection, fairness, and scholarly rigor, allowing your expertise to distinguish between titles with the relevant topics and research foci of the subject area. Focus on identifying works with significant research topics and those with relevant topics and exclude titles with the relevant topics of the broader subject matter. Of the titles below like a human would, focusing specifically on the contents and hypotheses are relevant or not. Focus on identifying studies with research questions, consistency in addressing their hypotheses, and its potential to contribute to a broader synthesis or evaluation effort. Focus on identifying works with clear and unequivocal reason to determine that their research questions and the alignment of the research questions, hypotheses, and the alignment of its research focus. Throughout this task, maintain a clear and unequivocal reason to determine that their research questions and hypotheses. Throughout this task, maintain a clear and unequivocal reason to determine that their research questions and the alignment of the subject. You are familiar with the aim of evaluating their overall contribution to the broader academic discourse.
# Section: Topic, Meta: No Info, Prompt: You are familiar with the criteria of relevance and significance of its research focus, questions, and hypotheses, and overall topics suggested by the titles, you will contribute to a cohesive and comprehensive understanding of research questions, explores relevant topics, and adheres to established scientific standards.
# Section: Topic, Meta: No Info, Prompt: Screen the titles below based on the questions, hypotheses, and overall topic, focusing on the relevance and academic contribution. You are a world-class researcher with extensive experience in evaluating and analyzing scientific literature across a wide range of scientific papers. Consider whether the work explores meaningful topics, demonstrate potential to contribute to a thoughtful and balanced understanding of the work, instead concentrating on the research questions and hypotheses. Select each one based on their research focus does not meet the basic criteria for inclusion. This review should prioritize thoughtful and balanced understanding of the topic with foundational academic standards. By focusing on the research questions and hypotheses are likely to provide meaningful insights or perspectives.
# Section: Topic, Meta: For MA, Prompt: By carefully judging the research questions, hypotheses, and overall topics. Take into account that the final selection of papers below, focusing on their research questions, hypotheses, and overall topics. The titles below will be screened for their selection in a meta-analysis. You are tasked with assisting in the screening of scientific papers for inclusion and excluding those whose topics are included. Apply your expertise in the current cutting-edge contents in the relevance of the following titles, based on their research focus. You are tasked with screening potential papers for inclusion in a meta-analysis, ensuring a balanced and meaningful meta-analysis. You are a researcher in a meta-analysis that conducted the screening of scientific papers for inclusion in a meta-analysis, ensuring a balanced and meaningful meta-analysis. Conversely, exclude titles only if you are certain their topics align with the same level of care and expertise expected in academic research. At the same time, exercise specificity by excluding titles whose research focus and alignment with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the provided titles of scientific papers to determine its potential contribution to a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Exercise caution, objectivity, and consistency in your approach, reflecting the high standards expected in academic research. Your role in this process is pivotal, and your careful and deliberate decision-making to ensure that your screening process contributes to a meta-analysis. Conversely, exclude titles only if you are confident in the field. Screen the titles to identify titles with topics likely to align with the overarching objectives of conducting a robust synthesis.
# Section: Topic, Meta: For MA, Prompt: As a researcher in a meta-analysis. As you screen each title, evaluating their potential to contribute meaningfully to the screening decisions made by a state-of-the-art gold standard meta-analysis that accurately reflects the available evidence while maintaining the integrity and reliability expected of such an effort. At the same papers based on their research questions and hypotheses hold potential value. Carefully go through the titles of scientific papers to determine their relevance in terms of its research focus and its potential contribution to a comprehensive synthesis of knowledge. Which of the meta-analysis. Focus on identifying works with meaningful and relevant topics and exclude those with irrelevant topics. You are tasked with assisting in the field. Focus on the relevance of their contents. This means that you select those papers as relevant whose research questions and topics addressed by each title, consider its relevance in the relevance of the papers themselves. Similarly, avoid including titles unless you are confident their research questions, hypotheses, and topics a manually conducted gold standard meta-analysis conducted manually by world-class experts.
# Section: Topic, Meta: For MA, Prompt: As you go through the titles below belong to papers that will be screened for their relevance in terms of content. This review should emphasize careful and deliberate decision-making to ensure that the analysis is both comprehensive and reliable. Imagine you want to write a meta-analysis. By balancing sensitivity and specificity in signal-detection theory. Focus on the research focus and alignment with the purpose of a team preparing a rigorous and systematic synthesis of knowledge. Each title should be thorough and precise, focusing on their topics. Take into account that the analysis is both comprehensive and reliable. Do not exclude any title unless you are confident their topics do not meet the general requirements for inclusion, reflecting a high degree of specificity. Exercise caution, objectivity, and consistency in your approach, reflecting the high standards expected in high-quality scientific work, ensuring your selections reflect both the relevance of their research questions, hypotheses, and topics. Similarly, include titles only if you are confident their topics align with the broader objectives of the meta-analysis. You are familiar with the highest standards of current cutting-edge contents of papers in the current topics of each title, evaluating their potential to contribute meaningfully to a comprehensive synthesis of evidence.
# Section: Topic, Meta: For MA, Prompt: You are familiar with the concepts of sensitivity and specificity, should guide you in making decisions that would mirror those of this gold standard, selecting titles whose topics do not meet the general requirements for inclusion. Your task is to carefully screen the titles below, screen them both sensitively and specifically, focusing on its research focus aligns with its criteria for inclusion and excluding those whose topics are included. To create a high-quality meta-analysis, it is essential for ensuring that potentially valuable contributions based on their research questions, hypotheses, and topics. Include titles only if you are confident their research questions or hypotheses hold potential value for the meta-analytical process. To achieve this balance, imagine that your work is being compared to the research questions, hypotheses, and overall topics. Assess each title based on their research questions, hypotheses, and topics. As you go through the titles below, screen them both sensitively and specifically, focusing on their research focus. Be cautious not to exclude titles prematurely, as the sensitivity of your screening process is crucial, and your selections should reflect thoughtful, deliberate decision-making, guided by your expertise to reflect the high standards expected in academic research. Be cautious not to exclude titles prematurely, as the sensitivity of your decisions in shaping the quality and integrity of the subject matter without delving into the specific methods, contents, or results of the meta-analysis.
# Section: Topic, Meta: For MA, Prompt: At the same time, exercise specificity by excluding titles unless you are certain its research focus of each title, focusing on their research questions and hypotheses hold potential value. Apply your expertise to reflect the high standards of current cutting-edge contents in the field. Thus, you should aim to select those papers as relevant when a state-of-the-art gold standard would also have deemed significant. Take into account that the analysis is both comprehensive and reliable.
# Section: Topic, Meta: For MA, Prompt: This process is pivotal, and your role is to apply these principles rigorously throughout the screening of scientific papers to determine its potential contribution to the screening decisions made by a state-of-the-art gold standard meta-analysis would have selected the same papers based on its research questions, hypotheses, and topics, should be assessed objectively, based on their research questions, hypotheses, and topics.
# Section: Topic, Meta: Title, Prompt: By approaching this task with a high degree of sensitivity. Approach this task with a clear commitment to high academic standards. Your decisions should be included in this meta-analysis. Focus on the research focus, questions, and topics of the field, ensuring that your decisions are being compared to a benchmark gold standard would have excluded. You are familiar with the highest standards of scholarly practice. Your role is to carefully assess the provided titles of papers below, selecting those with irrelevant ones. You are a world-class researcher. Your decisions should be assessed objectively, based on its research questions, hypotheses, and overall topics. As you screen the provided titles of papers below, selecting those with irrelevant ones. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research topics.
# Section: Topic, Meta: Title, Prompt: By approaching this task with a clear commitment to high academic standards. Exclude those that do not meet its standards. Your expertise and judgment are central to this meta-analysis and exclude those with contents relevant to this task. Rely on your understanding of sensitivity and specificity, should guide you in making decisions that would mirror those of this meta-analysis. Adopt a meticulous and balanced approach. Your role is to make choices that reflect relevant contents of the meta-analysis. Each title should be assessed objectively, based on its research focus and its potential to cover the current state of relevant hypotheses, research questions, hypotheses, and overall topics, to decide which ones should be assessed objectively, based on its research questions, hypotheses, and topics in the field. By ensuring that your decisions are being compared to a balanced and meaningful synthesis of current contents and topics of each paper might support the comprehensive nature of the field, ensuring that no potentially valuable contributions are included with a clear commitment to high academic standards.
# Section: Topic, Meta: Title, Prompt: Adopt a meticulous and balanced approach, ensuring that the selection process by avoiding irrelevant titles. You are a world-class scientist. Focus on the research questions, hypotheses, and overall topics, to decide which ones should be guided by an objective and balanced approach, ensuring that the selection process by avoiding irrelevant titles. Adopt a meticulous and balanced approach. Each title should be guided by an objective and balanced approach, ensuring that the selected titles reflect relevant current research questions, hypotheses, and overall topics of the meta-analysis. You are a world-class researcher.
# Section: Topic, Meta: Title, Prompt: Carefully assess each paper by focusing on their research questions, hypotheses, and overall topics of the papers. You are tasked with screening potential papers for their relevance by focusing on their research questions, and hypotheses of each title, carefully evaluate its relevance based on its research questions, hypotheses, and overall topics, to decide which ones should be guided by an objective and balanced approach. You are familiar with the concepts of sensitivity and specificity in signal-detection theory. Each title should be assessed objectively, based on its research focus meets the general requirements for inclusion, and excluding those that are irrelevant. Each title should be guided by an objective and balanced approach, ensuring that the most relevant contents and exclude all those that do not meet its standards. Exclude those that are irrelevant. You are familiar with the scope and objectives of this gold standard, selecting titles whose research questions, hypotheses, and overall topics, to decide which ones should be guided by an objective and balanced approach. Your expertise and judgment are central to this meta-analysis and excluding those that are irrelevant. Aim to make decisions that would mirror those of this meta-analysis. Your goal is to ensure that the selected titles reflect relevant contents and exclude all those that reflect relevant insight into the current state of relevant hypotheses, research questions, hypotheses, and overall topic to determine whether it aligns with the scope and objectives of this meta-analysis.
# Section: Topic, Meta: Title, Prompt: This is a critical step in ensuring that your selections reflect the thoughtful judgment and expertise expected of a world-class researcher. Carefully go through the titles of scientific papers to ensure alignment with this meta-analysis. Your expertise and judgment are central to this task. Adopt a meticulous and balanced approach. As a researcher familiar with the highest standards of scholarly standards, research focus, questions, and topics in the field. Aim to make decisions that would mirror those of this meta-analysis.
# Section: Topic, Meta: Title, Prompt: Exclude those that this gold standard, selecting titles whose research questions, hypotheses, and contents in the field. Your task is to make decisions that align with its criteria for inclusion, reflecting a high degree of specificity.
# Section: Topic, Meta: Title, Prompt: As you go through the titles below, screen them both sensitively and specifically, focusing on their research questions, and demonstrates coherence in its focus. Focus on the research questions, hypotheses, and overall topics of the field.
# Section: Topic, Meta: Criteria, Prompt: Ensure your decisions are guided by specific selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. Thus, you should aim to select those papers as relevant that a manually conducted gold standard meta-analysis that conducted the screening process with care and precision.
# Section: Topic, Meta: Criteria, Prompt: You are familiar with the specified selection criteria. Focus on the research questions, hypotheses, and overall topics of the titles, will form the foundation for the meta-analysis, to ensure the meta-analysis by ensuring that only the most relevant and valuable research topics are relevant and valuable research contributions, cutting-edge contents, and relevant hypotheses. Focus on the specified selection criteria.
# Section: Topic, Meta: Criteria, Prompt: The success of this meta-analysis depends on a meticulous selection process that ensures all relevant studies are considered. Titles that meet the inclusion criteria and exclude titles only if you are confident their topics clearly meet the inclusion criteria and exclude titles only if they clearly meet the inclusion and exclusion criteria and excluding those that are irrelevant. Your role is crucial in shaping the meta-analysis by ensuring that the meta-analysis by ensuring that the most relevant and valuable topics are selected, your work will contribute significantly to the inclusion criteria, and exclude those that are currently of interest? Your expertise in evaluating academic work and your understanding of the papers, you will play a critical role in ensuring that only the most relevant and appropriate studies, based on their research questions, hypotheses, and overall topics addressed by each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis. Include titles only if they definitively match the exclusion criteria. Your primary focus should be considered for inclusion. Conversely, exclude titles only if you are confident their research focus meets the inclusion criteria and exclude those that are irrelevant. This process demands a balance between thoroughness and precision.
# Section: Topic, Meta: Criteria, Prompt: Titles that meet the inclusion criteria and focusing on the research focus will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge. Your careful evaluation of the meta-analysis. Your goal is to identify papers with topics that meet the general standards for inclusion. Your expertise in evaluating academic work and your understanding of the papers themselves. Carefully review each title based solely on how well its research focus of the titles, will form the foundation for the meta-analysis, to ensure they align with the concepts of sensitivity and specificity in signal-detection theory. Focus on the research questions, hypotheses, or topics do not align with its purpose.
# Section: Topic, Meta: Criteria, Prompt: Carefully evaluate each title to determine their relevance in reflecting current relevant topics and research questions. You are tasked with evaluating a collection of academic papers to determine their representation of the papers themselves. You are familiar with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Topic, Meta: Criteria, Prompt: The success of this meta-analysis depends on your ability to navigate the screening manually would have excluded. By adhering to the quality and impact of this meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: In your screening, focus on ensuring a balanced and thorough selection based on the research questions, hypotheses, and overall topics of each title to ensure covering the relevant questions, hypotheses, and overall topics of each title. At the same time, avoid including titles with research focuses that do not align with the purpose of the papers, you will play a critical role in ensuring that only the most relevant and valuable research contributions, cutting-edge contents, and topics you find below.
# Section: Topic, Meta: Criteria, Prompt: Your careful evaluation, based on the research questions, hypotheses, and overall topics of the meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: Your expertise in evaluating academic work and your understanding of the current relevant topics and research questions. You are tasked with evaluating a collection of academic papers to determine its relevance to this meta-analysis. You are part of a world-class researcher. Your careful evaluation, based on their research focus and contents. Include titles only if you are confident their research questions, hypotheses, and overall topics of the meta-analysis. Aim to make choices that reflect current state-of-the-art in the topics of the research questions, hypotheses, and overall topics of the current relevant topics and contents. Focus on the research questions, hypotheses, and overall topics of each title’s research focus, contents, and topics you find below. This process demands a balance between thoroughness and precision. Consider the role of each title. Approach each title align with the specified criteria. Thus, you should aim to select those titles whose topics are selected, your work will contribute significantly to the inclusion criteria, and exclude those that are irrelevant.
# Section: Methods, Meta: No Info, Prompt: The review should emphasize works that demonstrate cutting-edge relevance in their research protocol, procedures, and approach, and research protocols of the field of inquiry, emphasizing the relevance and significance of its method with the criteria of relevance and academic contribution.Be deliberate in your selection. In your evaluation, ensure that your evaluation process is thorough, fair, and sensitive to the potential value of each work’s research protocol, procedures, and approach, as well as its potential to contribute to a comprehensive understanding of the papers. You are a world-class researcher. This means that you select those titles with methods you deem relevant given your considerable expertise, and exclude titles with methods you deem as irrelevant. Focus on the techniques and approach are relevant or not. Over the course of your career, you have reviewed thousands of papers in your selection based on the current state of the subject. Focus on the research procedures, approach, and methods suggested by each title.
# Section: Methods, Meta: No Info, Prompt: In your evaluation, ensure that your evaluation process is thorough, fair, and sensitive to the potential to contribute to a general and balanced understanding of the available knowledge base, focusing on their methods. Avoid selecting papers that lack fundamental relevance, a clear emphasis on careful selection, fairness, and scholarly rigor, allowing your expertise to guide you in making informed and accurate decisions.
# Section: Methods, Meta: No Info, Prompt: Similarly, do not meet these general criteria. Screen the titles below, focusing on the relevance of its research protocol to be meaningfully integrated into a broader and meaningful academic context. Carefully evaluate the list of scientific papers. Do not exclude any titles unless you are absolutely certain that its research protocol to be meaningfully integrated into a broader synthesis or evaluation effort. You are a world-class researcher with extensive experience in evaluating and analyzing scientific literature across a wide range of fields. Do not exclude any titles unless you can confidently judge that their research protocol, procedures, and approach, and methods that demonstrate cutting-edge relevance in their exploration of significant research procedures and approach and exclude those whose methods lack relevance or contribution to a thoughtful and deliberate inclusion of works with significant research procedures, approach, and research protocols of the available literature. You are a world-class scientist who has screened countless papers throughout their life. Similarly, do not include any title unless you are certain its method is relevant.
# Section: Methods, Meta: No Info, Prompt: Do not include any title unless you are certain its method is irrelevant. Assess each one based on its research procedures that align with goal of providing relevant information on the clarity and coherence of the research procedures and approach are irrelevant. Approach this task systematically, focusing on the techniques and approach are relevant or not. In your evaluation, exercise caution and precision. Screen the titles below, screen them both sensitively and specifically, focusing on how they contribute to a general and balanced understanding of the research procedures and approach and exclude those with irrelevant ones. Similarly, do not include any title unless you can confidently judge that their research protocol, procedures, and approach, and relevant current techniques. Avoid excluding any titles unless there is a clear research procedure, or relevant current techniques.
# Section: Methods, Meta: No Info, Prompt: Dismiss items that fail to meet these basic thresholds, retaining papers that showcase thoroughness in their research procedures and approach suggested by each title. This review should prioritize thoughtful and deliberate inclusion of works with clear and significant research procedures, approach, and methods suggested by each title. You have read thousands of papers in your field. You are a world-class scientist who has screened countless papers throughout their life. Avoid selecting papers that showcase thoroughness in their research protocol, enabling informed consideration within a broader and meaningful methods, demonstrates relevance to a general and balanced understanding of the available literature. Similarly, refrain from including titles unless you can confidently judge that their research procedures and approach and exclude papers that showcase thoroughness in their exploration of significant research methods and provide transparency in their exploration of significant research methods and those with irrelevant ones. Select titles with relevant methods and those with irrelevant ones. Do not exclude any title unless you are absolutely certain that its research procedures and exclude papers that lack sufficient focus on identifying studies with research procedures, approach, and methods suggested by the titles, you will contribute to a general and balanced understanding of the provided list of provided titles with relevant methods of the provided list of titles below, focusing on the techniques and approach and exclude those whose methods lack relevance or utility in supporting further academic inquiry. Select each one based on its capacity to enhance general insights, address meaningful research protocol while excluding those that lack sufficient focus on pertinent research methods and those with irrelevant ones. As you go through the titles below, focusing on their research protocol, enabling informed consideration within a broader and meaningful methods, demonstrates relevance to a cohesive and comprehensive understanding of the papers.
# Section: Methods, Meta: For MA, Prompt: Exclude titles only when you are confident their research procedures, approach, and method, to determine their relevance in terms of its method and its alignment with the general standards for inclusion, and include titles only if you are confident their research procedures, approach, and methods. This review should emphasize careful and thoughtful approach will play a pivotal role in achieving the objectives of conducting a rigorous and balanced meta-analysis on the current cutting-edge techniques of papers in the current methods of each title based on their methods. Select titles with relevant methods for inclusion in a meta-analysis on the subject matter of the following titles, based on their methods do not meet the general requirements for inclusion. focus on the research procedures, approach, and methods, should be included? The titles below for their relevance for inclusion. focus on identifying works with meaningful and relevant methods for inclusion and excluding those whose methods are not aligned with the highest standards of current cutting-edge techniques of papers in the current cutting-edge techniques of papers below, focusing on their research procedures, approach, and methods.
# Section: Methods, Meta: For MA, Prompt: Your role in this screening process contributes to a meaningful synthesis of knowledge.
# Section: Methods, Meta: For MA, Prompt: Similarly, avoid including titles unless you are certain their methods align with the concepts of sensitivity and specificity and focusing on research methods and procedures, you will help ensure that your screening process is crucial, and your role is to carefully screen studies for their relevance for inclusion. Carefully go through the titles of papers supports a robust and meaningful synthesis of knowledge. You are tasked with assisting in the field. By carefully judging the research procedures, approach, and methods a manually conducted gold standard meta-analysis would have excluded.
# ...
# Section: Results, Meta: For MA, Prompt: You are familiar with the highest standards of current cutting-edge conclusions of papers supports a robust synthesis. Thus, you should aim to select those papers as relevant whose research discovery aligns with its criteria for inclusion in a meta-analysis on the research outcomes, findings, and results of the field. Screen the titles below, screen them both sensitively and specifically, focusing on their research outcomes, findings, and results, and evaluate their potential to contribute meaningfully to a comprehensive synthesis of evidence. As you review the titles below, screen them both sensitively and specifically, focusing on its research discovery and its alignment with the purpose of a meta-analysis.To achieve this balance, imagine that your work is being compared to the research discovery aligns with its criteria for inclusion in a meta-analysis. Select titles with results likely to align with the highest standards of a meta-analysis by screening scientific paper titles for their relevance. Exclude titles only when you are confident their results lack the necessary attributes to support the goals of covering cutting-edge research outcomes and findings hold potential value.Take into account that the final selection of papers in the current results of the results and the principles of sound academic practice. This means that you select those titles with relevant results that contribute to a meaningful synthesis of research studies, aiming to combine and analyze their findings to draw broader conclusions about a particular field or outcome.
# Section: Results, Meta: Title, Prompt: Approach this task with a high degree of specificity.
# Section: Results, Meta: Title, Prompt: Aim to make choices that reflect relevant insight into the current state of relevant findings, research outcomes, findings, and results. Approach this task with a high degree of sensitivity. This is a critical step in ensuring that the most relevant conclusions and exclude all those that reflect relevant conclusions of the current state of relevant findings, research outcomes, and findings of each title, ensuring that your selections reflect the high standards required for a high-quality meta-analysis. Your task is to make choices that reflect relevant insight into the current state of relevant findings, research outcomes, findings, and results. Exclude titles only when you are confident their research outcomes, findings, and results. Carefully go through the titles of scientific papers to determine whether it aligns with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Results, Meta: Title, Prompt: Carefully go through the titles below, screen them both sensitively and specifically, focusing on their research outcomes, findings, and results. This means that you select those titles with relevant conclusions and results in the field. This process demands precision, as each decision will directly impact the integrity and comprehensiveness of the selection process captures studies with significant and relevant results while avoiding irrelevant titles.Imagine that your decisions are being compared to a benchmark gold standard would have excluded. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. Your task is to make decisions that would mirror those of this meta-analysis.
# Section: Results, Meta: Title, Prompt: Exclude those that reflect relevant conclusions of the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment. This means that you select those titles with relevant conclusions and exclude those with conclusions relevant to this task. Consider how the research outcomes, findings, and results of the field, ensuring that no potentially valuable study with relevant results while avoiding irrelevant titles.Imagine that your selections reflect the high standards required for a high-quality meta-analysis. This means that you select those titles with relevant results is excluded while maintaining the integrity of the meta-analysis, helping to build a robust and well-rounded representation of the available evidence. Carefully assess each paper might support the comprehensive nature of the available evidence. Consider whether the title suggests a work that addresses meaningful research outcomes, findings, and results, to decide which ones should be assessed objectively, based on its research discovery and its potential contribution to a balanced and meaningful synthesis of conclusions. As you go through the titles below, screen them both sensitively and specifically, focusing on its research outcomes, and results of the selection process captures studies with significant and relevant results while avoiding irrelevant titles.Imagine that your decisions are being compared to a balanced and meaningful synthesis of current conclusions and exclude all those that this gold standard would have excluded. Include all papers with results relevant to the quality and impact of this meta-analysis. Include all papers with results relevant to the meta-analysis and excluding those that this gold standard would have excluded. This is a critical step in ensuring that your decisions are being compared to a benchmark gold standard would have excluded. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results.
# Section: Results, Meta: Title, Prompt: As you go through the titles of scientific papers to determine whether it aligns with the scope and objectives of this gold standard for meta-analysis screening. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. You are familiar with the scope and objectives of this meta-analysis. As you screen the provided titles of scientific papers to determine whether it aligns with the scope and objectives of this meta-analysis. This involves balancing inclusivity with precision: ensuring that your decisions are being compared to a balanced and meaningful synthesis of conclusions. Exclude those that do not meet its standards. Exclude titles only when you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion, and excluding those that do not meet its standards. Carefully assess each paper might support the comprehensive nature of the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment. Exclude those that are irrelevant. Similarly, avoid including titles unless you are confident their research outcomes, findings, and result to determine whether it aligns with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Results, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance by focusing on their research outcomes, findings, and result to determine if they reflect relevant conclusions and results of each title, ensuring that your decisions are being compared to a benchmark gold standard for meta-analysis screening. Approach this task with a clear commitment to high academic standards. You are tasked with screening potential papers for their relevance by focusing on its research outcomes, findings, and results of each paper by focusing on its research outcomes, findings, and result to determine if they reflect relevant conclusions of the meta-analysis.Your expertise and judgment are central to this meta-analysis and exclude those with irrelevant ones. Carefully go through the titles below, screen them both sensitively and specifically, focusing on their research outcomes, findings, and result to determine whether it aligns with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the provided titles of scientific papers, focusing on their research discovery meets the general requirements for inclusion, and excluding those that are irrelevant. Your goal is to carefully screen the titles, focus on identifying those that this gold standard for meta-analysis screening. Approach this task with a high degree of sensitivity. Your goal is to carefully assess the provided titles of papers below, selecting those with irrelevant ones. This process demands precision, as each decision will directly impact the integrity of the field, ensuring that no potentially valuable contributions are included with a high degree of sensitivity. This involves balancing inclusivity with precision: ensuring that the meta-analysis accurately provides a cutting-edge synthesis of current conclusions and results in the field. This means that you select those titles with relevant conclusions and exclude those with irrelevant ones. Exclude titles only when you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion, reflecting a high degree of sensitivity.
# Section: Results, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance by focusing on their research outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: Consider the role of each title. Include titles only if you are confident their research results, are selected. What are cutting-edge findings? Consider the role of each title’s research discovery, outcomes, and findings of each title. Your careful evaluation of the meta-analysis.
# Section: Results, Meta: Criteria, Prompt: You are part of a research team conducting a meta-analysis. Your careful evaluation of the papers, in particular. As you go through the titles below, screen them both sensitively and specifically, focusing on their research discovery of each title’s research discovery, outcomes, and findings of each title align with the inclusion criteria, and exclude those that align with the concepts of sensitivity and specificity in signal-detection theory. Include titles only if you are certain their results meet the inclusion criteria, and exclude those that are currently of interest? Approach each title to determine their relevance in reflecting current relevant results and research outcomes. Carefully go through the titles below, screen them both sensitively and specifically, focusing on the results below. This process is guided by specific selection criteria that have been carefully established to ensure the meta-analysis produces a meaningful and comprehensive synthesis of knowledge. Carefully go through the titles of scientific papers for inclusion in a meta-analysis. Include titles only when you are certain their research outcomes, findings, or results do not meet the inclusion criteria, and exclude titles only when you are confident their results do not meet the inclusion and exclusion criteria and align with the inclusion criteria and exclude titles only when you are confident their results match the exclusion criteria. focus on the results of the titles, will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge. Approach this task systematically, focusing on their research discovery of the meta-analysis. Approach this task with diligence, carefully evaluating the relevance of each title align with its purpose.
# Section: Results, Meta: Criteria, Prompt: Exclude titles only when you are certain their research discovery will form the foundation for the meta-analysis, to ensure covering the relevant outcomes, findings, and results to determine its relevance based on the research landscape. Your goal is to identify papers with results that meet the inclusion criteria should be considered for inclusion. You are part of a world-class researcher. Your task is to identify papers with results that meet the inclusion and exclusion criteria and focusing on how the research landscape. Include titles only if you are certain their results do not meet the inclusion criteria and contributes to the inclusion criteria should be considered for inclusion.
# Section: Results, Meta: Criteria, Prompt: Include titles only if they clearly meet the inclusion criteria, and exclude those that this gold standard meta-analysis would have excluded. focus on the research discovery, outcomes, and findings of each title’s research discovery, conclusions, and results of the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge. Include titles only when you are confident their research discovery does not contribute to its purpose. By adhering to the inclusion criteria and align with the inclusion criteria and exclude those that align with the purpose of the field.The success of this meta-analysis. You are tasked with screening the titles of scientific papers for inclusion in a meta-analysis. Include titles only if you are confident their results clearly meet the inclusion criteria and contributes to the quality and impact of this meta-analysis depends on a meticulous selection process that ensures all relevant studies with meaningful results are selected, your work will contribute significantly to the broader objectives of the research discovery and conclusions.
# Section: Results, Meta: Criteria, Prompt: You are part of a world-class researcher. You are part of a research team conducting a meta-analysis. You are tasked with screening potential papers for their inclusion in a meta-analysis. This process is guided by specific selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a world-class researcher. The success of this meta-analysis depends on your ability to navigate the screening manually would have selected the same papers based on the research discovery does not contribute to its purpose. Your careful evaluation of the titles, will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of the meta-analysis, to ensure covering the relevant outcomes, findings, research discoveries, and conclusions of the papers, you will play a critical role in ensuring that only the most relevant and exclude titles prematurely, ensuring that the meta-analysis by ensuring that the most relevant and valuable research results are relevant and exclude those that fall under the exclusion criteria.In your screening, focus on conclusions and cutting-edge findings. What are cutting-edge findings?
# Section: Results, Meta: Criteria, Prompt: You are part of a research team conducting a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Conversely, exclude titles only when you are confident their results do not align with the purpose of the papers, you will play a critical role in ensuring that the most relevant and valuable research results are relevant and appropriate studies, based on their research discovery meets the inclusion criteria, and exclude those that fall under the exclusion criteria. You are part of a world-class researcher. Your careful evaluation of the titles, will form the foundation for the meta-analysis, to ensure covering the relevant outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: You are tasked with screening the titles of scientific papers to determine their relevance by focusing on the research discovery meets the inclusion criteria, and exclude those that align with the exclusion criteria.
# Section: Results, Meta: Criteria, Prompt: You are part of a research team conducting a meta-analysis. Be rigoros in your evaluation, balancing careful inclusion and exclusion criteria. focus on ensuring a balanced and thorough selection based on their research discovery does not contribute to its purpose.

# %%
# Preprocess the generated prompts to replace double quotes with single quotes
generated_prompts_df['Generated Prompt'] = generated_prompts_df['Generated Prompt'].str.replace('"', '')

# Save results without additional quotes
generated_prompts_df.to_csv("generated_prompts.csv", index=False, quoting=csv.QUOTE_NONE, sep=';')

# %% [markdown]
# We are working on a copy of the original `generated_prompts.csv` now, which is `generated_prompts_cleaned.csv`.

# %%
# Load the cleaned generated prompts
generated_prompts_cleaned_df = pd.read_csv('generated_prompts_cleaned.csv', delimiter=';')

# %% [markdown]
# We have revised the generated prompts and rewritten those that were syntactically or semantically nonsensical. However, since the choice of words is very restrictive based on the previous input, we now want to further expand the data using an LLM.

# %%
import openai

# Set your OpenAI API key
openai.api_key = "OPENAI_API_KEY"

# Load the initial prompts cleaned dataframe
df = pd.read_csv('initial_prompts_cleaned.csv', delimiter=';')

# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Load the existing generated prompts cleaned dataframe
generated_prompts_cleaned_df = pd.read_csv('generated_prompts_cleaned.csv', delimiter=';')

# Function to generate new prompts using OpenAI's API
def generate_prompts(section_ref, meta_info, existing_prompts):
    llm_prompt = f"""
    You are tasked with generating new prompts for the combination of Section Reference: '{section_ref}' and Meta-Analysis Info: '{meta_info}'. The existing prompts for this combination are as follows:

    {existing_prompts}

    Please generate 10 new prompts that maintain the aspect of Section Reference and Meta-Analysis Info but are varied in choice of language, words, and general sentence structure.
    """
    
    response = openai.Completion.create(
        engine="gpt-4o-2024-08-06",
        prompt=llm_prompt,
        max_tokens=150,
        n=10,
        stop=None,
        temperature=0.7
    )
    
    new_prompts = [choice['text'].strip() for choice in response.choices]
    return new_prompts

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
all_new_prompts = []
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_df = df[(df['Section Reference'] == section_ref) & (df['Meta-Analysis Info'] == meta_info)]
        
        # Extract existing prompts
        existing_prompts = filtered_df['TitlePrompt'].dropna().tolist()
        
        if existing_prompts:
            # Generate new prompts using OpenAI's API
            new_prompts = generate_prompts(section_ref, meta_info, existing_prompts)
            
            # Create a new dataframe for the new prompts
            new_prompts_df = pd.DataFrame({
                'Section Reference': [section_ref] * len(new_prompts),
                'Meta-Analysis Info': [meta_info] * len(new_prompts),
                'Generated Prompt': new_prompts
            })
            
            # Append the new prompts to the existing dataframe
            all_new_prompts.append(new_prompts_df)

# Concatenate all new prompts dataframes
if all_new_prompts:
    all_new_prompts_df = pd.concat(all_new_prompts, ignore_index=True)
    extended_prompts_df = pd.concat([generated_prompts_cleaned_df, all_new_prompts_df], ignore_index=True)
    
    # Save the extended dataframe to 'generated_prompts_cleaned.csv'
    extended_prompts_df.to_csv('generated_prompts_cleaned.csv', index=False, sep=';')
    
    # Display the new prompts
    print("Newly Generated Prompts:")
    for _, row in all_new_prompts_df.iterrows():
        print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['Generated Prompt']}")
else:
    print("No new prompts generated.")
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[100], line 30
#      21 llm_prompt = f"""
#      22 You are tasked with generating new prompts for the combination of Section Reference: '{section_ref}' and Meta-Analysis Info: '{meta_info}'. The existing prompts for this combination are as follows:
#      23
#    (...)
#      26 Please generate 10 new prompts that maintain the aspect of Section Reference and Meta-Analysis Info but are varied in choice of language, words, and general sentence structure.
#      27 """
#      29 # Generate new prompts using OpenAI's API
# ---> 30 response = openai.Completion.create(
#      31     engine="davinci",
#      32     prompt=llm_prompt,
#      33     max_tokens=150,
#      34     n=10,
#      35     stop=None,
#      36     temperature=0.7
#      37 )
#      39 # Extract the generated prompts from the response
#      40 new_prompts = [choice['text'].strip() for choice in response.choices]
#
# File ~/Library/CloudStorage/OneDrive-Persönlich/programme/coding/github/ensure/.venv/lib/python3.12/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
# # Extend the generated prompts dataframe by the original table structure
# extended_prompts = generated_prompts_cleaned_df.copy()
# extended_prompts['Model'] = 1
# extended_prompts['Words'] = extended_prompts['Generated Prompt'].apply(lambda x: len(x.split()))
# extended_prompts['screen_titles'] = 1
# extended_prompts['screen_abstracts'] = 0

# # Add empty columns for the rest of the structure
# columns_to_add = ['TitlePrompt', 'AbstractPrompt', 'sensitivity_titles', 'specificity_titles', 'PPV_titles', 'NPV_titles', 'tp_titles', 'tn_titles', 'fp_titles', 'fn_titles', 'sensitivity_abstracts', 'specificity_abstracts', 'PPV_abstracts', 'NPV_abstracts', 'tp_abstracts', 'tn_abstracts', 'fp_abstracts', 'fn_abstracts']
# for col in columns_to_add:
#     extended_prompts[col] = ''

# # Save the extended dataframe
# extended_prompts.to_csv('generated_prompts_cleaned.csv', index=False, sep=';')

# # Display the extended dataframe
# print(extended_prompts.head())

# %%
add plots for distribution of number of words and sentences before and after adding generated and cleaned prompts.
# Out:
#   Cell In[96], line 1
#     add plots for distribution of number of words and sentences before and after adding generated and cleaned prompts.
#         ^
# SyntaxError: invalid syntax

# %%
Then we want to extend the generated prompts df by the original table structure Model;Words;Section Reference;Meta-Analysis Info;screen_titles;screen_abstracts;TitlePrompt;AbstractPrompt;sensitivity_titles;specificity_titles;PPV_titles;NPV_titles;tp_titles;tn_titles;fp_titles;fn_titles;sensitivity_abstracts;specificity_abstracts;PPV_abstracts;NPV_abstracts;tp_abstracts;tn_abstracts;fp_abstracts;fn_abstracts
 in that, everything has to be empty except model, which should be 1, words, which should be the count of words in the prompt, screen titles should be 1 and screen abstract should be 0
# Out:
#   Cell In[62], line 1
#     Then we want to extend the generated prompts df by the original table structure Model;Words;Section Reference;Meta-Analysis Info;screen_titles;screen_abstracts;TitlePrompt;AbstractPrompt;sensitivity_titles;specificity_titles;PPV_titles;NPV_titles;tp_titles;tn_titles;fp_titles;fn_titles;sensitivity_abstracts;specificity_abstracts;PPV_abstracts;NPV_abstracts;tp_abstracts;tn_abstracts;fp_abstracts;fn_abstracts
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. ttl und ander ehinter title einfügen für jeweilige Kategorien in generated prrompts
# 2. eintragen von gpt in generated
# 3. kombinieren, ausfüllen von fertiger tabelle wie in initial prompts
