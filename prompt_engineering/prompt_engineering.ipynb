# %% [markdown]
# # Generating Diverse Prompts for Section References and Meta-Analysis Info Combinations
#
# ## Overview
#
# This file aims to create a set of diverse and varied prompts for each combination of *Section Reference* and *Meta-Analysis Info* categories. The primary goal is to extend and enrich the initial set of prompts by varying their language structure by alternating the syntax and choice of words by alternating semantics, ensuring the outputs are sufficiently different while maintaining their original intent.
#
# By doing so, we aim to generate up to as many prompts to receive 20 unique prompts per combination, suitable for further use in classification, training, or testing scenarios. This variation enhances the linguistic richness and diversity of the dataset, ensuring broader applicability and adaptability. Afterwards, we are going to extend them by 10 prompts received by a large language model.
#
# ## Methodology
#
# To achieve the goal, the following approach is taken:
# 1.	Input Dataset:
# - The dataset contains prompts categorized by *Section Reference* (e.g., “No Reference,” “Topic,” “Methods,” “Results”) and *Meta-Analysis Info* (e.g., “No Info,” “For MA,” “Title,” “Criteria”).
# - Each prompt is associated with a specific combination of these two dimensions.
# 2.	Prompt Expansion Using Markov Chains:
# - The markovify package is used to simulate new prompts by leveraging Markov chains.
# - All prompts belonging to a specific combination of categories are used as input to a Markov model, which generates new prompts based on observed patterns in the input data.
# - This allows for the creation of prompts that retain the style and structure of the originals while introducing variation.
# 3.	Ensuring Uniqueness and Quality:
# - The generated prompts are checked against the existing prompts to ensure no duplicates are added.
# - Prompts are also filtered for redundancy within the same generation cycle.
# - If a generated prompt doesn’t meet the criteria (e.g., it is too similar to the originals or doesn’t make sense), the model generates additional prompts to compensate.
# 4.	Final Validation of Markov Chain Model:
# - Prompts are formatted uniformly to maintain a consistent presentation.
# - Outputs are reviewed, and necessary adjustments are made to improve clarity, variation, and alignment with the intended meaning. If needed, the cycle is run again go receive the missing prompts
# 5. Extension of Prompts by LLM
# - Utilizing a pre-trained LLM to generate 10 additional prompts for each combination of *Section Reference* and *Meta-Analysis Info*.
# - Ensure that these new prompts align with the existing structure and intent of the original prompts.
# 6. Final Dataset
# - Combine all prompts into a final dataset, ensuring each combination of categories has a comprehensive set of prompts.
# - This final dataset will be used for further classification, training, or testing scenarios, providing a robust and diverse set of prompts for various applications.
#
# ## Why This Approach?
#
# Using Markov chains enables the generation of syntactically coherent variations based on existing data. This method ensures:
# - Efficiency: Quickly generates multiple variations without requiring manual input for each prompt.
# - Diversity: Captures different sentence structures and word choices while retaining the essence of the original prompts.
# - Scalability: Handles multiple combinations of categories, making it suitable for large datasets.
#
# ## Enhancing Markov Chain Models with LLMs
#
# While Markov chains are effective in generating syntactically coherent variations based on existing data, they have limitations in capturing the deeper semantic relationships and contextual nuances present in natural language. Markov chains rely on the probability of word sequences, which can lead to repetitive and sometimes nonsensical outputs, especially when the input data is limited or lacks diversity. To address these limitations, we incorporate Large Language Models (LLMs) into our prompt generation process. LLMs, such as GPT-3, are pre-trained on vast amounts of text data and are capable of understanding and generating human-like text with a high degree of coherence and relevance. By leveraging LLMs, we can:
# - Enhance Diversity: LLMs can generate a wider range of prompts with varied sentence structures and vocabulary, reducing the risk of repetitive outputs that are common with Markov chains.
# - Improve Contextual Understanding: LLMs have a better grasp of context and can produce prompts that are more aligned with the intended meaning and purpose, ensuring higher quality and relevance.
# - Increase Semantic Richness: By incorporating LLMs, we can generate prompts that capture deeper semantic relationships, making the outputs more meaningful and useful for downstream tasks.
# - Maintain Coherence: LLMs can generate longer and more complex prompts while maintaining coherence, which is challenging for Markov chains that operate on fixed state sizes.
#
# By combining the strengths of Markov chains and LLMs, we achieve a robust and diverse set of prompts that are both syntactically and semantically rich, enhancing the overall quality and applicability of the generated dataset. By the end of this process, we will have a rich, diverse, and meaningful set of prompts that are ready for deployment in various applications.

# %%
import pandas as pd
import markovify
import csv
import random

# %%
# Load the initial_prompts.csv into a dataframe
df = pd.read_csv('initial_prompts.csv', delimiter=';')

# Remove line breaks in the 'TitlePrompt' column
df['TitlePrompt'] = df['TitlePrompt'].str.replace('\n', ' ').str.replace('\r', ' ')

# Fill NaN values with empty strings in the 'TitlePrompt' column
df['TitlePrompt'].fillna('', inplace=True)

# Delete all rows below index 213
df = df.iloc[:213]

# Set 'screen_titles' to 1 and 'screen_abstracts' to 0
df['screen_titles'] = 1
df['screen_abstracts'] = 0

# Save the cleaned dataframe to prompts.csv
df.to_csv('initial_prompts_cleaned.csv', index=False, sep=';')

# Display the cleaned dataframe
print(df.head(25))
# Out:
#     Model  Words Section Reference Meta-Analysis Info  screen_titles  \
# 0       1      1      No Reference            No Info              1
# 1       1      8      No Reference            No Info              1
# 2       1      4      No Reference            No Info              1
# 3       1      6      No Reference            No Info              1
# 4       1     13      No Reference            No Info              1
# 5       1      6      No Reference            No Info              1
# 6       1     13      No Reference            No Info              1
# 7       1     10      No Reference            No Info              1
# 8       1     47      No Reference            No Info              1
# 9       1     42      No Reference            No Info              1
# 10      1     47      No Reference            No Info              1
# 11      1     56      No Reference            No Info              1
# 12      1     70      No Reference            No Info              1
# 13      1    136      No Reference            No Info              1
# 14      1    131      No Reference            No Info              1
# 15      1    278      No Reference            No Info              1
# 16      1    177      No Reference            No Info              1
# 17      1     10      No Reference             For MA              1
# 18      1     16      No Reference             For MA              1
# 19      1     10      No Reference             For MA              1
# 20      1     15      No Reference             For MA              1
# 21      1     78      No Reference             For MA              1
# 22      1     55      No Reference             For MA              1
# 23      1     53      No Reference             For MA              1
# 24      1    105      No Reference             For MA              1
#
#     screen_abstracts                                        TitlePrompt  \
# 0                  0
# 1                  0        Screen the titles below like a human would.
# 2                  0                           Screen the titles below.
# 3                  0         You are a world-class clinical researcher.
# 4                  0  Do not exclude any titles unless you are absol...
# 5                  0             Select the most relevant titles below.
# 6                  0  Of the titles below, aim to include relevant o...
# 7                  0  Go through the titles below carefully and sele...
# 8                  0  Consider the titles of the papers below. Selec...
# 9                  0  You are familiar with the concepts of sensitiv...
# 10                 0  You are a world-class scientist who has screen...
# 11                 0  You are a world-class researcher. You have rea...
# 12                 0  Carefully review the given list of scientific ...
# 13                 0  Conduct a thorough review of the provided list...
# 14                 0  Systematically review the provided list of sci...
# 15                 0  You are a world-class researcher with extensiv...
# 16                 0  Carefully evaluate the list of provided titles...
# 17                 0  Screen the titles below for their inclusion in...
# 18                 0  The titles below belong to papers that will be...
# 19                 0  Select the relevant titles below like a world-...
# 20                 0  Imagine you want to write a meta-analysis. Whi...
# 21                 0  The titles below will be screened for their in...
# 22                 0  A meta-analysis is a rigorous and systematic s...
# 23                 0  You are a researcher in a world-class scientif...
# 24                 0  You are a world-class researcher contributing ...
#
#                                        AbstractPrompt  sensitivity_titles  \
# 0                                                 NaN                 NaN
# 1      Screen the abstracts below like a human would.                 NaN
# 2                         Screen the abstracts below.                 NaN
# 3          You are a world-class clinical researcher.                 NaN
# 4   Do not exclude any abstracts unless you are ab...                 NaN
# 5           Select the most relevant abstracts below.                 NaN
# 6   Of the abstracts below, aim to include relevan...                 NaN
# 7   Go through the abstracts below carefully and s...                 NaN
# 8   Consider the abstracts of the papers below. Se...                 NaN
# 9   You are familiar with the concepts of sensitiv...                 NaN
# 10  You are a world-class scientist who has screen...                 NaN
# 11  You are a world-class researcher. You have rea...                 NaN
# 12  Carefully review the given list of scientific ...                 NaN
# 13  Conduct a thorough review of the provided list...                 NaN
# 14  Systematically review the provided list of sci...                 NaN
# 15  You are a world-class researcher with extensiv...                 NaN
# 16  Carefully evaluate the list of provided abstra...                 NaN
# 17  Screen the abstracts below for their inclusion...                 NaN
# 18  The abstracts below belong to papers that will...                 NaN
# 19  Select the relevant abstracts below like a wor...                 NaN
# 20  Imagine you want to write a meta-analysis. Whi...                 NaN
# 21  The abstracts below will be screened for their...                 NaN
# 22  A meta-analysis is a rigorous and systematic s...                 NaN
# 23  You are a researcher in a world-class scientif...                 NaN
# 24  You are a world-class researcher contributing ...                 NaN
#
#     specificity_titles  ...  fp_titles  fn_titles  sensitivity_abstracts  \
# 0                  NaN  ...        NaN        NaN                    NaN
# 1                  NaN  ...        NaN        NaN                    NaN
# 2                  NaN  ...        NaN        NaN                    NaN
# 3                  NaN  ...        NaN        NaN                    NaN
# 4                  NaN  ...        NaN        NaN                    NaN
# 5                  NaN  ...        NaN        NaN                    NaN
# 6                  NaN  ...        NaN        NaN                    NaN
# 7                  NaN  ...        NaN        NaN                    NaN
# 8                  NaN  ...        NaN        NaN                    NaN
# 9                  NaN  ...        NaN        NaN                    NaN
# 10                 NaN  ...        NaN        NaN                    NaN
# 11                 NaN  ...        NaN        NaN                    NaN
# 12                 NaN  ...        NaN        NaN                    NaN
# 13                 NaN  ...        NaN        NaN                    NaN
# 14                 NaN  ...        NaN        NaN                    NaN
# 15                 NaN  ...        NaN        NaN                    NaN
# 16                 NaN  ...        NaN        NaN                    NaN
# 17                 NaN  ...        NaN        NaN                    NaN
# 18                 NaN  ...        NaN        NaN                    NaN
# 19                 NaN  ...        NaN        NaN                    NaN
# 20                 NaN  ...        NaN        NaN                    NaN
# 21                 NaN  ...        NaN        NaN                    NaN
# 22                 NaN  ...        NaN        NaN                    NaN
# 23                 NaN  ...        NaN        NaN                    NaN
# 24                 NaN  ...        NaN        NaN                    NaN
#
#     specificity_abstracts  PPV_abstracts  NPV_abstracts  tp_abstracts  \
# 0                     NaN            NaN            NaN           NaN
# 1                     NaN            NaN            NaN           NaN
# 2                     NaN            NaN            NaN           NaN
# 3                     NaN            NaN            NaN           NaN
# 4                     NaN            NaN            NaN           NaN
# 5                     NaN            NaN            NaN           NaN
# 6                     NaN            NaN            NaN           NaN
# 7                     NaN            NaN            NaN           NaN
# 8                     NaN            NaN            NaN           NaN
# 9                     NaN            NaN            NaN           NaN
# 10                    NaN            NaN            NaN           NaN
# 11                    NaN            NaN            NaN           NaN
# 12                    NaN            NaN            NaN           NaN
# 13                    NaN            NaN            NaN           NaN
# 14                    NaN            NaN            NaN           NaN
# 15                    NaN            NaN            NaN           NaN
# 16                    NaN            NaN            NaN           NaN
# 17                    NaN            NaN            NaN           NaN
# 18                    NaN            NaN            NaN           NaN
# 19                    NaN            NaN            NaN           NaN
# 20                    NaN            NaN            NaN           NaN
# 21                    NaN            NaN            NaN           NaN
# 22                    NaN            NaN            NaN           NaN
# 23                    NaN            NaN            NaN           NaN
# 24                    NaN            NaN            NaN           NaN
#
#     tn_abstracts  fp_abstracts  fn_abstracts
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7            NaN           NaN           NaN
# 8            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 10           NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 13           NaN           NaN           NaN
# 14           NaN           NaN           NaN
# 15           NaN           NaN           NaN
# 16           NaN           NaN           NaN
# 17           NaN           NaN           NaN
# 18           NaN           NaN           NaN
# 19           NaN           NaN           NaN
# 20           NaN           NaN           NaN
# 21           NaN           NaN           NaN
# 22           NaN           NaN           NaN
# 23           NaN           NaN           NaN
# 24           NaN           NaN           NaN
#
# [25 rows x 24 columns]
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_1092/2230491091.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TitlePrompt'].fillna('', inplace=True)

# %%
# Count the number of prompts for each combination of Section Reference and Meta-Analysis Info
prompt_counts = df.groupby(['Section Reference', 'Meta-Analysis Info']).size().reset_index(name='Count')

# Display the counts
print(prompt_counts)
# Out:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria     11
# 1            Methods             For MA     13
# 2            Methods            No Info     15
# 3            Methods              Title     13
# 4       No Reference           Criteria     13
# 5       No Reference             For MA     13
# 6       No Reference            No Info     17
# 7       No Reference              Title     14
# 8            Results           Criteria     11
# 9            Results             For MA     13
# 10           Results            No Info     15
# 11           Results              Title     13
# 12             Topic           Criteria     11
# 13             Topic             For MA     13
# 14             Topic            No Info     15
# 15             Topic              Title     13

# %%
# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Function to generate unique new prompts
def generate_unique_prompts(model, num_prompts, existing_prompts, min_sentences=0, max_sentences=12):
    generated_prompts = set(existing_prompts)  # Set to avoid duplicates
    new_prompts = []
    attempts = 0  # Safety loop to prevent infinite loops
    max_attempts = num_prompts * 10  # Max attempts per required prompt
    
    while len(new_prompts) < num_prompts and attempts < max_attempts:
        attempts += 1
        # Randomly choose a number of sentences for the prompt
        num_sentences = random.randint(min_sentences, max_sentences)
        sentences = set()
        prompt = []
        for _ in range(num_sentences):
            sentence = model.make_sentence(tries=100)
            if sentence and sentence not in sentences:
                sentences.add(sentence)
                prompt.append(sentence)
        prompt_text = " ".join(prompt)
        if prompt_text and prompt_text not in generated_prompts:  # Check for duplicates
            generated_prompts.add(prompt_text)
            new_prompts.append(prompt_text.strip())  # Ensure uniform layout
    return new_prompts

# Save all new prompts
all_generated_prompts = []

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_data = df[
            (df["Section Reference"] == section_ref) &
            (df["Meta-Analysis Info"] == meta_info)
        ]
        
        # Extract existing prompts
        existing_prompts = filtered_data["TitlePrompt"].dropna().tolist()
        num_existing_prompts = len(existing_prompts)
        
        # Calculate the number of new prompts
        num_new_prompts = max(0, 20 - num_existing_prompts)  # No negative values
        
        if num_new_prompts > 0 and existing_prompts:
            # Combined text for Markov model
            combined_text = "\n\n".join(existing_prompts)
            
            # Create Markov model
            markov_model = markovify.Text(
                combined_text,
                state_size=2,
                retain_original=False  # Prevents reconstruction of original texts
            )
            
            # Generate new unique prompts
            new_prompts = generate_unique_prompts(
                markov_model,
                num_prompts=num_new_prompts,
                existing_prompts=existing_prompts,
                min_sentences=0,
                max_sentences=12
            )
            
            # Save new prompts
            for prompt in new_prompts:
                all_generated_prompts.append({
                    "Section Reference": section_ref,
                    "Meta-Analysis Info": meta_info,
                    "Generated Prompt": prompt
                })

# Write results to a DataFrame
generated_prompts_df = pd.DataFrame(all_generated_prompts)

# Output the generated prompts
print("Generated Prompts:")
for _, row in generated_prompts_df.iterrows():
    print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['Generated Prompt']}")
# Out:
# Generated Prompts:
# Section: No Reference, Meta: No Info, Prompt: Exclude the irrelevant papers and include the relevant papers in your life from a broad range of fields. Consider whether the paper addresses the broader context of inquiry. Of the titles below and assess their scientific rigor.
# Section: No Reference, Meta: No Info, Prompt: Systematically review the provided list of provided titles with the concepts of sensitivity and specificity in signal-detection theory. Consider whether the paper addresses the broader research question, adheres to established principles of careful selection, fairness, and scholarly rigor, allowing your expertise to guide you in making informed and accurate decisions. This review should prioritize thoughtful and balanced understanding of the available literature, prioritizing works that provide sufficient detail and transparency to allow for informed consideration within a broader understanding of the subject area.
# Section: No Reference, Meta: No Info, Prompt: In your evaluation, exercise caution and precision. This review should prioritize thoughtful and deliberate inclusion, reserving exclusion for cases where relevance and potential to contribute to a general and balanced understanding of the available knowledge base. You are a world-class researcher. Consider the titles of the subject. Your task is to assess each title based on its overall relevance and contribution are decisively lacking. Prioritize retaining papers that align with the highest standards of scholarly rigor. Systematically review the list of titles below and assess their scientific rigor. Consider whether the work demonstrates relevance to broader intellectual exploration, and demonstrate an ability to enrich the overarching goals of intellectual exploration. For each paper, assess its overall relevance and potential to contribute to a balanced perspective throughout. Aim to ensure that your selections align with the aim of evaluating their overall contribution to a thoughtful and deliberate inclusion, reserving exclusion for cases where relevance and potential to contribute meaningfully to a comprehensive and balanced understanding of the papers below.
# Section: No Reference, Meta: For MA, Prompt: Screen the titles of scientific papers for their inclusion in a meta-analysis. Exclude titles only if you are confident they align with its criteria for inclusion in a meta-analysis. Similarly, avoid including titles unless you are certain it lacks relevance or does not meet the general objectives of the subject matter without delving into the broader objectives of conducting a robust and meaningful meta-analysis. You are tasked with screening potential papers for inclusion in a meta-analysis. As you screen each title, you will ensure that the analysis is both comprehensive and reliable. As you go through the titles below, focus on including relevant ones and excluding irrelevant ones. Similarly, include titles only if you are confident they align with the broader research landscape. Similarly, avoid including titles unless you are certain they do not meet the general objectives of conducting a rigorous and comprehensive meta-analysis, and your role is to make decisions that would not meet the general requirements for inclusion. Your goal is to carefully screen the provided titles of papers you find below and select them for a meta-analysis. By carefully judging each title, you will help ensure that the final selection of papers supports a robust and meaningful insights into the broader objectives of conducting a robust and meaningful insights into the broader research landscape.
# Section: No Reference, Meta: For MA, Prompt: Prioritize titles that are irrelevant. Your goal is to carefully screen the provided titles and evaluate their overall potential to contribute meaningfully to the screening manually would have selected the same time, exercise specificity by excluding titles that are relevant and exclude those that are relevant and exclude irrelevant ones.
# Section: No Reference, Meta: For MA, Prompt: Exercise caution, objectivity, and consistency in your approach, reflecting the high standards expected in high-quality scientific work, ensuring your selections reflect both relevance and the principles of sound academic practice. The titles below will be screened for their selection in a meta-analysis. Aim to include relevant ones and exclude those that a gold standard would also have selected. Your role in achieving the objectives of conducting a rigorous and systematic synthesis of knowledge. You are a researcher familiar with the overarching objectives of conducting a rigorous and comprehensive synthesis of research studies, aiming to combine and analyze their findings to draw broader conclusions about a particular field or question. Similarly, avoid including titles unless you are certain they lack the necessary attributes to support the goals of a meta-analysis that conducted the screening of scientific papers for inclusion in a meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: You are assisting in the preparation of a team preparing a rigorous and balanced meta-analysis. As you go through the titles below, screen them both sensitively and specifically. You have properly marked titles as relevant when a state-of-the-art gold standard would also have selected. Conversely, exclude titles only when you are certain they do not meet the general criteria for inclusion in a meta-analysis. Take into account that the selection process is pivotal, and your selections reflect both relevance and the principles of sound academic practice. Similarly, avoid including titles unless you are confident that they meet the general requirements for inclusion. Similarly, include titles only when you are confident they align with the highest standards of a meta-analysis. You are tasked with screening potential papers for their relevance.
# Section: No Reference, Meta: For MA, Prompt: You are part of a meta-analytical process. Prioritize titles that are relevant and exclude those that are relevant and exclude those that are irrelevant as these world-class scientists would. This review should emphasize careful and thoughtful approach will play a pivotal role in this screening process contributes to a comprehensive understanding of the subject matter without delving into the specific methods, contents, or results of the following titles should be assessed objectively, based on its potential to contribute meaningfully to the meta-analysis. Similarly, avoid including titles unless you are confident in their relevance. Similarly, include titles only when you are confident they align with the same papers. As you screen each title, you will ensure that your screening process contributes to a meta-analysis that accurately reflects the broader objectives of the papers themselves. Thus, you should aim to select those titles that align with the precision and care, recognizing the importance of your decisions in shaping the quality and integrity of the available research. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant contributions. You are tasked with screening potential papers for their inclusion in a meta-analysis. Which of the available evidence while maintaining the integrity and reliability expected of such an effort. Approach this task with the goals of the following titles should be included? Your task is to identify titles that suggest alignment with the same time, exercise specificity by excluding titles that align with the broader body of knowledge within its scope.
# Section: No Reference, Meta: For MA, Prompt: Your task is to identify relevant titles below belong to papers that will be screened for their relevance for inclusion. Exclude titles only when you are certain it lacks relevance or does not meet the general objectives of conducting a rigorous and balanced meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: The titles below like a world-class scientific team that wants to write a meta-analysis. Do not exclude any title unless you are certain they do not meet the general objectives of the available evidence while maintaining the integrity and reliability expected of such an effort. Select the relevant titles with a high degree of specificity. You are a world-class researcher contributing to a meta-analysis that accurately reflects the broader research landscape. You have properly marked titles as relevant that a gold standard meta-analysis that conducted the screening of scientific papers for their relevance in the preparation of a rigorous and systematic synthesis of knowledge. At the same level of care and expertise expected in high-quality scientific work, ensuring that your screening process contributes to a balanced and meaningful synthesis of knowledge. Be cautious not to exclude titles only when you are confident they align with its criteria for inclusion in a meta-analysis. Your work in this process is crucial, and your role is to apply these principles rigorously throughout the screening decisions made by a state-of-the-art gold standard would also have selected. You are part of a meta-analysis. This process is crucial for the meta-analytical process. Apply your expertise in scholarly evaluation. Apply your expertise in rigorous academic evaluation to make thoughtful and accurate judgment.
# Section: No Reference, Meta: Title, Prompt: As you go through the titles below, screen them both sensitively and specifically. Use your expertise to make choices that reflect clarity, purpose, and potential value in contributing to a comprehensive and accurate representation of the available evidence. As a researcher familiar with the principles of rigorous scholarly communication. Use your expertise to make decisions that would mirror those of this gold standard, selecting titles that are relevant to this meta-analysis. By ensuring that the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Include titles only when it is clear they do not meet the broad criteria for inclusion in this meta-analysis. Your task is to identify relevant titles with a high degree of sensitivity, ensuring that your decisions are being compared to a cohesive and balanced approach, ensuring that potentially valuable contributions are included. Include titles only when you are confident in their relevance to this meta-analysis. Each title should be included in this meta-analysis. Each title should be guided by an objective and balanced synthesis. As you screen the provided titles of papers you find below and select them for a meta-analysis. You are tasked with screening potential papers for their relevance for inclusion and excluding those that reflect clarity, purpose, and potential value in contributing to a cohesive and balanced synthesis. Aim to make decisions that would mirror those of this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Conversely, exclude titles only when it is clear they do not meet its standards. Each title should be assessed objectively, based on its potential contribution to a balanced and meaningful synthesis of knowledge. Be cautious not to exclude titles only when you are confident in their relevance for inclusion in this meta-analysis. Your role is to ensure that the selected titles contribute to a cohesive and balanced synthesis. Think about how each paper might support the comprehensive nature of the available research. As you go through the titles below, screen them both sensitively and specifically. Exclude all those that reflect the thoughtful judgment and expertise expected of a world-class researcher.
# Section: No Reference, Meta: Title, Prompt: Aim to make decisions that would not meet its standards. Include titles only if you are confident in their relevance in the meta-analysis. Carefully evaluate each title to determine their relevance to the meta-analysis and exclude titles only when you are certain they lack the depth, scope, or relevance required to meet the general standards for inclusion. Aim to make decisions that would not meet the general standards for inclusion.
# Section: No Reference, Meta: Title, Prompt: Rely on your understanding of scholarly standards and best practices. Think about how each paper might support the comprehensive nature of the available evidence. Your goal is to carefully screen the provided titles of scientific papers to determine their relevance for inclusion in this meta-analysis. Exclude all those that are relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this gold standard, selecting titles that are relevant and exclude those that reflect the thoughtful judgment and expertise expected of a world-class researcher. Your goal is to ensure that the most relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis and exclude irrelevant ones. Aim to include relevant ones and exclude irrelevant ones.
# Section: No Reference, Meta: Title, Prompt: Be cautious not to exclude titles only when it is clear they do not align with its goals. Thus, you should aim to select those titles that are relevant to this task. As you screen the titles, focus on identifying those that would not meet the general standards for inclusion. Your decisions should be included in this meta-analysis. Your role is to carefully assess the provided titles of scientific papers and decide which ones should be included in this meta-analysis. Consider whether the title suggests a work that adheres to foundational academic standards, demonstrates coherence in its focus, and aligns with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully assess the provided titles of scientific papers to determine their relevance for inclusion in this meta-analysis. You are tasked with screening potential papers for their relevance to the quality and impact of this gold standard, selecting titles that are relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this meta-analysis. Your primary objective is to identify relevant titles with a high degree of sensitivity, ensuring that the selection process by avoiding irrelevant titles.Imagine that your decisions are being compared to a comprehensive and accurate decisions, ensuring that the most relevant and exclude titles only when you are certain they do not align with its criteria for inclusion. Use your expertise to make choices that reflect the standards required for a meta-analysis. Your task is to ensure that the selected titles contribute to a benchmark gold standard would also have selected. Aim to make decisions that would not meet the broad criteria for inclusion. As you screen the titles, focus on identifying those that are relevant and exclude irrelevant ones.
# Section: No Reference, Meta: Criteria, Prompt: Your goal is to identify papers that meet the inclusion and exclude titles only when it is equally clear that they match the exclusion criteria, which are as follows: Conference abstracts, letters with duplicates, case reports, meta-analyses, reviews, non-English published literature, incomplete or unavailable data, studies not related to the broader objectives of the importance of selection criteria will guide you in making decisions that reflect the highest standards of scholarly rigor. Apply your expertise thoughtfully, you will play a critical role in ensuring that only the most relevant and valuable titles are selected, your work will contribute significantly to the inclusion criteria and instead fall under the exclusion criteria, which are as follows: Conference abstracts, letters with duplicates, case reports, meta-analyses, reviews, non-English published literature, incomplete or unavailable data, studies not related to the topic of the importance of selection criteria will guide you in making decisions that reflect the highest standards of scholarly rigor. You are tasked with screening the titles of scientific papers for inclusion in a meta-analysis. Your evaluation should reflect careful judgment and rigorous evaluations that support the integrity and comprehensiveness of the meta-analysis.Your expertise in evaluating academic work and your understanding of the meta-analysis.Your expertise in evaluating academic work and your understanding of the meta-analysis. Consider the role of each title in contributing to the broader objectives of the importance of selection criteria that have been carefully established to ensure that the meta-analysis produces a meaningful and comprehensive synthesis of knowledge. Ensure your decisions are guided by specific selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a comprehensive and rigorous. Your primary focus should be on accurately assessing the potential relevance of each title in contributing to the quality and impact of this meta-analysis depends on your ability to navigate the screening manually would have selected the same time, avoid including titles that are irrelevant. You are part of a comprehensive and rigorous.
# Section: No Reference, Meta: Criteria, Prompt: Carefully go through the titles of scientific papers to determine whether it should be excluded. You are part of a research team conducting a meta-analysis. This requires a meticulous and thoughtful approach to ensure that the selection process supports the creation of a world-class researcher. At the same papers. Your careful evaluation will form the foundation for the meta-analysis, ensuring that your decisions are guided by specific selection criteria will guide you in making decisions that reflect the highest standards of scholarly rigor. Approach each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis. As you go through the titles of scientific papers to determine whether it should be excluded. By adhering to the inclusion and exclusion criteria. Be cautious not to exclude titles prematurely, ensuring that the final selection of studies supports a robust synthesis of knowledge under the meta-analysis. By adhering to the inclusion and exclude titles prematurely, ensuring that the final selection of studies supports a robust synthesis of knowledge. Aim to include relevant ones and exclude those that a gold standard meta-analysis that conducted the screening process with care and precision.
# Section: No Reference, Meta: Criteria, Prompt: You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis would have selected the same time, avoid including titles that do not meet the inclusion and exclude titles prematurely, ensuring that your decisions are fair, objective, and aligned with the objectives of the research landscape. Exclude all those that are irrelevant. Consider the role of each title in contributing to the inclusion and exclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that your decisions are guided by specific selection criteria that have been carefully established to ensure the meta-analysis by ensuring that the final selection of studies supports a robust synthesis of knowledge under the meta-analysis. As you go through the titles of scientific papers to determine their relevance for inclusion in a meta-analysis. Apply your expertise thoughtfully, you will play a critical role in ensuring that your decisions are fair, objective, and aligned with the objectives of the meta-analysis.Your expertise in evaluating academic work and your understanding of the meta-analysis, ensuring that the meta-analysis by ensuring that potentially valuable contributions are not overlooked.
# Section: No Reference, Meta: Criteria, Prompt: By adhering to the inclusion and exclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that potentially valuable contributions are not overlooked. Approach each title in contributing to the broader objectives of the meta-analysis. Papers that do not meet the inclusion and exclusion criteria and applying your expertise to make choices that reflect the thoughtful judgment and expertise expected of a world-class researcher. You are tasked with screening the titles of papers you find below and select them for a meta-analysis. Consider the role of each title in contributing to the topic of the meta-analysis, ensuring that the meta-analysis by ensuring that only the most relevant and valuable titles are selected, your work will contribute significantly to the inclusion criteria, and exclude those that are irrelevant. Your goal is to identify papers that meet the inclusion and exclude irrelevant ones. Be cautious not to exclude titles only when you are confident they clearly meet the inclusion criteria and applying your expertise to make choices that reflect the highest standards of scholarly rigor. Papers that do not meet the inclusion criteria and instead fall under the meta-analysis. This process is guided by specific selection criteria that have been carefully established to ensure that the selection process supports the creation of a world-class researcher. As you go through the titles of scientific papers for their inclusion in a meta-analysis. Your primary focus should be considered for inclusion.
# Section: No Reference, Meta: Criteria, Prompt: By ensuring that the meta-analysis is comprehensive and rigorous. As you go through the titles of scientific papers for their inclusion in this meta-analysis. Include titles only if they clearly meet the inclusion and exclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that the meta-analysis produces a meaningful and comprehensive synthesis of knowledge. Papers that do not. Aim to include relevant ones and exclude titles only when it is equally clear that they match the exclusion criteria. In your screening, focus on ensuring a balanced and thorough selection. This process demands a balance between thoroughness and precision. You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis that conducted the screening manually would have excluded.
# Section: No Reference, Meta: Criteria, Prompt: Include titles only if they definitively match the exclusion criteria. At the same time, avoid including titles that do not meet the inclusion criteria, and exclude titles only when it is equally clear that they match the exclusion criteria. Exclude all those that are not MSC transfusions, should be on accurately assessing the potential relevance of each title to determine its relevance based on the specified selection criteria. Be cautious not to exclude titles only when it is equally clear that they match the exclusion criteria.
# Section: No Reference, Meta: Criteria, Prompt: You are tasked with screening the titles of papers you find below and select them for a meta-analysis. Consider the role of each title based solely on how well it aligns with the objectives of the meta-analysis, ensuring that your decisions are guided by specific selection criteria that have been carefully established to ensure the meta-analysis produces a meaningful and comprehensive synthesis of knowledge. Exclude all those that do not. Be cautious not to exclude titles only when it is equally clear that they match the exclusion criteria. Apply your expertise thoughtfully, you will play a critical role in ensuring that the final selection of studies supports a robust synthesis of knowledge. You are tasked with screening the titles of scientific papers to determine their relevance for inclusion in a meta-analysis. Include all papers that are relevant and exclude titles only when you are confident they align with the objectives of the meta-analysis.
# Section: Topic, Meta: No Info, Prompt: Assess each one based on whether its research focus and hypotheses, as well as its potential to contribute meaningfully to a comprehensive understanding of the subject. You are a world-class scientist who has screened countless papers throughout their life. Consider the titles below, screen them both sensitively and specifically, focusing on how they contribute to a thoughtful and balanced understanding of research questions, hypotheses, and the alignment of the field of inquiry, emphasizing the relevance and academic contribution. Similarly, refrain from including titles unless you can confidently judge that their research focus of the papers. Do not exclude any title unless you are confident that it explores valuable topics. Systematically go through the titles below, focusing on their topic. Prioritize works that demonstrate meaningful research questions, consistency in addressing their hypotheses, and overall topic, focusing on the research questions, consistency in addressing their hypotheses, and topics that demonstrate meaningful research focus does not meet the basic criteria for inclusion. Screen the titles below for relevance, focusing on the clarity and coherence of the field.
# Section: Topic, Meta: No Info, Prompt: Do not include any title unless you are certain its topic is relevant. For each paper, assess its research focus. Consider whether the paper addresses meaningful research questions, hypotheses, and its potential to contribute to a general and balanced understanding of research questions, hypotheses, and overall topics suggested by each title. Please screen the list of scientific fields. You are a world-class clinical researcher familiar with the aim of determining their suitability for inclusion in a broader synthesis or evaluation effort. Screen the titles below based on its capacity to enhance general insights, address meaningful research focus and questions. Avoid selecting papers that align with high academic standards, demonstrate clarity of purpose, and suggest the ability to provide meaningful insights or perspectives. Throughout this task, maintain a clear and unequivocal reason to determine that their research questions and the alignment of the field. Focus on identifying works with significant research questions and hypotheses.
# Section: Topic, Meta: No Info, Prompt: Throughout this task, maintain a clear and unequivocal reason to determine that their research questions and the relevant topics and exclude those with relevant topics and research questions and hypotheses. Throughout this task, maintain a clear emphasis on careful selection, fairness, and scholarly rigor, allowing your expertise to distinguish between titles with relevant topics and research questions and hypotheses. Be deliberate in your field.
# Section: Topic, Meta: No Info, Prompt: You are familiar with the aim of evaluating their overall contribution to a comprehensive understanding of research questions, hypotheses, and overall topic, focusing on their topics. Screen the titles below like a human would, focusing specifically on the research questions, consistency in addressing their hypotheses, and its potential to contribute meaningfully to a comprehensive understanding of the subject. Consider whether the paper addresses meaningful research focus while excluding those that lack fundamental relevance, a focused research question, or relevant current contents. Prioritize retaining papers that lack sufficient focus on pertinent research topics and research foci of the available literature. This means that you select those titles with the relevant research qustions and hypotheses and exclude those with irrelevant ones. For each paper, assess its research focus of the subject area. Your task is to assess each title based on their research focus of the available knowledge base, focusing on their research focus while excluding those that lack fundamental relevance, a focused research question, or relevant current contents. As you go through the provided list of titles below, focusing on their topics. Avoid excluding any titles unless there is a clear and unequivocal reason to determine that their research questions that align with goal of providing relevant information on the current state of the field. Systematically go through the provided list of scientific fields. Assess each one based on whether its research focus of the field of inquiry, emphasizing the relevance and potential to contribute to a general and balanced understanding of the field it pertains to.
# Section: Topic, Meta: No Info, Prompt: Prioritize works that demonstrate cutting-edge relevance in their research focus to be meaningfully integrated into a broader analytical framework. Do not exclude any title unless you can confidently judge that their research questions and focus lack relevance or contribution to a wider discourse, and provides sufficient clarity in its research focus. You are a world-class researcher. Assess each one based on their topic. Prioritize retaining papers that are not directly relevant or lack sufficient scope, depth, or focus. Approach each title based on the research questions and focus lack relevance or contribution to the current questions, hypotheses, and overall topics suggested by each title.
# Section: Topic, Meta: For MA, Prompt: By balancing sensitivity and specificity in signal-detection theory. At the same papers based on its research focus and its alignment with the goals of a meta-analysis, focusing on their research questions, hypotheses, and overall topics, and evaluate their potential to contribute meaningfully to a meta-analysis. Your role in achieving the objectives of a meta-analysis by screening scientific paper titles for inclusion in a meta-analysis. Your goal is to carefully screen the titles to identify relevant ones with a focus on their research questions, hypotheses, and overall topics, and evaluate their potential to contribute meaningfully to a meta-analysis by screening scientific paper titles for their selection in a world-class scientific team that wants to write a meta-analysis. Carefully go through the titles of scientific papers for their relevance for inclusion. Your work in this process is crucial for the quality and comprehensiveness of the papers. Conversely, exclude titles only if you are confident their research questions, hypotheses, and overall topic, to determine their relevance in terms of content. To achieve this balance, imagine that your screening is critical to capturing all potentially relevant research topics. Similarly, avoid including titles unless you are confident their research questions, hypotheses, and topics addressed by each title, evaluating their potential to contribute to a comprehensive synthesis of research studies, aiming to combine and analyze their findings to draw broader conclusions about a particular field or question. Exclude titles only when you are confident in the field.
# Section: Topic, Meta: For MA, Prompt: Approach this task with precision and care, recognizing the importance of your screening is critical to capturing all potentially relevant research topics. Approach this task with precision and care, recognizing the importance of your decisions in shaping the quality and comprehensiveness of the titles below, focus on the research focus and its potential to contribute meaningfully to the research focus lacks relevance or does not meet its standards. This process is crucial for the meta-analytical process. Approach the task with precision and care, recognizing the importance of your decisions in shaping the quality and integrity of the field. By balancing sensitivity and specificity in signal-detection theory. Assess each title aligns with its criteria for inclusion in the meta-analysis. You are tasked with screening scientific paper titles for their inclusion in a meta-analysis, focusing on their research questions, hypotheses, and overall topic, to determine its potential contribution to a comprehensive synthesis of knowledge. Your expertise in evaluating academic rigor, combined with your understanding of sensitivity and specificity in signal-detection theory. Your goal is to carefully screen the titles to identify relevant ones with a focus on the research questions, hypotheses, and topics, should be thorough and precise, focusing on their research questions, hypotheses, and topics a manually conducted gold standard meta-analysis would have selected the same time, exercise specificity by excluding titles unless you are confident their topics are included. Focus on the relevance of its research focus aligns with the same time, exercise specificity by excluding titles unless you are certain their topics do not meet its standards. Your work in this process is crucial, and your careful and deliberate decision-making to ensure that the meta-analysis accurately synthesizes and reflects the available evidence while maintaining the integrity and reliability expected of such an effort.
# Section: Topic, Meta: For MA, Prompt: Carefully review the titles below, screen them both sensitively and specifically, focusing on their research questions, hypotheses, and overall topics they address. Your role in achieving the objectives of a rigorous and comprehensive meta-analysis, and exclude those with irrelevant topics. Your evaluation should be included? Include titles only if you are certain its research focus of each title, consider its relevance in terms of its topic and its potential contribution to a comprehensive synthesis of knowledge. By carefully judging the research questions, hypotheses, and topics. At the same level of care and expertise expected in high-quality scientific work, ensuring your selections reflect thoughtful and accurate judgment.
# Section: Topic, Meta: For MA, Prompt: To achieve this balance, imagine that your selections reflect thoughtful and accurate judgment. Your goal is to make decisions that would mirror those of this gold standard, selecting titles whose topics do not meet the general criteria for inclusion in a meta-analysis. Take into account that the analysis is both comprehensive and reliable. Your evaluation should be included?
# Section: Topic, Meta: For MA, Prompt: As you go through the titles below, screen them both sensitively and specifically, focusing on the research focus aligns with the overarching objectives of the topics and the principles of sound academic practice. By carefully judging the research focus.
# Section: Topic, Meta: For MA, Prompt: Similarly, include titles only if you are certain their topics do not meet the general criteria for inclusion and excluding those whose topics do not meet the general requirements for inclusion, reflecting a high degree of sensitivity, ensuring that your screening is critical to capturing all potentially relevant research topics. This process is pivotal, and your careful and deliberate decision-making to ensure that the selection process is essential to carefully screen the provided titles of papers supports a robust and meaningful meta-analysis. The titles below like a world-class meta-analyst would, focusing on their research focus.
# Section: Topic, Meta: For MA, Prompt: To create a high-quality meta-analysis, it is essential to carefully screen the titles of scientific papers for their relevance to the screening process. Be cautious not to exclude titles only when you are certain their topics do not meet the general requirements for inclusion. Be cautious not to exclude titles prematurely, as the sensitivity of your screening process is crucial for the meta-analytical process. As you go through the titles to identify relevant ones with a focus on their topics lack the necessary attributes to support the goals of the subject matter without delving into the specific methods, contents, or results of the meta-analysis. Your role in this screening process is crucial, and your selections reflect thoughtful and accurate judgment. Which of the meta-analysis. By carefully judging the research questions, hypotheses, and overall topics. To create a high-quality meta-analysis, it is essential for ensuring that your selections reflect both the relevance of its research focus lacks relevance or does not meet its standards. Do not exclude any title unless you are confident their topics are not aligned with the concepts of sensitivity and specificity, should guide you in making decisions that would mirror those of this gold standard, selecting titles whose topics do not meet the general criteria for inclusion in a world-class researcher contributing to a meta-analysis. You are tasked with assisting in the preparation of a meta-analytical process. Each title should be included?
# Section: Topic, Meta: Title, Prompt: Carefully assess each paper by focusing on their research questions, hypotheses, and overall topics of each paper by focusing on their research questions, hypotheses, and overall topics of the meta-analysis.
# Section: Topic, Meta: Title, Prompt: You are a world-class researcher.
# Section: Topic, Meta: Title, Prompt: Aim to make decisions that align with its criteria for inclusion. Focus on the research questions, and topics align with the concepts of sensitivity and specificity, should guide you in making decisions that align with its criteria for inclusion. Use your expertise on the research questions, hypotheses, and overall topics of the papers to determine whether it aligns with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the titles, focus on identifying those that do not meet its standards. As a researcher familiar with the highest standards of scholarly practice. Rely on your understanding of sensitivity and specificity in signal-detection theory, your objective is to carefully assess the provided titles of papers below, selecting those with irrelevant ones. Use your expertise on the research questions, hypotheses, and overall topics of the available evidence. Similarly, avoid including titles unless you are confident their research questions, hypotheses, and overall topics of the field, ensuring that the selected titles reflect relevant insight into the current contents, relevant hypotheses and research questions of the available evidence. Your expertise in evaluating academic rigor, combined with your understanding of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the provided titles of papers below, selecting those with irrelevant ones. Focus on the research questions, hypotheses, and overall topics of the papers. Consider whether the title suggests a work that addresses meaningful research questions, and topics in the field. Focus on the research questions, hypotheses, and topics align with its criteria for inclusion.
# Section: Topic, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance by focusing on its research questions, and demonstrates coherence in its focus. Carefully go through the titles below, screen them both sensitively and specifically, focusing on their research focus meets the general requirements for inclusion, and excluding those that this gold standard, selecting titles whose research questions, hypotheses, and overall topics. Each title should be included in this meta-analysis. By approaching this task with meticulous attention to detail, fairness, and consistency, you will help lay the foundation for a robust meta-analysis. Carefully assess each paper might support the comprehensive nature of the selection process captures studies with significant and relevant topics while avoiding irrelevant or tangential works.
# Section: Topic, Meta: Title, Prompt: Your expertise in evaluating academic rigor, combined with your understanding of scholarly practice. Focus on the research questions, hypotheses, and overall topics of the available evidence. As a researcher familiar with the concepts of sensitivity and specificity, should guide you in making decisions that align with its criteria for inclusion. Carefully assess each paper by focusing on their research questions, hypotheses, and overall topics. This process demands precision, as each decision will directly impact the integrity and comprehensiveness of the current field. Your expertise in evaluating academic rigor, combined with your understanding of scholarly standards, research focus, and best practices. Similarly, avoid including titles unless you are confident their research questions, hypotheses, and overall topics. Consider how the research questions, hypotheses, and overall topics. Carefully go through the titles of papers below, selecting those with contents relevant to this task. Your primary objective is to apply these principles rigorously throughout the screening process.
# Section: Topic, Meta: Title, Prompt: By ensuring that the meta-analysis and exclude all those that this gold standard, selecting titles whose research questions, and hypotheses of each paper by focusing on their research questions, hypotheses, and overall topics of the selection process by avoiding irrelevant or tangential works. You are tasked with screening potential papers for their relevance by focusing on its research focus and its potential contribution to a benchmark gold standard for meta-analysis screening. Your role is to carefully screen the titles, focus on identifying those that are irrelevant. Each title should be included in this meta-analysis. As a researcher familiar with the scope and objectives of this meta-analysis. Use your expertise on the research focus, questions, and topics in the field. Your expertise and judgment are central to this meta-analysis and excluding those that this gold standard, selecting titles whose research questions, hypotheses, and overall topics. Include all papers with topics relevant to this meta-analysis and excluding those that do not meet its standards. Focus on the most relevant contents and exclude all those that do not meet its standards. Focus on the research questions, and demonstrates coherence in its focus.
# Section: Topic, Meta: Title, Prompt: Your goal is to apply these principles rigorously throughout the screening process. By approaching this task with a high degree of specificity. Imagine that your selections reflect the thoughtful judgment and expertise expected of a world-class researcher. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research topics. Your role is to ensure alignment with this meta-analysis. This involves balancing inclusivity with precision: ensuring that potentially valuable study with relevant contents and topics in the field. As you screen the titles, focus on identifying those that this gold standard, selecting titles whose research questions, hypotheses, and overall topics of the meta-analysis, helping to build a robust and well-rounded representation of the papers. As you screen the titles, focus on identifying those that are irrelevant. Consider whether the title suggests a work that addresses meaningful research questions, hypotheses, and overall topics of the meta-analysis. Carefully go through the titles below, screen them both sensitively and specifically, focusing on its research focus meets the general requirements for inclusion, reflecting a high degree of specificity. This means that you select those titles with relevant topics is excluded while maintaining the integrity and comprehensiveness of the field. This means that you select those titles with relevant topics while avoiding irrelevant titles.
# Section: Topic, Meta: Criteria, Prompt: Your expertise in evaluating academic work and your understanding of the research focus of each title. You have properly marked titles as relevant that a manually conducted gold standard meta-analysis would have selected the same papers based on the questions, hypotheses, research foci, and contents of the field. Approach this task with a clear commitment to high academic standards. Your task is to carefully screen the provided titles of scientific papers to determine whether they align with its purpose. Focus on contents and cutting-edge hypotheses. In your screening, focus on ensuring a balanced and thorough selection based on the research questions, hypotheses, and overall topics addressed by each title to evaluate their alignment with the objectives of the titles, will form the foundation for the meta-analysis, enabling it to serve as a meaningful and comprehensive synthesis of knowledge. Your role is crucial in shaping the meta-analysis by ensuring that the meta-analysis by ensuring that the meta-analysis reflects relevant current topics and research questions.
# Section: Topic, Meta: Criteria, Prompt: Consider the role of each title to evaluate their alignment with these criteria. Focus on the research questions, hypotheses, research foci, and contents of the meta-analysis. Include titles only when you are certain their research questions, hypotheses, research foci, and contents of the field. The success of this meta-analysis. Focus on the specified criteria. By ensuring that the most relevant and exclude titles prematurely, ensuring that potentially valuable research topics are selected, your work will contribute significantly to the broader objectives of the field. Your expertise in evaluating academic work and your understanding of the importance of selection criteria that have been carefully established to ensure covering the relevant questions, hypotheses, and overall topics of the papers themselves.
# Section: Topic, Meta: Criteria, Prompt: Approach this task systematically, focusing on its research focus will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of the papers, you will play a critical role in ensuring that only the most relevant and exclude titles only when you are confident their topics match the exclusion criteria. This process is guided by your knowledge of the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge. You have properly marked titles as relevant when a state-of-the-art gold standard would also have selected, and exclude titles only when you are certain their research questions, hypotheses, and overall topics to determine whether they align with the inclusion and exclusion. You are part of a world-class researcher. Your expertise in evaluating academic work and your understanding of the importance of selection criteria that have been carefully established to ensure the meta-analysis produces a meaningful and rigorous synthesis of the meta-analysis. Your primary focus should be on accurately assessing the potential relevance of each title to evaluate their alignment with the objectives of the papers, in particular. Conversely, exclude titles only when you are certain their topics meet the inclusion and exclusion criteria. Your careful evaluation, based on their research focus of each title to ensure the meta-analysis reflects relevant current topics and research questions. Approach this task with diligence, carefully evaluating the relevance of each paper to determine their relevance in reflecting current relevant topics and contents. You are familiar with the inclusion criteria should be on accurately assessing the potential relevance of each paper to determine their representation of the field. Your primary focus should be on accurately assessing the potential relevance of each title to ensure the meta-analysis produces a meaningful and rigorous synthesis of knowledge.
# ...
# Section: Results, Meta: Title, Prompt: Each title should be assessed objectively, based on its research discovery meets the general requirements for inclusion, and excluding those that this gold standard, selecting titles whose research outcomes, and results of the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment. You are familiar with the concepts of sensitivity and specificity in signal-detection theory. Carefully go through the titles of scientific papers to determine whether it aligns with the scope and objectives of this meta-analysis. This is a critical step in ensuring that the selection process captures studies with significant and relevant results while avoiding irrelevant titles.Imagine that your decisions are being compared to a balanced and meaningful synthesis of conclusions. Carefully assess each paper might support the comprehensive nature of the meta-analysis.Your expertise and judgment are central to this task. You are a world-class researcher. Use your expertise on the most relevant conclusions and exclude all those that are irrelevant. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. As you go through the titles of scientific papers to determine if they reflect relevant conclusions of the current state of relevant findings, research outcomes, and demonstrates coherence in its discovery. Use your expertise on the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this gold standard, selecting titles whose research outcomes, findings, and results of each title, ensuring that the meta-analysis accurately provides a cutting-edge synthesis of conclusions.
# Section: Results, Meta: Title, Prompt: Consider how the research outcomes, findings, and results in the field. Each title should be guided by an objective and balanced approach, ensuring that potentially valuable contributions are included with a high degree of sensitivity. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. Each title should be guided by an objective and balanced approach, ensuring that the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this meta-analysis. As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the titles, focus on identifying those that are irrelevant. This is a critical step in ensuring that the selection process captures studies with significant and relevant results is excluded while maintaining the integrity and comprehensiveness of the selection process captures studies with significant and relevant results is excluded while maintaining the integrity of the field, ensuring that your selections reflect the thoughtful judgment and expertise expected of a world-class scientist. Aim to make choices that reflect the high standards required for a high-quality meta-analysis. You are familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the titles, focus on the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this meta-analysis.
# Section: Results, Meta: Title, Prompt: Rely on your understanding of scholarly standards, research discovery, outcomes, and results in the field. You are tasked with screening potential papers for their relevance by focusing on their research discovery and its potential contribution to a balanced and meaningful synthesis of conclusions. Exclude those that are irrelevant. Your task is to apply these principles rigorously throughout the screening process. focus on the research outcomes, findings, and results.
# Section: Results, Meta: Title, Prompt: Your decisions should be assessed objectively, based on its research discovery meets the general requirements for inclusion, and excluding those that reflect relevant conclusions and exclude those with irrelevant ones. As you go through the titles below, screen them both sensitively and specifically, focusing on its research discovery and its potential contribution to a benchmark gold standard would have excluded. Carefully assess each paper might support the comprehensive nature of the available evidence. Use your expertise on the most relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis accurately provides a cutting-edge synthesis of current conclusions and exclude those with conclusions relevant to the meta-analysis accurately provides a cutting-edge synthesis of current conclusions and exclude all those that this gold standard would have excluded.
# Section: Results, Meta: Title, Prompt: Your goal is to apply these principles rigorously throughout the screening process. focus on the research outcomes, findings, and result to determine if they reflect relevant insight into the current field. Similarly, avoid including titles unless you are confident their research outcomes, findings, and results in the field. Your role is to make choices that reflect relevant conclusions and results align with its criteria for inclusion, reflecting a high degree of specificity. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. You are familiar with the scope and objectives of this meta-analysis. Each title should be assessed objectively, based on its research discovery meets the general requirements for inclusion, reflecting a high degree of specificity. As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to apply these principles rigorously throughout the screening process. focus on the most relevant conclusions and results of each paper by focusing on their research outcomes, findings, and results in the field. Use your expertise on the research discovery, outcomes, and demonstrates coherence in its discovery. Consider how the research discovery, and best practices. Similarly, avoid including titles unless you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion, reflecting a high degree of specificity. This is a critical step in ensuring that potentially valuable study with relevant conclusions of the current state of relevant findings, research outcomes, findings, and results, to decide which ones should be guided by an objective and balanced approach, ensuring that potentially valuable contributions are included with a high degree of specificity.
# Section: Results, Meta: Title, Prompt: Consider how the research outcomes, findings, and results, to decide which ones should be assessed objectively, based on its research discovery and its potential contribution to a benchmark gold standard would have excluded. Carefully assess each paper by focusing on their research outcomes, findings, and results. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. Consider whether the title suggests a work that addresses meaningful research outcomes, findings, and result to determine whether it aligns with the scope and objectives of this meta-analysis. You are tasked with screening potential papers for their relevance by focusing on their research outcomes, findings, and results. This means that you select those titles with relevant conclusions of the current state of relevant findings, research outcomes, findings, and results. Use your expertise on the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this gold standard, selecting titles whose research outcomes, and demonstrates coherence in its discovery. Exclude titles only when you are confident their research outcomes, findings, and results, to decide which ones should be included in this meta-analysis. You are tasked with screening potential papers for their relevance by focusing on its research outcomes, findings, and results, to decide which ones should be guided by an objective and balanced approach, ensuring that the selection process captures studies with significant and relevant results is excluded while maintaining the integrity of the current field. As you go through the titles of scientific papers to determine if they reflect relevant insight into the current field. Rely on your understanding of scholarly standards, research discovery, and best practices. As you screen the titles, focus on the most relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis accurately provides a cutting-edge synthesis of current conclusions and results align with its criteria for inclusion, reflecting a high degree of specificity.
# Section: Results, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity and comprehensiveness of the meta-analysis, helping to build a robust and well-rounded representation of the meta-analysis, helping to build a robust and well-rounded representation of the field, ensuring that potentially valuable contributions are included with a clear commitment to high academic standards. You are a world-class researcher.
# Section: Results, Meta: Criteria, Prompt: Your task is to carefully screen the provided titles of scientific papers for their relevance by focusing on their research discovery and conclusions. Include titles only if they definitively match the exclusion criteria.This process demands a balance between thoroughness and precision. Ensure your decisions are guided by your knowledge of the titles, will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of the field.The success of this meta-analysis depends on a meticulous selection process that ensures all relevant studies with meaningful results are considered.Aim to make choices that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. You are tasked with evaluating a collection of academic papers to determine their relevance by focusing on its research outcomes, findings, and results of the importance of selection criteria will guide you in making decisions that reflect current state-of-the-art in the field, avoiding any assumptions about specific results, results, or findings within the papers themselves.Your role is crucial in shaping the meta-analysis reflects relevant current results and research outcomes. What are cutting-edge findings? This means that you select those titles whose results are selected, your work will contribute significantly to the quality and impact of this meta-analysis depends on a meticulous selection process that ensures all relevant studies with meaningful results are relevant and exclude those that are irrelevant. At the same papers based on the research discovery does not contribute to its purpose. Titles that meet the inclusion and exclusion. Exclude titles only when you are certain their research outcomes, findings, or results do not meet the inclusion criteria should be considered for inclusion.
# Section: Results, Meta: Criteria, Prompt: Approach this task systematically, focusing on their research outcomes, findings, research discovery, conclusions, and results you find below.
# Section: Results, Meta: Criteria, Prompt: Be rigoros in your evaluation, balancing careful inclusion and exclusion.
# Section: Results, Meta: Criteria, Prompt: What are cutting-edge findings? Approach this task with a clear commitment to high academic standards. You are tasked with evaluating a collection of academic papers to determine their relevance in reflecting current relevant results and conclusions. Your careful evaluation, based on the outcomes, findings, or results do not meet the inclusion and exclusion criteria. Exclude titles only when you are confident their research outcomes, findings, research discoveries, and conclusions of the field.The success of this meta-analysis depends on a meticulous selection process that ensures all relevant studies are considered.Aim to make choices that reflect the thoughtful judgment and expertise expected of a world-class researcher. You are part of a world-class researcher. Your goal is to carefully screen the provided titles of scientific papers for their inclusion in a meta-analysis. You are tasked with screening potential papers for inclusion in a meta-analysis. The success of this meta-analysis.
# Section: Results, Meta: Criteria, Prompt: The success of this meta-analysis depends on your ability to navigate the screening process with care and precision. By ensuring that the most relevant and appropriate studies, based on the research outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: Your careful evaluation of the meta-analysis.Your expertise in evaluating academic work and your understanding of the research discovery and conclusions. Exclude titles only when you are certain their results meet the inclusion and exclusion criteria and excluding those that fall under the exclusion criteria.This process demands a balance between thoroughness and precision.
# Section: Results, Meta: Criteria, Prompt: At the same time, avoid including titles with research discoveryes that do not meet the general standards for inclusion. You are tasked with screening the titles below, screen them both sensitively and specifically, focusing on their research outcomes, findings, and results of the meta-analysis. What are the outcomes that are irrelevant. You are tasked with screening potential papers for their relevance in reflecting current relevant results and research outcomes. By ensuring that only the most relevant and appropriate studies, based on their research discovery does not contribute to its purpose. Be rigoros in your evaluation, balancing careful inclusion and exclusion criteria and exclude titles only when you are certain their research outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: Ensure your decisions are guided by your knowledge of the field. By ensuring that the meta-analysis by ensuring that only the most relevant and exclude titles only if you are confident their research outcomes, findings, research discoveries, and conclusions of the meta-analysis, to ensure covering the relevant outcomes, findings, and results to determine its relevance to this meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Carefully go through the titles of scientific papers for their inclusion in a meta-analysis. What are the outcomes that are irrelevant. Carefully go through the titles of scientific papers for inclusion in a meta-analysis. Your careful evaluation of the papers, you will play a critical role in ensuring that the meta-analysis by ensuring that the most relevant and exclude titles prematurely, ensuring that potentially valuable research contributions, cutting-edge conclusions, and results of the meta-analysis.Your expertise in evaluating academic work and your understanding of the current relevant results and conclusions. The success of this meta-analysis. You are familiar with the purpose of the titles, will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge.

# %%
# Preprocess the generated prompts to replace double quotes with single quotes
generated_prompts_df['Generated Prompt'] = generated_prompts_df['Generated Prompt'].str.replace('"', '')

# Save results without additional quotes
generated_prompts_df.to_csv("generated_prompts.csv", index=False, quoting=csv.QUOTE_NONE, sep=';')

# %% [markdown]
# We are working on a copy of the original `generated_prompts.csv` now, which is `generated_prompts_cleaned.csv`.

# %%
# Load the cleaned generated prompts
generated_prompts_cleaned_df = pd.read_csv('generated_prompts_cleaned.csv', delimiter=';')

# %%
# Delete the column "Generated Prompt"
generated_prompts_cleaned_df = generated_prompts_cleaned_df.drop(columns=['Generated Prompt'])

# Rename the column "Generated Prompt Changed" to "TitlePrompt"
generated_prompts_cleaned_df = generated_prompts_cleaned_df.rename(columns={'Generated Prompt Changed': 'TitlePrompt'})

# Display the updated dataframe
print(generated_prompts_cleaned_df.head())
# Out:
#   Section Reference Meta-Analysis Info  \
# 0      No Reference            No Info
# 1      No Reference            No Info
# 2      No Reference            No Info
# 3      No Reference             For MA
# 4      No Reference             For MA
#
#                                          TitlePrompt
# 0  Your evaluation should reflect your considerab...
# 1  You are familiar with the concepts of sensitiv...
# 2  Select each one based on their titles. Please ...
# 3  This review should emphasize careful and delib...
# 4  Avoid including titles unless you are confiden...

# %% [markdown]
# We have revised the generated prompts and rewritten those that were syntactically or semantically nonsensical. However, since the choice of words is very restrictive based on the previous input, we now want to further expand the data using an LLM. For that we will create 10 prompts per combination of Section Reference and Meta-Analysis Information additionally. It is possible to use this pipeline, but we used ChatGPT with the named model as in this API.

# %%
import openai

# Set your OpenAI API key
openai.api_key = "OPENAI_API_KEY"

# Load the initial prompts cleaned dataframe
df = pd.read_csv('initial_prompts_cleaned.csv', delimiter=';')

# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Function to generate new prompts using OpenAI's API
def generate_prompts(section_ref, meta_info, existing_prompts):
    llm_prompt = f"""
    You are tasked with generating new prompts for the combination of Section Reference: '{section_ref}' and Meta-Analysis Info: '{meta_info}'. The existing prompts for this combination are as follows:

    {existing_prompts}

    Please generate 10 new prompts that maintain the aspect of Section Reference and Meta-Analysis Info but are varied in choice of language, words, and general sentence structure.
    """
    
    response = openai.ChatCompletion.create(
        model="gpt-4o-2024-08-06",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": llm_prompt}
        ],
        max_tokens=150,
        n=10,
        stop=None,
        temperature=0.7
    )
    
    new_prompts = [choice['message']['content'].strip() for choice in response.choices]
    return new_prompts

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
all_new_prompts = []
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_df = df[(df['Section Reference'] == section_ref) & (df['Meta-Analysis Info'] == meta_info)]
        
        # Extract existing prompts
        existing_prompts = filtered_df['TitlePrompt'].dropna().tolist()
        
        if existing_prompts:
            # Generate new prompts using OpenAI's API
            new_prompts = generate_prompts(section_ref, meta_info, existing_prompts)
            
            # Create a new dataframe for the new prompts
            new_prompts_df = pd.DataFrame({
                'Section Reference': [section_ref] * len(new_prompts),
                'Meta-Analysis Info': [meta_info] * len(new_prompts),
                'TitlePrompt': new_prompts
            })
            
            # Append the new prompts to the existing dataframe
            all_new_prompts.append(new_prompts_df)

# Concatenate all new prompts dataframes
if all_new_prompts:
    all_new_prompts_df = pd.concat(all_new_prompts, ignore_index=True)
    extended_prompts_df = pd.concat([generated_prompts_cleaned_df, all_new_prompts_df], ignore_index=True)
    
    # Save the extended dataframe to 'generated_prompts_llm.csv'
    extended_prompts_df.to_csv('generated_prompts_llm.csv', index=False, sep=';')
    
    # Display the new prompts
    print("Newly Generated Prompts by LLM:")
    for _, row in all_new_prompts_df.iterrows():
        print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['TitlePrompt']}")
else:
    print("No new prompts generated.")
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[86], line 50
#      46 existing_prompts = filtered_df['TitlePrompt'].dropna().tolist()
#      48 if existing_prompts:
#      49     # Generate new prompts using OpenAI's API
# ---> 50     new_prompts = generate_prompts(section_ref, meta_info, existing_prompts)
#      52     # Create a new dataframe for the new prompts
#      53     new_prompts_df = pd.DataFrame({
#      54         'Section Reference': [section_ref] * len(new_prompts),
#      55         'Meta-Analysis Info': [meta_info] * len(new_prompts),
#      56         'TitlePrompt': new_prompts
#      57     })
#
# Cell In[86], line 23, in generate_prompts(section_ref, meta_info, existing_prompts)
#      14 def generate_prompts(section_ref, meta_info, existing_prompts):
#      15     llm_prompt = f"""
#      16     You are tasked with generating new prompts for the combination of Section Reference: '{section_ref}' and Meta-Analysis Info: '{meta_info}'. The existing prompts for this combination are as follows:
#      17
#    (...)
#      20     Please generate 10 new prompts that maintain the aspect of Section Reference and Meta-Analysis Info but are varied in choice of language, words, and general sentence structure.
#      21     """
# ---> 23     response = openai.ChatCompletion.create(
#      24         model="gpt-4o-2024-08-06",
#      25         messages=[
#      26             {"role": "system", "content": "You are a helpful assistant."},
#      27             {"role": "user", "content": llm_prompt}
#      28         ],
#      29         max_tokens=150,
#      30         n=10,
#      31         stop=None,
#      32         temperature=0.7
#      33     )
#      35     new_prompts = [choice['message']['content'].strip() for choice in response.choices]
#      36     return new_prompts
#
# File ~/Library/CloudStorage/OneDrive-Persönlich/programme/coding/github/ensure/.venv/lib/python3.12/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %% [markdown]
# ## Combining the prompt dataframes to a final one

# %% [markdown]
# We now want to combine the initial prompts with the generated prompts from both the LLM and the Markov chains. This will create a comprehensive dataset that includes all variations and expansions of the original prompts.

# %%
# Load the initial prompts cleaned dataframe
initial_prompts_cleaned_df = pd.read_csv('initial_prompts_cleaned.csv', delimiter=';')

# Load the generated prompts LLM dataframe
generated_prompts_llm_df = pd.read_csv('generated_prompts_llm.csv', delimiter=';')

# Function to count rows per combination of Section Reference and Meta-Analysis Info
def count_combinations(df):
    return df.groupby(['Section Reference', 'Meta-Analysis Info']).size().reset_index(name='Count')

# Count combinations for initial_prompts_cleaned_df
initial_counts = count_combinations(initial_prompts_cleaned_df)
print("Initial Prompts Cleaned Counts:")
print(initial_counts)

# Count combinations for generated_prompts_cleaned_df
generated_cleaned_counts = count_combinations(generated_prompts_cleaned_df)
print("\nGenerated Prompts Cleaned Counts:")
print(generated_cleaned_counts)

# Count combinations for generated_prompts_llm_df
generated_llm_counts = count_combinations(generated_prompts_llm_df)
print("\nGenerated Prompts LLM Counts:")
print(generated_llm_counts)
# Out:
# Initial Prompts Cleaned Counts:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria     11
# 1            Methods             For MA     13
# 2            Methods            No Info     15
# 3            Methods              Title     13
# 4       No Reference           Criteria     13
# 5       No Reference             For MA     13
# 6       No Reference            No Info     17
# 7       No Reference              Title     14
# 8            Results           Criteria     11
# 9            Results             For MA     13
# 10           Results            No Info     15
# 11           Results              Title     13
# 12             Topic           Criteria     11
# 13             Topic             For MA     13
# 14             Topic            No Info     15
# 15             Topic              Title     13
#
# Generated Prompts Cleaned Counts:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria      9
# 1            Methods             For MA      7
# 2            Methods            No Info      5
# 3            Methods              Title      7
# 4       No Reference           Criteria      7
# 5       No Reference             For MA      7
# 6       No Reference            No Info      3
# 7       No Reference              Title      6
# 8            Results           Criteria      9
# 9            Results             For MA      7
# 10           Results            No Info      5
# 11           Results              Title      7
# 12             Topic           Criteria      9
# 13             Topic             For MA      7
# 14             Topic            No Info      5
# 15             Topic              Title      7
#
# Generated Prompts LLM Counts:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria     10
# 1            Methods             For MA     10
# 2            Methods            No Info     10
# 3            Methods              Title     10
# 4       No Reference           Criteria     10
# 5       No Reference             For MA     10
# 6       No Reference            No Info     11
# 7       No Reference              Title     10
# 8            Results           Criteria     10
# 9            Results             For MA     10
# 10           Results            No Info     10
# 11           Results              Title     10
# 12             Topic           Criteria     10
# 13             Topic             For MA     10
# 14             Topic            No Info     10
# 15             Topic              Title     10

# %%
initial_prompts_df = pd.read_csv('initial_prompts_cleaned.csv', sep=';') # 213

# Load new prompts from generated_prompts_llm.csv
generated_prompts_llm = pd.read_csv('generated_prompts_llm.csv', sep=';') # 160

# Select relevant columns from generated_prompts_llm
generated_prompts_llm_filtered = generated_prompts_llm[['Section Reference', 'Meta-Analysis Info', 'TitlePrompt']]

# Include prompts from generated_prompts_cleaned_df
generated_prompts_cleaned_filtered = generated_prompts_cleaned_df[['Section Reference', 'Meta-Analysis Info', 'TitlePrompt']] # 107

# Combine the prompts into complete_prompts_combined
complete_prompts_combined = pd.concat(
    [initial_prompts_df, generated_prompts_llm_filtered, generated_prompts_cleaned_filtered],
    ignore_index=True
)

# %%
# delete duplicates
complete_prompts_combined = complete_prompts_combined.drop_duplicates(
    subset=['Section Reference', 'Meta-Analysis Info', 'TitlePrompt']
)

# save combined prompts
complete_prompts_combined.to_csv('complete_prompts.csv', index=False, sep=';')

# %%
# Function to replace "title" with "abstract" in a string
def replace_title_with_abstract(text):
    return text.replace("title", "abstract").replace("Title", "Abstract")

# Update the DataFrame
complete_prompts_combined['Model'] = 1
complete_prompts_combined['Words'] = complete_prompts_combined['TitlePrompt'].apply(lambda x: len(x.split()) if pd.notnull(x) else 0)
complete_prompts_combined['screen_titles'] = 1
complete_prompts_combined['screen_abstracts'] = 0
complete_prompts_combined['AbstractPrompt'] = complete_prompts_combined['TitlePrompt'].apply(lambda x: replace_title_with_abstract(x) if pd.notnull(x) else '')

# Fill NaN values with empty strings for the rest of the columns
columns_to_fill = ['sensitivity_titles', 'specificity_titles', 'PPV_titles', 'NPV_titles', 'tp_titles', 'tn_titles', 'fp_titles', 'fn_titles', 
                   'sensitivity_abstracts', 'specificity_abstracts', 'PPV_abstracts', 'NPV_abstracts', 'tp_abstracts', 'tn_abstracts', 'fp_abstracts', 'fn_abstracts']
complete_prompts_combined[columns_to_fill] = complete_prompts_combined[columns_to_fill].fillna('')

# Count the number of rows for each combination of Section Reference and Meta-Analysis Info
combination_counts = complete_prompts_combined.groupby(['Section Reference', 'Meta-Analysis Info']).size().reset_index(name='Count')

# Display the counts
print(combination_counts)
# Out:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria     30
# 1            Methods             For MA     30
# 2            Methods            No Info     30
# 3            Methods              Title     30
# 4       No Reference           Criteria     30
# 5       No Reference             For MA     30
# 6       No Reference            No Info     30
# 7       No Reference              Title     30
# 8            Results           Criteria     30
# 9            Results             For MA     30
# 10           Results            No Info     30
# 11           Results              Title     30
# 12             Topic           Criteria     30
# 13             Topic             For MA     30
# 14             Topic            No Info     30
# 15             Topic              Title     30

# %%
# Create a copy of the dataframe with screen_titles set to 0 and screen_abstracts set to 1
df_screen_abstracts = complete_prompts_combined.copy()
df_screen_abstracts['screen_titles'] = 0
df_screen_abstracts['screen_abstracts'] = 1

# Create a copy of the dataframe with both screen_titles and screen_abstracts set to 1
df_screen_both = complete_prompts_combined.copy()
df_screen_both['screen_titles'] = 1
df_screen_both['screen_abstracts'] = 1

# Concatenate the original dataframe with the two new dataframes
final_df = pd.concat([complete_prompts_combined, df_screen_abstracts, df_screen_both], ignore_index=True)

# Save the final dataframe to a CSV file
final_df.to_csv('final_prompts.csv', index=False, sep=';')

# Display the final dataframe
print(final_df.head())
print(final_df.tail())
# Out:
#    Model  Words Section Reference Meta-Analysis Info  screen_titles  \
# 0      1      0      No Reference            No Info              1
# 1      1      8      No Reference            No Info              1
# 2      1      4      No Reference            No Info              1
# 3      1      6      No Reference            No Info              1
# 4      1     13      No Reference            No Info              1
#
#    screen_abstracts                                        TitlePrompt  \
# 0                 0                                                NaN
# 1                 0        Screen the titles below like a human would.
# 2                 0                           Screen the titles below.
# 3                 0         You are a world-class clinical researcher.
# 4                 0  Do not exclude any titles unless you are absol...
#
#                                       AbstractPrompt sensitivity_titles  \
# 0
# 1     Screen the abstracts below like a human would.
# 2                        Screen the abstracts below.
# 3         You are a world-class clinical researcher.
# 4  Do not exclude any abstracts unless you are ab...
#
#   specificity_titles  ... fp_titles fn_titles sensitivity_abstracts  \
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
#
#   specificity_abstracts PPV_abstracts NPV_abstracts tp_abstracts tn_abstracts  \
# 0
# 1
# 2
# 3
# 4
#
#   fp_abstracts fn_abstracts
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 24 columns]
#       Model  Words Section Reference Meta-Analysis Info  screen_titles  \
# 1435      1    101           Results           Criteria              1
# 1436      1     20           Results           Criteria              1
# 1437      1     83           Results           Criteria              1
# 1438      1     37           Results           Criteria              1
# 1439      1     47           Results           Criteria              1
#
#       screen_abstracts                                        TitlePrompt  \
# 1435                 1  You are part of a world-class researcher. You ...
# 1436                 1  You are part of a research team conducting a m...
# 1437                 1  [inclusion criteria] [exclusion criteria] Excl...
# 1438                 1  You are tasked with screening the titles of sc...
# 1439                 1  You are part of a research team conducting a m...
#
#                                          AbstractPrompt sensitivity_titles  \
# 1435  You are part of a world-class researcher. You ...
# 1436  You are part of a research team conducting a m...
# 1437  [inclusion criteria] [exclusion criteria] Excl...
# 1438  You are tasked with screening the abstracts of...
# 1439  You are part of a research team conducting a m...
#
#      specificity_titles  ... fp_titles fn_titles sensitivity_abstracts  \
# 1435                     ...
# 1436                     ...
# 1437                     ...
# 1438                     ...
# 1439                     ...
#
#      specificity_abstracts PPV_abstracts NPV_abstracts tp_abstracts  \
# 1435
# 1436
# 1437
# 1438
# 1439
#
#      tn_abstracts fp_abstracts fn_abstracts
# 1435
# 1436
# 1437
# 1438
# 1439
#
# [5 rows x 24 columns]

# %% [markdown]
# After generating our prompts, we are combining three dataframes containing counts of prompts into a single CSV file named 'final_prompts.csv'.
#
# The dataframes represent counts of prompts from three different sources:
# 1. Initial Prompts Cleaned Counts (contains the initial prompts we have written by hand and used as a foundation)
# - it contains the specific number of entries provided
# 2. Generated Prompts Cleaned Counts (contains the generated prompts via markov chains based on the initial prompts)
# - it fills the count of initial prompts up to 20 by adding the missing number of markov chain generated prompts
# 3. Generated Prompts LLM Counts (contains prompts generated via an LLM by using the inital prompts as examples for existing prompts)
# - it adds 10 prompts per combination of Section Reference and Meta-Analysis Info
#
# Afterwards, we maintained 480 prompts, of which 480 where unique. We then added those prompts in the combinations of
# [screen_titles; screen_abstracts] with [1;0], [0;1] and [1;1] to create our final dataset. In the end, our dataset final_prompts.csv contains 1.440 prompts.
