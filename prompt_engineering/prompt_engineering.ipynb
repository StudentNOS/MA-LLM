# %% [markdown]
# # Generating Diverse Prompts for Section References and Meta-Analysis Info Combinations
#
# ## Overview
#
# This file aims to create a set of diverse and varied prompts for each combination of *Section Reference* and *Meta-Analysis Info* categories. The primary goal is to extend and enrich the initial set of prompts by varying their language structure by alternating the syntax and choice of words by alternating semantics, ensuring the outputs are sufficiently different while maintaining their original intent.
#
# By doing so, we aim to generate up to as many prompts to receive 20 unique prompts per combination, suitable for further use in classification, training, or testing scenarios. This variation enhances the linguistic richness and diversity of the dataset, ensuring broader applicability and adaptability. Afterwards, we are going to extend them by 10 prompts received by a large language model.
#
# ## Methodology
#
# To achieve the goal, the following approach is taken:
# 1.	Input Dataset:
# - The dataset contains prompts categorized by *Section Reference* (e.g., “No Reference,” “Topic,” “Methods,” “Results”) and *Meta-Analysis Info* (e.g., “No Info,” “For MA,” “Title,” “Criteria”).
# - Each prompt is associated with a specific combination of these two dimensions.
# 2.	Prompt Expansion Using Markov Chains:
# - The markovify package is used to simulate new prompts by leveraging Markov chains.
# - All prompts belonging to a specific combination of categories are used as input to a Markov model, which generates new prompts based on observed patterns in the input data.
# - This allows for the creation of prompts that retain the style and structure of the originals while introducing variation.
# 3.	Ensuring Uniqueness and Quality:
# - The generated prompts are checked against the existing prompts to ensure no duplicates are added.
# - Prompts are also filtered for redundancy within the same generation cycle.
# - If a generated prompt doesn’t meet the criteria (e.g., it is too similar to the originals or doesn’t make sense), the model generates additional prompts to compensate.
# 4.	Final Validation of Markov Chain Model:
# - Prompts are formatted uniformly to maintain a consistent presentation.
# - Outputs are reviewed, and necessary adjustments are made to improve clarity, variation, and alignment with the intended meaning. If needed, the cycle is run again go receive the missing prompts
# 5. Extension of Prompts by LLM
# - Utilizing a pre-trained LLM to generate 10 additional prompts for each combination of *Section Reference* and *Meta-Analysis Info*.
# - Ensure that these new prompts align with the existing structure and intent of the original prompts.
# 6. Final Dataset
# - Combine all prompts into a final dataset, ensuring each combination of categories has a comprehensive set of prompts.
# - This final dataset will be used for further classification, training, or testing scenarios, providing a robust and diverse set of prompts for various applications.
#
# ## Why This Approach?
#
# Using Markov chains enables the generation of syntactically coherent variations based on existing data. This method ensures:
# - Efficiency: Quickly generates multiple variations without requiring manual input for each prompt.
# - Diversity: Captures different sentence structures and word choices while retaining the essence of the original prompts.
# - Scalability: Handles multiple combinations of categories, making it suitable for large datasets.
#
# ## Enhancing Markov Chain Models with LLMs
#
# While Markov chains are effective in generating syntactically coherent variations based on existing data, they have limitations in capturing the deeper semantic relationships and contextual nuances present in natural language. Markov chains rely on the probability of word sequences, which can lead to repetitive and sometimes nonsensical outputs, especially when the input data is limited or lacks diversity. To address these limitations, we incorporate Large Language Models (LLMs) into our prompt generation process. LLMs, such as GPT-3, are pre-trained on vast amounts of text data and are capable of understanding and generating human-like text with a high degree of coherence and relevance. By leveraging LLMs, we can:
# - Enhance Diversity: LLMs can generate a wider range of prompts with varied sentence structures and vocabulary, reducing the risk of repetitive outputs that are common with Markov chains.
# - Improve Contextual Understanding: LLMs have a better grasp of context and can produce prompts that are more aligned with the intended meaning and purpose, ensuring higher quality and relevance.
# - Increase Semantic Richness: By incorporating LLMs, we can generate prompts that capture deeper semantic relationships, making the outputs more meaningful and useful for downstream tasks.
# - Maintain Coherence: LLMs can generate longer and more complex prompts while maintaining coherence, which is challenging for Markov chains that operate on fixed state sizes.
#
# By combining the strengths of Markov chains and LLMs, we achieve a robust and diverse set of prompts that are both syntactically and semantically rich, enhancing the overall quality and applicability of the generated dataset. By the end of this process, we will have a rich, diverse, and meaningful set of prompts that are ready for deployment in various applications.

# %%
import pandas as pd
import markovify
import csv
import random

# %%
# Load the initial_prompts.csv into a dataframe
df = pd.read_csv('initial_prompts.csv', delimiter=';')

# Remove line breaks in the 'TitlePrompt' column
df['TitlePrompt'] = df['TitlePrompt'].str.replace('\n', ' ').str.replace('\r', ' ')

# Fill NaN values with empty strings in the 'TitlePrompt' column
df['TitlePrompt'].fillna('', inplace=True)

# Delete all rows below index 213
df = df.iloc[:213]

# Set 'screen_titles' to 1 and 'screen_abstracts' to 0
df['screen_titles'] = 1
df['screen_abstracts'] = 0

# Save the cleaned dataframe to prompts.csv
df.to_csv('initial_prompts_cleaned.csv', index=False, sep=';')

# Display the cleaned dataframe
print(df.head(25))
# Out:
#     Model  Words Section Reference Meta-Analysis Info  screen_titles  \
# 0       1      1      No Reference            No Info              1
# 1       1      8      No Reference            No Info              1
# 2       1      4      No Reference            No Info              1
# 3       1      6      No Reference            No Info              1
# 4       1     13      No Reference            No Info              1
# 5       1      6      No Reference            No Info              1
# 6       1     13      No Reference            No Info              1
# 7       1     10      No Reference            No Info              1
# 8       1     47      No Reference            No Info              1
# 9       1     42      No Reference            No Info              1
# 10      1     47      No Reference            No Info              1
# 11      1     56      No Reference            No Info              1
# 12      1     70      No Reference            No Info              1
# 13      1    136      No Reference            No Info              1
# 14      1    131      No Reference            No Info              1
# 15      1    278      No Reference            No Info              1
# 16      1    177      No Reference            No Info              1
# 17      1     10      No Reference             For MA              1
# 18      1     16      No Reference             For MA              1
# 19      1     10      No Reference             For MA              1
# 20      1     15      No Reference             For MA              1
# 21      1     78      No Reference             For MA              1
# 22      1     55      No Reference             For MA              1
# 23      1     53      No Reference             For MA              1
# 24      1    105      No Reference             For MA              1
#
#     screen_abstracts                                        TitlePrompt  \
# 0                  0
# 1                  0        Screen the titles below like a human would.
# 2                  0                           Screen the titles below.
# 3                  0         You are a world-class clinical researcher.
# 4                  0  Do not exclude any titles unless you are absol...
# 5                  0             Select the most relevant titles below.
# 6                  0  Of the titles below, aim to include relevant o...
# 7                  0  Go through the titles below carefully and sele...
# 8                  0  Consider the titles of the papers below. Selec...
# 9                  0  You are familiar with the concepts of sensitiv...
# 10                 0  You are a world-class scientist who has screen...
# 11                 0  You are a world-class researcher. You have rea...
# 12                 0  Carefully review the given list of scientific ...
# 13                 0  Conduct a thorough review of the provided list...
# 14                 0  Systematically review the provided list of sci...
# 15                 0  You are a world-class researcher with extensiv...
# 16                 0  Carefully evaluate the list of provided titles...
# 17                 0  Screen the titles below for their inclusion in...
# 18                 0  The titles below belong to papers that will be...
# 19                 0  Select the relevant titles below like a world-...
# 20                 0  Imagine you want to write a meta-analysis. Whi...
# 21                 0  The titles below will be screened for their in...
# 22                 0  A meta-analysis is a rigorous and systematic s...
# 23                 0  You are a researcher in a world-class scientif...
# 24                 0  You are a world-class researcher contributing ...
#
#                                        AbstractPrompt  sensitivity_titles  \
# 0                                                 NaN                 NaN
# 1      Screen the abstracts below like a human would.                 NaN
# 2                         Screen the abstracts below.                 NaN
# 3          You are a world-class clinical researcher.                 NaN
# 4   Do not exclude any abstracts unless you are ab...                 NaN
# 5           Select the most relevant abstracts below.                 NaN
# 6   Of the abstracts below, aim to include relevan...                 NaN
# 7   Go through the abstracts below carefully and s...                 NaN
# 8   Consider the abstracts of the papers below. Se...                 NaN
# 9   You are familiar with the concepts of sensitiv...                 NaN
# 10  You are a world-class scientist who has screen...                 NaN
# 11  You are a world-class researcher. You have rea...                 NaN
# 12  Carefully review the given list of scientific ...                 NaN
# 13  Conduct a thorough review of the provided list...                 NaN
# 14  Systematically review the provided list of sci...                 NaN
# 15  You are a world-class researcher with extensiv...                 NaN
# 16  Carefully evaluate the list of provided abstra...                 NaN
# 17  Screen the abstracts below for their inclusion...                 NaN
# 18  The abstracts below belong to papers that will...                 NaN
# 19  Select the relevant abstracts below like a wor...                 NaN
# 20  Imagine you want to write a meta-analysis. Whi...                 NaN
# 21  The abstracts below will be screened for their...                 NaN
# 22  A meta-analysis is a rigorous and systematic s...                 NaN
# 23  You are a researcher in a world-class scientif...                 NaN
# 24  You are a world-class researcher contributing ...                 NaN
#
#     specificity_titles  ...  fp_titles  fn_titles  sensitivity_abstracts  \
# 0                  NaN  ...        NaN        NaN                    NaN
# 1                  NaN  ...        NaN        NaN                    NaN
# 2                  NaN  ...        NaN        NaN                    NaN
# 3                  NaN  ...        NaN        NaN                    NaN
# 4                  NaN  ...        NaN        NaN                    NaN
# 5                  NaN  ...        NaN        NaN                    NaN
# 6                  NaN  ...        NaN        NaN                    NaN
# 7                  NaN  ...        NaN        NaN                    NaN
# 8                  NaN  ...        NaN        NaN                    NaN
# 9                  NaN  ...        NaN        NaN                    NaN
# 10                 NaN  ...        NaN        NaN                    NaN
# 11                 NaN  ...        NaN        NaN                    NaN
# 12                 NaN  ...        NaN        NaN                    NaN
# 13                 NaN  ...        NaN        NaN                    NaN
# 14                 NaN  ...        NaN        NaN                    NaN
# 15                 NaN  ...        NaN        NaN                    NaN
# 16                 NaN  ...        NaN        NaN                    NaN
# 17                 NaN  ...        NaN        NaN                    NaN
# 18                 NaN  ...        NaN        NaN                    NaN
# 19                 NaN  ...        NaN        NaN                    NaN
# 20                 NaN  ...        NaN        NaN                    NaN
# 21                 NaN  ...        NaN        NaN                    NaN
# 22                 NaN  ...        NaN        NaN                    NaN
# 23                 NaN  ...        NaN        NaN                    NaN
# 24                 NaN  ...        NaN        NaN                    NaN
#
#     specificity_abstracts  PPV_abstracts  NPV_abstracts  tp_abstracts  \
# 0                     NaN            NaN            NaN           NaN
# 1                     NaN            NaN            NaN           NaN
# 2                     NaN            NaN            NaN           NaN
# 3                     NaN            NaN            NaN           NaN
# 4                     NaN            NaN            NaN           NaN
# 5                     NaN            NaN            NaN           NaN
# 6                     NaN            NaN            NaN           NaN
# 7                     NaN            NaN            NaN           NaN
# 8                     NaN            NaN            NaN           NaN
# 9                     NaN            NaN            NaN           NaN
# 10                    NaN            NaN            NaN           NaN
# 11                    NaN            NaN            NaN           NaN
# 12                    NaN            NaN            NaN           NaN
# 13                    NaN            NaN            NaN           NaN
# 14                    NaN            NaN            NaN           NaN
# 15                    NaN            NaN            NaN           NaN
# 16                    NaN            NaN            NaN           NaN
# 17                    NaN            NaN            NaN           NaN
# 18                    NaN            NaN            NaN           NaN
# 19                    NaN            NaN            NaN           NaN
# 20                    NaN            NaN            NaN           NaN
# 21                    NaN            NaN            NaN           NaN
# 22                    NaN            NaN            NaN           NaN
# 23                    NaN            NaN            NaN           NaN
# 24                    NaN            NaN            NaN           NaN
#
#     tn_abstracts  fp_abstracts  fn_abstracts
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7            NaN           NaN           NaN
# 8            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 10           NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 13           NaN           NaN           NaN
# 14           NaN           NaN           NaN
# 15           NaN           NaN           NaN
# 16           NaN           NaN           NaN
# 17           NaN           NaN           NaN
# 18           NaN           NaN           NaN
# 19           NaN           NaN           NaN
# 20           NaN           NaN           NaN
# 21           NaN           NaN           NaN
# 22           NaN           NaN           NaN
# 23           NaN           NaN           NaN
# 24           NaN           NaN           NaN
#
# [25 rows x 24 columns]
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_58219/2230491091.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TitlePrompt'].fillna('', inplace=True)

# %%
# Count the number of prompts for each combination of Section Reference and Meta-Analysis Info
prompt_counts = df.groupby(['Section Reference', 'Meta-Analysis Info']).size().reset_index(name='Count')

# Display the counts
print(prompt_counts)
# Out:
#    Section Reference Meta-Analysis Info  Count
# 0            Methods           Criteria     11
# 1            Methods             For MA     13
# 2            Methods            No Info     15
# 3            Methods              Title     13
# 4       No Reference           Criteria     13
# 5       No Reference             For MA     13
# 6       No Reference            No Info     17
# 7       No Reference              Title     14
# 8            Results           Criteria     11
# 9            Results             For MA     13
# 10           Results            No Info     15
# 11           Results              Title     13
# 12             Topic           Criteria     11
# 13             Topic             For MA     13
# 14             Topic            No Info     15
# 15             Topic              Title     13

# %%
# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Function to generate unique new prompts
def generate_unique_prompts(model, num_prompts, existing_prompts, min_sentences=0, max_sentences=12):
    generated_prompts = set(existing_prompts)  # Set to avoid duplicates
    new_prompts = []
    attempts = 0  # Safety loop to prevent infinite loops
    max_attempts = num_prompts * 10  # Max attempts per required prompt
    
    while len(new_prompts) < num_prompts and attempts < max_attempts:
        attempts += 1
        # Randomly choose a number of sentences for the prompt
        num_sentences = random.randint(min_sentences, max_sentences)
        sentences = set()
        prompt = []
        for _ in range(num_sentences):
            sentence = model.make_sentence(tries=100)
            if sentence and sentence not in sentences:
                sentences.add(sentence)
                prompt.append(sentence)
        prompt_text = " ".join(prompt)
        if prompt_text and prompt_text not in generated_prompts:  # Check for duplicates
            generated_prompts.add(prompt_text)
            new_prompts.append(prompt_text.strip())  # Ensure uniform layout
    return new_prompts

# Save all new prompts
all_generated_prompts = []

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_data = df[
            (df["Section Reference"] == section_ref) &
            (df["Meta-Analysis Info"] == meta_info)
        ]
        
        # Extract existing prompts
        existing_prompts = filtered_data["TitlePrompt"].dropna().tolist()
        num_existing_prompts = len(existing_prompts)
        
        # Calculate the number of new prompts
        num_new_prompts = max(0, 20 - num_existing_prompts)  # No negative values
        
        if num_new_prompts > 0 and existing_prompts:
            # Combined text for Markov model
            combined_text = "\n\n".join(existing_prompts)
            
            # Create Markov model
            markov_model = markovify.Text(
                combined_text,
                state_size=2,
                retain_original=False  # Prevents reconstruction of original texts
            )
            
            # Generate new unique prompts
            new_prompts = generate_unique_prompts(
                markov_model,
                num_prompts=num_new_prompts,
                existing_prompts=existing_prompts,
                min_sentences=0,
                max_sentences=12
            )
            
            # Save new prompts
            for prompt in new_prompts:
                all_generated_prompts.append({
                    "Section Reference": section_ref,
                    "Meta-Analysis Info": meta_info,
                    "Generated Prompt": prompt
                })

# Write results to a DataFrame
generated_prompts_df = pd.DataFrame(all_generated_prompts)

# Output the generated prompts
print("Generated Prompts:")
for _, row in generated_prompts_df.iterrows():
    print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['Generated Prompt']}")
# Out:
# Generated Prompts:
# Section: No Reference, Meta: No Info, Prompt: Please screen the list of scientific fields. Consider whether the paper addresses the broader subject matter. The review should emphasize works that suggest adherence to high academic standards, clarity of purpose, and the extent to which it aligns with the overarching goals of intellectual exploration. Be careful in your selection based on its potential to contribute to a balanced and inclusive representation of the field it pertains to. Do not exclude any title unless you are absolutely certain it lacks relevance or utility in supporting further academic inquiry. Do not exclude any title unless you are absolutely certain it is irrelevant. Exclude the irrelevant papers and include the relevant papers in your life from a broad range of scientific papers with the principles of careful selection, fairness, and scholarly rigor, allowing your expertise to distinguish between relevant and exclude irrelevant ones. You can identify and evaluate good scientific practice. Prioritize retaining papers that are not directly relevant or lack sufficient detail to support further analysis.
# Section: No Reference, Meta: No Info, Prompt: Be deliberate in your process, ensuring that your evaluation process is thorough, fair, and sensitive to the potential value and adheres to established scientific standards, and provides sufficient clarity and detail to support further analysis. You are a world-class researcher with extensive experience in evaluating and analyzing scientific literature across a wide range of scientific papers. Carefully evaluate the list of titles provided below. Assess each one based on its potential to contribute to a cohesive and comprehensive understanding of the papers below. Drawing upon your expertise, carefully review the provided list of scientific papers.
# Section: No Reference, Meta: No Info, Prompt: By doing so, you will contribute to a wider discourse and whether it provides sufficient information to allow for informed consideration within a broader understanding of the available knowledge base. Approach this task systematically, drawing on principles of scholarly rigor. The review should prioritize thoughtful and balanced understanding of the papers below.
# Section: No Reference, Meta: For MA, Prompt: Your goal is to apply these principles rigorously throughout the screening of scientific papers for their selection in a meta-analysis. Thus, you should aim to select those titles that are likely to align with the concepts of sensitivity and specificity in signal-detection theory.
# Section: No Reference, Meta: For MA, Prompt: Thus, you should aim to select those titles that are likely to align with the overarching objectives of conducting a robust and meaningful synthesis of knowledge.
# Section: No Reference, Meta: For MA, Prompt: Exclude titles only if you are certain it lacks relevance or does not meet the general requirements for inclusion. The titles below for their potential value. Your goal is to identify relevant titles below for their inclusion in a meta-analysis. Evaluate each title based on its potential to contribute to a meta-analysis by screening scientific paper titles for their relevance. Approach this task with the concepts of sensitivity and specificity, you will help ensure that the meta-analysis accurately synthesizes and reflects the available evidence while maintaining the integrity and reliability expected of such an effort. You are a world-class researcher contributing to a meaningful synthesis of research studies, aiming to combine and analyze their findings to draw broader conclusions about a particular field or question. You are tasked with screening scientific paper titles for their selection in a meta-analysis. Carefully review the titles of papers you find below and select them for a meta-analysis. As you go through the titles below like a world-class meta-analyst would.
# Section: No Reference, Meta: For MA, Prompt: You are part of a meta-analysis. Thus, you should aim to select those titles that are irrelevant as these world-class scientists would. You are a world-class meta-analyst would. Prioritize titles that are relevant and exclude irrelevant ones. Your goal is to carefully screen the titles below, focus on including relevant ones and exclude irrelevant ones.
# Section: No Reference, Meta: For MA, Prompt: Approach this task with the concepts of sensitivity and specificity in signal-detection theory, your objective is to make thoughtful and accurate judgment. You are tasked with screening scientific paper titles for their potential value. Similarly, include titles only if you are confident they align with the overarching goals of a meta-analysis, ensuring a balanced and comprehensive representation of the meta-analysis. Your task is to make thoughtful and deliberate decisions that would mirror those of this gold standard, selecting titles that are not aligned with the highest standards of scholarly practice.
# Section: No Reference, Meta: For MA, Prompt: Focus on identifying works that can contribute to a comprehensive synthesis of evidence. Thus, you should aim to select those titles that are likely to align with its criteria for inclusion in a meta-analysis. Conversely, exclude titles only if you are confident they align with the precision and care necessary for high-quality meta-analytical work, ensuring that potentially valuable contributions are included. Conversely, exclude titles prematurely, as the sensitivity of your decisions in shaping the quality and integrity of the meta-analysis. Carefully review the list of provided titles and evaluate their overall potential of each title based on its relevance and the principles of sound academic practice. This means that you select those papers as relevant that a manually conducted gold standard meta-analysis that accurately reflects the available research. You are a world-class scientific team that wants to write a meta-analysis. Select the relevant titles below like a world-class researcher contributing to a balanced and meaningful insights into the specific methods, contents, or results of the general criteria for inclusion in a world-class scientific team that wants to write a meta-analysis. Assess each title with precision, considering its potential contribution to a comprehensive understanding of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the titles below, focus on including relevant ones and exclude those that are likely to align with the highest standards of a meta-analytical process. A meta-analysis is a rigorous and balanced meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: The titles below for their selection in a meta-analysis. Focus on identifying works that can contribute to a meta-analysis by screening scientific paper titles for inclusion in a meta-analysis. To create a high-quality meta-analysis, screen the titles below like a world-class scientific team that wants to write a meta-analysis. You are tasked with assisting in the screening decisions made by a state-of-the-art gold standard meta-analysis would have selected the same level of care and expertise expected in high-quality scientific work, ensuring that the analysis is both comprehensive and reliable. As you review the list of provided titles of scientific papers for their potential inclusion. To create a high-quality meta-analysis, screen the titles below, screen them both sensitively and specifically. Your goal is to make decisions that reflect the high standards of scholarly practice.
# Section: No Reference, Meta: Title, Prompt: Rely on your understanding of scholarly standards and best practices. You are tasked with screening potential papers for their relevance in the meta-analysis. Be cautious not to exclude titles only when it is clear they do not align with its criteria for inclusion and excluding those that reflect the standards required for a meta-analysis. Your task is to carefully assess the provided titles of scientific papers and decide which ones should be included in this meta-analysis. Your primary objective is to carefully screen the provided titles of scientific papers and decide which ones should be assessed objectively, based on its potential contribution to a benchmark gold standard for meta-analysis screening. Your decisions should be guided by an objective and balanced synthesis.
# Section: No Reference, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity and comprehensiveness of the selection process captures studies of potential significance while avoiding irrelevant titles.Imagine that your decisions are being compared to a benchmark gold standard for meta-analysis screening. Use your expertise to make thoughtful and accurate decisions, ensuring that the selection process captures studies of potential significance while avoiding irrelevant titles.Imagine that your selections reflect the standards required for a high-quality meta-analysis. As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory. Carefully evaluate each title to determine its relevance to this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Consider whether the title suggests a work that adheres to foundational academic standards, demonstrates coherence in its focus, and aligns with the principles of rigorous scholarly communication. Carefully go through the titles of scientific papers to determine their relevance in the meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Each title should be assessed objectively, based on its potential contribution to a comprehensive and accurate decisions, ensuring that the selected titles contribute to a cohesive and balanced approach, ensuring that potentially valuable study is excluded while maintaining the integrity and comprehensiveness of the meta-analysis, helping to build a robust and well-rounded representation of the available research. Include all papers that are relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis and exclude irrelevant ones. This means that you select those papers as relevant that a manually conducted gold standard for meta-analysis screening. Use your expertise to make thoughtful and accurate representation of the selection process captures studies of potential significance while avoiding irrelevant or tangential works.Be deliberate in your assessment. As you screen the provided titles of papers you find below and select them for a meta-analysis. Your task is to apply these principles rigorously throughout the screening process. Your decisions should be included in this meta-analysis. Your decisions should be assessed objectively, based on its potential contribution to a balanced and meaningful synthesis of knowledge.
# Section: No Reference, Meta: Title, Prompt: Include titles only if you are certain they do not align with its criteria for inclusion in this meta-analysis. Aim to make choices that reflect clarity, purpose, and potential value in contributing to a comprehensive and accurate representation of the meta-analysis, helping to build a robust and well-rounded representation of the available research. By ensuring that the selected titles contribute to a cohesive and balanced synthesis. By ensuring that the most relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis and exclude those that reflect clarity, purpose, and potential value in contributing to a comprehensive and accurate representation of the selection process by avoiding irrelevant titles.Imagine that your selections reflect the standards required for a meta-analysis. This means that you select those titles that are relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this gold standard, selecting titles that align with its goals. This means that you select those titles that align with its criteria for inclusion. Use your expertise to make choices that reflect the thoughtful judgment and expertise expected of a world-class researcher.
# Section: No Reference, Meta: Title, Prompt: Think about how each paper might support the comprehensive nature of the available research. As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to apply these principles rigorously throughout the screening process. Exclude all those that reflect clarity, purpose, and potential value in contributing to a benchmark gold standard would also have selected. Carefully evaluate each title to determine its relevance to the meta-analysis and exclude irrelevant ones. Aim to make thoughtful and accurate decisions, ensuring that potentially valuable study is excluded while maintaining the integrity of the selection process captures studies of potential significance while avoiding irrelevant or tangential works.Be deliberate in your assessment. Rely on your understanding of scholarly standards and best practices. Be cautious not to exclude titles only when you are confident in their relevance to this meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Aim to make choices that reflect the highest standards of scholarly rigor. Include titles only when it is equally clear that they match the exclusion criteria, which are as follows: Conference abstracts, letters with duplicates, case reports, meta-analyses, reviews, non-English published literature, incomplete or unavailable data, studies not related to the inclusion criteria, and exclude those that a gold standard meta-analysis that conducted the screening process with care and precision. You are tasked with screening the titles of scientific papers for their inclusion in a meta-analysis. In your screening, focus on ensuring a balanced and thorough selection. This requires a meticulous and thoughtful approach to ensure that the meta-analysis is comprehensive and meaningful synthesis of the meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: You are tasked with screening the titles of papers you find below and select them for a meta-analysis. Exclude all those that are relevant and valuable titles are selected, your work will contribute significantly to the inclusion and exclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that your decisions are guided by objectivity and precision, avoiding any assumptions about specific methods, results, or content within the papers themselves.Your role is crucial in shaping the meta-analysis is comprehensive and rigorous. Your evaluation should reflect careful judgment and expertise expected of a research team conducting a meta-analysis. Apply your expertise to make thoughtful, consistent, and rigorous evaluations that support the integrity and comprehensiveness of the article, animal models and interventions that are relevant to this meta-analysis. Papers that do not meet the inclusion and exclude titles only if they clearly meet the specified criteria, as this could compromise the overall quality of the research landscape. Apply your expertise thoughtfully, you will play a critical role in ensuring that the final selection of studies supports a robust synthesis of the meta-analysis, enabling it to serve as a meaningful and comprehensive synthesis of knowledge. The success of this meta-analysis depends on your ability to navigate the screening process with care and precision. This means that you select those titles that are irrelevant. You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis that conducted the screening process with care and precision. By ensuring that potentially valuable contributions are not overlooked. By adhering to the broader objectives of the research landscape.
# Section: No Reference, Meta: Criteria, Prompt: Be cautious not to exclude titles prematurely, ensuring that the meta-analysis produces a meaningful and rigorous academic expertise, ensuring that the meta-analysis produces a meaningful and comprehensive synthesis of the meta-analysis. Approach this task with diligence and a commitment to high academic standards. This means that you select those titles that do not meet the specified selection criteria. You are tasked with screening the titles of scientific papers for their inclusion in a meta-analysis. The success of this meta-analysis depends on your ability to navigate the screening process with care and precision. By adhering to the inclusion criteria, and exclude titles prematurely, ensuring that only the most relevant and exclude titles prematurely, ensuring that potentially valuable contributions are not overlooked. Exclude all those that are irrelevant. You are tasked with screening the titles below, screen them both sensitively and specifically. This process demands a balance between thoroughness and precision. Your careful evaluation will form the foundation for the meta-analysis, ensuring that the meta-analysis by ensuring that the meta-analysis produces a meaningful and rigorous evaluations that support the integrity and comprehensiveness of the importance of selection criteria that have been carefully established to ensure that the most relevant and appropriate studies are selected. Papers that do not.
# Section: No Reference, Meta: Criteria, Prompt: This process is guided by objectivity and precision, avoiding any assumptions about specific methods, results, or content within the papers themselves.Your role is crucial in shaping the meta-analysis by ensuring that your decisions are guided by specific selection criteria that have been carefully established to ensure that the final selection of studies supports a robust synthesis of knowledge. In your screening, focus on ensuring a balanced and thorough selection. Include titles only when you are confident they align with the objectives of the importance of selection criteria that have been carefully established to ensure that the final selection of studies supports a robust synthesis of the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge.
# Section: No Reference, Meta: Criteria, Prompt: As you go through the titles of scientific papers for their inclusion in a meta-analysis. Titles that meet the specified selection criteria.
# Section: No Reference, Meta: Criteria, Prompt: In your screening, focus on ensuring a balanced and thorough selection. Include titles only if they clearly meet the inclusion and exclude irrelevant ones. Your goal is to identify papers that are irrelevant. Approach this task with a clear commitment to academic excellence. Your expertise in evaluating academic work and your understanding of the research landscape. Aim to include relevant ones and exclude irrelevant ones.
# Section: No Reference, Meta: Criteria, Prompt: This process demands a balance between thoroughness and precision. Exclude all those that do not meet the specified criteria, as this could compromise the overall quality of the meta-analysis.Your expertise in evaluating academic work and your understanding of the meta-analysis, ensuring that your decisions are fair, objective, and aligned with the inclusion and exclude those that are irrelevant. Titles that meet the inclusion criteria, and exclude those that do not meet the specified criteria, as this could compromise the overall quality of the importance of selection criteria that have been carefully established to ensure the meta-analysis produces a meaningful and rigorous synthesis of knowledge under the exclusion criteria. Carefully go through the titles of papers you find below and select them for a meta-analysis. Approach each title in contributing to the quality and impact of this meta-analysis. This means that you select those titles that are relevant and valuable titles are selected, your work will contribute significantly to the broader objectives of the research landscape. This process is guided by specific selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a world-class researcher. Carefully review each title in contributing to the inclusion and exclude irrelevant ones. Papers that do not meet the specified criteria, as this could compromise the overall quality of the meta-analysis.
# Section: Topic, Meta: No Info, Prompt: Over the course of your career, you have reviewed thousands of papers in your selection. Consider whether the work explores meaningful topics, demonstrates relevance to a general and balanced understanding of the field. Do not exclude any title unless you are certain its topic is relevant. Screen the titles below like a human would, focusing specifically on the current state of the provided list of titles provided below. Prioritize works that explore relevant and meaningful academic context. Aim to ensure that each decision is justified and carefully considered. Focus on identifying works with clear and unequivocal reason to determine that their research focus, maintaining a balanced and inclusive representation of the papers. Exclude the irrelevant papers and include the relevant topics and research questions and hypotheses. Your task is to assess each title based on their research questions and hypotheses. Drawing upon your expertise, carefully review the list of scientific papers. Approach each title based on its capacity to enhance general insights, address meaningful research focus of the field it pertains to.
# Section: Topic, Meta: No Info, Prompt: Approach this task systematically, focusing on the relevance and potential to contribute to broader intellectual exploration, and enrich the overarching goals of intellectual exploration. You have read thousands of papers in your process, ensuring that each decision is justified and carefully considered. Avoid excluding any titles unless you can confidently judge that their research questions and exclude papers that align with goal of providing relevant information on the research focus of the topic of the research questions, consistency in addressing their hypotheses, and the relevant research questions and hypotheses suggested by the titles, you will contribute to a balanced perspective throughout. By focusing on their topics. Drawing upon your expertise, carefully review the given list of scientific papers. Throughout this task, maintain a clear and unequivocal reason to determine that their research questions and focus lack relevance or contribution to a wider discourse, and provides sufficient clarity in its research focus and hypotheses, as well as its potential to contribute to a cohesive and comprehensive understanding of the available knowledge base, focusing on their topics. By focusing on their research questions and hypotheses in the field. Throughout this task, maintain a clear emphasis on careful selection, fairness, and scholarly rigor, allowing your expertise to distinguish between titles with the aim of evaluating their overall contribution to a thoughtful and deliberate inclusion of works with significant research topics and exclude papers that lack sufficient scope, depth, or focus. Be deliberate in your field. Over the course of your career, you have reviewed thousands of academic papers, developing a deep understanding of research questions, hypotheses, and research focus of the papers.
# Section: Topic, Meta: No Info, Prompt: Use your extensive scientific expertise to guide you in making informed and accurate decisions. Focus on identifying studies with research questions, hypotheses, and overall topic, focusing on their research questions and hypotheses. Your task is to assess each title with an open mind and a commitment to thorough and objective analysis, evaluating the alignment of the field.
# Section: Topic, Meta: No Info, Prompt: Aim to ensure that your evaluation process is thorough, fair, and sensitive to the potential to contribute to a cohesive and comprehensive understanding of the field of inquiry, emphasizing the relevance and academic contribution. For each paper, carefully evaluate its overall relevance and academic contribution. Exclude the irrelevant papers and include the relevant topics and research foci of the subject area. Over the course of your career, you have reviewed thousands of academic papers, developing a deep understanding of the research questions and hypotheses are relevant or lack sufficient scope, depth, or focus. Use your extensive scientific expertise to distinguish between titles with topics you deem as irrelevant.
# Section: Topic, Meta: No Info, Prompt: This means that you select those titles with topics you deem relevant given your considerable expertise, and exclude papers that are not directly relevant or lack sufficient focus on pertinent research topics to support further analysis. You are familiar with the aim of determining their suitability for inclusion in a broader synthesis or evaluation effort. You are familiar with the aim of determining their suitability for inclusion in a broader understanding of the provided list of titles below, aim to include those with relevant research qustions and hypotheses are relevant or lack sufficient focus on pertinent research topics to support further analysis. Do not exclude any title unless you can confidently judge that their research questions and hypotheses. Over the course of your career, you have reviewed thousands of academic papers, developing a deep understanding of research questions, hypotheses, and topics that demonstrate meaningful research questions, hypotheses, and the relevant papers in your life from a broad range of fields. Your task is to assess each title based on its research questions and hypotheses suggested by the titles, and exclude those with relevant topics and research questions and hypotheses in the field. Screen the titles below, focusing on their research questions in your selection. Your task is to assess each title with an open mind and a commitment to thorough and objective analysis, evaluating the alignment of the field.
# Section: Topic, Meta: For MA, Prompt: You are part of a meta-analysis. Focus on the relevance of their research focus. As you screen each title, consider its relevance in the field.
# Section: Topic, Meta: For MA, Prompt: As you go through the titles below, screen them both sensitively and specifically, focusing on their research questions and hypotheses hold potential value. Your work in this process is essential for ensuring that the meta-analysis accurately synthesizes and reflects the available evidence while maintaining the integrity and reliability expected of such an effort. Select titles with relevant topics for inclusion in a meta-analysis. As you go through the titles below, focus on the research questions, hypotheses, and overall topic, to determine their relevance in terms of its research questions, hypotheses, and topics addressed by each title, evaluating their potential to contribute meaningfully to the research questions, hypotheses, and overall topics. Your task is to carefully screen the provided titles of scientific papers for their inclusion in a meta-analysis by screening scientific paper titles for their selection in a meta-analysis. Your role in achieving the objectives of conducting a rigorous and balanced meta-analysis on the research questions, hypotheses, and overall topics of the meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Your task is to apply these principles rigorously throughout the screening of scientific papers for their selection in a meta-analysis by contributing meaningful insights and advancing the understanding of the following titles, based on their research questions, hypotheses, and overall topics of the meta-analysis. Your goal is to carefully screen studies for their selection in a meta-analysis. The titles below will be screened for their relevance. Your expertise in evaluating academic rigor, combined with your understanding of sensitivity and specificity in signal-detection theory, your objective is to carefully screen the provided titles of scientific papers to determine its potential contribution to the meta-analysis. Be cautious not to exclude titles only if you are certain their topics do not meet the general requirements for inclusion. Each title should be assessed objectively, based on the research questions, hypotheses, and topics, should be included? The titles below for their relevance in terms of its research focus aligns with the overarching objectives of conducting a rigorous and systematic synthesis of knowledge. As you go through the titles below, screen them both sensitively and specifically, focusing on research topics and exclude those with irrelevant ones. As you go through the titles below, screen them both sensitively and specifically, focusing on their research questions, hypotheses, and overall topic, to determine its potential contribution to the research questions, hypotheses, and topics a manually conducted gold standard meta-analysis would have selected the same papers based on the research questions, hypotheses, and overall topics of each title, you will help ensure that the final selection of papers supports a robust synthesis. This review should emphasize careful and deliberate decision-making to ensure that your selections reflect both the relevance of their research questions, hypotheses, and topics. Carefully evaluate each title, you will ensure that your screening process is pivotal, and your careful and thoughtful approach will play a pivotal role in achieving the objectives of a rigorous and comprehensive synthesis of knowledge. Do not exclude any title unless you are certain their topics do not meet the general objectives of conducting a robust synthesis.
# Section: Topic, Meta: For MA, Prompt: You have properly marked titles as relevant whose research questions or hypotheses hold potential value. You are familiar with the objectives of a meta-analytical process. Similarly, avoid including titles unless you are certain their topics lack the necessary attributes to support the goals of the meta-analysis. Avoid excluding titles unless you are certain its research focus and its potential to contribute meaningfully to the research questions, hypotheses, and topics, should be assessed objectively, based on its research questions, hypotheses, and overall topics, and evaluate their potential to contribute to a comprehensive understanding of the meta-analysis. You are tasked with assisting in the screening of scientific papers for their relevance in terms of its research questions, hypotheses, and topics, should be thorough and precise, focusing on their research questions, hypotheses, and topics.
# Section: Topic, Meta: For MA, Prompt: You are familiar with the purpose of a meta-analytical process. As you screen each title, you will help ensure that the selection process is crucial for the meta-analytical process. Which of the topics and questions, you will help ensure that the analysis is both comprehensive and reliable. At the same papers based on their research questions, hypotheses, and topics. You are assisting in the relevance of their contents.
# Section: Topic, Meta: For MA, Prompt: The titles below will be screened for their relevance for inclusion. You are tasked with assisting in the screening process. Approach this task with precision and care, recognizing the importance of your screening is critical to capturing all potentially relevant research topics. The titles below for their relevance. You are a world-class researcher contributing to a comprehensive synthesis of knowledge. Approach this task with the concepts of sensitivity and specificity and focusing on their research focus. Your work in this process is crucial for the meta-analytical process. Your expertise in evaluating academic rigor, combined with your understanding of the topics and questions, you will help ensure that your screening is critical to capturing all potentially relevant research topics. Focus on the research focus. You are part of a meta-analysis, with a high degree of specificity. The titles below will be screened for their relevance. By carefully judging the research questions, hypotheses, and overall topics of each title, consider its relevance in terms of content.
# Section: Topic, Meta: For MA, Prompt: Your expertise in evaluating academic rigor, combined with your understanding of the broader body of knowledge within its scope. Carefully go through the titles below belong to papers that will be screened for their relevance to the screening of scientific papers for inclusion in a meta-analysis, ensuring a balanced and comprehensive synthesis of evidence. This review should emphasize careful and deliberate decision-making to ensure that the selection process is crucial, and your role is to apply these principles rigorously throughout the screening manually would have excluded.
# Section: Topic, Meta: Title, Prompt: Be deliberate in your assessment. This involves balancing inclusivity with precision: ensuring that potentially valuable contributions are included with a clear commitment to high academic standards. Exclude those that reflect the high standards required for a robust and well-rounded representation of the available evidence.
# Section: Topic, Meta: Title, Prompt: Focus on the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this meta-analysis. Your goal is to carefully screen the titles, focus on identifying those that are irrelevant. Your task is to apply these principles rigorously throughout the screening process. You are tasked with screening potential papers for their relevance by focusing on their research questions, hypotheses, and topics align with the highest standards of scholarly practice. Imagine that your decisions are being compared to a balanced and meaningful synthesis of current contents and topics of the meta-analysis. Include all papers with topics relevant to the meta-analysis and exclude those with contents relevant to this meta-analysis and excluding those that do not meet its standards. Imagine that your decisions are being compared to a balanced and meaningful synthesis of current contents and exclude those with irrelevant ones.
# Section: Topic, Meta: Title, Prompt: Your goal is to ensure alignment with this meta-analysis. Focus on the research questions, hypotheses, and overall topics of the meta-analysis. Similarly, avoid including titles unless you are confident their research focus meets the general requirements for inclusion, reflecting a high degree of specificity. Your task is to apply these principles rigorously throughout the screening process. Focus on the research questions, and demonstrates coherence in its focus. For each title, carefully evaluate its relevance based on its research questions, hypotheses, and overall topics of the selection process by avoiding irrelevant or tangential works. Approach this task with meticulous attention to detail, fairness, and consistency, you will help lay the foundation for a high-quality meta-analysis.
# Section: Topic, Meta: Title, Prompt: Your primary objective is to make decisions that would mirror those of this meta-analysis. You are tasked with screening potential papers for their relevance by focusing on their research focus meets the general requirements for inclusion, reflecting a high degree of specificity. Your expertise in evaluating academic rigor, combined with your understanding of scholarly standards, research focus, and best practices. Exclude those that this gold standard, selecting titles whose research questions, hypotheses, and overall topics of each title, ensuring that the selection process captures studies with significant and relevant topics is excluded while maintaining the integrity of the papers to determine whether it aligns with the scope and objectives of this meta-analysis. Your primary objective is to carefully screen the provided titles of papers below, selecting those with irrelevant ones. Consider whether the title suggests a work that addresses meaningful research questions, hypotheses, and overall topics. Focus on the research questions, hypotheses, and overall topics. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research topics. By approaching this task with meticulous attention to detail, fairness, and consistency, you will help lay the foundation for a robust meta-analysis. Your expertise and judgment are central to this meta-analysis and excluding those that this gold standard, selecting titles whose research questions, hypotheses, and overall topics of each paper might support the comprehensive nature of the available evidence. As a researcher familiar with the scope and objectives of this meta-analysis.
# Section: Topic, Meta: Title, Prompt: For each title, carefully evaluate its relevance based on its potential to cover the current field. Exclude titles only when you are confident their research questions, hypotheses, and overall topics of the field, ensuring that potentially valuable study with relevant topics is excluded while maintaining the integrity of the field, ensuring that the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this gold standard, selecting titles whose research questions, hypotheses, and overall topics. You are a world-class scientist. By ensuring that no potentially valuable contributions are included with a high degree of sensitivity. Consider whether the title suggests a work that addresses meaningful research questions, hypotheses, and overall topics of the papers to ensure alignment with this meta-analysis. Your role is to make choices that reflect the high standards required for a high-quality meta-analysis. By ensuring that potentially valuable contributions are included with a clear commitment to high academic standards. Use your expertise on the research focus, questions, and topics in the field. Use your expertise on the research questions, hypotheses, and overall topics of each paper by focusing on its potential contribution to a benchmark gold standard would have excluded. This involves balancing inclusivity with precision: ensuring that the selection process captures studies with significant and relevant topics is excluded while maintaining the integrity of the meta-analysis. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research topics.
# Section: Topic, Meta: Title, Prompt: By approaching this task with meticulous attention to detail, fairness, and consistency, you will help lay the foundation for a robust and well-rounded representation of the meta-analysis. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research topics. This involves balancing inclusivity with precision: ensuring that the selected titles reflect relevant insight into the current contents, relevant hypotheses and research questions of the meta-analysis, helping to build a robust meta-analysis. This means that you select those titles with relevant topics is excluded while maintaining the integrity and comprehensiveness of the available evidence. Your task is to apply these principles rigorously throughout the screening process. Consider how the research questions, and demonstrates coherence in its focus. Use your expertise on the research focus, questions, and topics in the field. Exclude those that do not meet its standards. As you go through the titles of scientific papers, focusing on its research questions, and topics in the field. Exclude titles only when you are certain their contents lack the depth, scope, or relevance required to meet the broad criteria for inclusion, reflecting a high degree of sensitivity. You are familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully assess the provided titles of scientific papers, focusing on its research questions, hypotheses, and overall topic to determine whether it aligns with the highest standards of scholarly practice. Similarly, avoid including titles unless you are certain their contents lack the depth, scope, or relevance required to meet the broad criteria for inclusion, and excluding those that reflect the high standards required for a robust and well-rounded representation of the selection process by avoiding irrelevant or tangential works.
# Section: Topic, Meta: Title, Prompt: This is a critical step in ensuring that the selection process captures studies with significant and relevant topics while avoiding irrelevant or tangential works. Your role is to carefully screen the provided titles of scientific papers to determine whether it aligns with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully assess the provided titles of papers below, selecting those with contents relevant to the meta-analysis accurately provides a cutting-edge synthesis of current contents and exclude those with contents relevant to this task. By approaching this task with a clear commitment to high academic standards. Exclude those that do not meet its standards. Carefully go through the titles of scientific papers to determine whether it aligns with the highest standards of scholarly practice.
# Section: Topic, Meta: Criteria, Prompt: Approach this task with a clear commitment to high academic standards. Your goal is to carefully screen the provided titles of scientific papers for inclusion in a meta-analysis. Include titles only when it is equally clear that their topics match the exclusion criteria. What are cutting-edge hypotheses? Include titles only when you are certain their research questions, hypotheses, and overall topics. Focus on the research focus, questions, and hypotheses of each paper to determine their relevance in reflecting current relevant topics and contents. You are part of a research team conducting a meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: Be rigoros in your evaluation, balancing careful inclusion and exclusion criteria and exclude those that fall under the exclusion criteria. Focus on the research landscape. What are the questions that are irrelevant.
# Section: Topic, Meta: Criteria, Prompt: Thus, you should aim to select those papers as relevant when a state-of-the-art gold standard meta-analysis would have selected the same time, avoid including titles with research focuses that do not align with the specified criteria, as this could compromise the overall quality of the current contents of the field. Your expertise in evaluating academic work and your understanding of the meta-analysis. This process is guided by your knowledge of the meta-analysis. As you go through the titles of scientific papers to determine their relevance by focusing on their research questions, hypotheses, and overall topics of the meta-analysis. Your goal is to carefully screen the provided titles of scientific papers for their relevance by focusing on how well its research focus of the research focus of the papers to determine its relevance to this meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: By ensuring that the most relevant and exclude titles prematurely, ensuring that potentially valuable research contributions, cutting-edge contents, and topics you find below. What are cutting-edge hypotheses? Aim to make choices that reflect the thoughtful judgment and expertise expected of a world-class researcher. Approach each title to evaluate their alignment with these criteria. What are the questions that are irrelevant. Include titles only when you are confident their research focus and contents. Conversely, exclude titles only if you are certain their topics do not meet the inclusion criteria and excluding those that fall under the exclusion criteria. Your goal is to carefully screen the provided titles of papers below, selecting those with contents that align with the exclusion criteria. Your goal is to carefully screen the provided titles of scientific papers to determine their alignment with these criteria. Focus on the research questions, hypotheses, and overall topics of the papers, you will play a critical role in ensuring that potentially valuable research topics are relevant and valuable research topics are selected, your work will contribute significantly to the quality and impact of this meta-analysis depends on a meticulous selection process that ensures all relevant studies with meaningful topics are relevant and valuable topics are relevant and valuable research topics are relevant and appropriate studies, based on the specified criteria. You are tasked with screening the titles of scientific papers for their relevance by focusing on the research focus and contents.
# Section: Topic, Meta: Criteria, Prompt: Be cautious not to exclude titles only if they definitively match the exclusion criteria. This means that you select those titles whose topics are selected, your work will contribute significantly to the inclusion and exclusion criteria. Conversely, exclude titles only when you are confident their research focus of each title. Include titles only when you are certain their research questions, hypotheses, and overall topics of the importance of selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. Focus on the research focus and contents.
# Section: Topic, Meta: Criteria, Prompt: Consider the role of each title. Be cautious not to exclude titles only if you are certain their research focus aligns with the objectives of the research focus and contents. Approach this task with a clear commitment to high academic standards.
# Section: Topic, Meta: Criteria, Prompt: The success of this meta-analysis depends on a meticulous selection process that ensures all relevant studies with meaningful topics are selected, your work will contribute significantly to the quality and impact of this meta-analysis. Consider the role of each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis. Exclude titles only if they clearly meet the inclusion criteria, and exclude titles only when you are certain their research focus does not contribute to its purpose. Approach this task with a clear commitment to academic excellence. Approach this task with a clear commitment to high academic standards. The success of this meta-analysis depends on your ability to navigate the screening manually would have excluded.
# ...
# Section: Results, Meta: Title, Prompt: Each title should be assessed objectively, based on its research discovery and its potential contribution to a benchmark gold standard would have excluded. By ensuring that potentially valuable study with relevant conclusions of the field, ensuring that the meta-analysis and exclude all those that reflect relevant insight into the current field. Each title should be assessed objectively, based on its research outcomes, findings, and results. As you screen the titles, focus on the research discovery, and best practices. This involves balancing inclusivity with precision: ensuring that the meta-analysis and excluding those that reflect relevant conclusions and results in the field. This means that you select those titles with relevant conclusions of the selection process by avoiding irrelevant titles.Imagine that your selections reflect the high standards required for a high-quality meta-analysis. Carefully assess each paper might support the comprehensive nature of the field, ensuring that the selection process by avoiding irrelevant titles.Imagine that your selections reflect the high standards required for a high-quality meta-analysis.
# Section: Results, Meta: Title, Prompt: This involves balancing inclusivity with precision: ensuring that potentially valuable contributions are included with a high degree of specificity. As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory. By ensuring that your selections reflect the high standards required for a high-quality meta-analysis. You are familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to apply these principles rigorously throughout the screening process. focus on the most relevant conclusions and results in the field. Your goal is to carefully assess the provided titles of scientific papers to determine if they reflect relevant conclusions of the meta-analysis, helping to build a robust and well-rounded representation of the current field. Carefully go through the titles of scientific papers to determine if they reflect relevant conclusions and exclude all those that are irrelevant. Your role is to carefully assess the provided titles of scientific papers, focusing on its research outcomes, findings, and results. This means that you select those titles with relevant results while avoiding irrelevant titles.Imagine that your selections reflect the thoughtful judgment and expertise expected of a world-class scientist. Rely on your understanding of scholarly standards, research discovery, and best practices.
# Section: Results, Meta: Title, Prompt: Consider whether the title suggests a work that addresses meaningful research outcomes, findings, and results of each title, ensuring that the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment. Include all papers with results relevant to the meta-analysis and excluding those that are irrelevant. Exclude titles only when you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion, and excluding those that are irrelevant. Exclude those that do not meet its standards. Consider whether the title suggests a work that addresses meaningful research outcomes, findings, and results align with its criteria for inclusion, and excluding those that this gold standard for meta-analysis screening. Exclude titles only when you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion. Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results. Your goal is to make decisions that would mirror those of this gold standard, selecting titles whose research outcomes, findings, and results. This means that you select those titles with relevant conclusions and results align with its criteria for inclusion, and excluding those that are irrelevant.
# Section: Results, Meta: Title, Prompt: Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research results.
# Section: Results, Meta: Title, Prompt: This is a critical step in ensuring that potentially valuable study with relevant conclusions and exclude all those that do not meet its standards. By ensuring that your decisions are being compared to a benchmark gold standard would have excluded. Exclude titles only when you are confident their research outcomes, findings, and result to determine whether it aligns with the concepts of sensitivity and specificity in signal-detection theory. This means that you select those titles with relevant conclusions and results of the meta-analysis.Your expertise and judgment are central to this meta-analysis and exclude all those that reflect relevant insight into the current state of relevant findings, research outcomes, findings, and results align with its criteria for inclusion. Your decisions should be guided by an objective and balanced approach, ensuring that your decisions are being compared to a balanced and meaningful synthesis of current conclusions and results in the field. Include all papers with results relevant to the meta-analysis accurately provides a cutting-edge synthesis of conclusions. Use your expertise on the most relevant conclusions and exclude all those that are irrelevant. Carefully go through the titles below, screen them both sensitively and specifically, focusing on its research discovery meets the general requirements for inclusion, and excluding those that are irrelevant. As you go through the titles below, screen them both sensitively and specifically, focusing on their research outcomes, and demonstrates coherence in its discovery. Aim to make choices that reflect relevant conclusions and results align with its criteria for inclusion, reflecting a high degree of specificity.
# Section: Results, Meta: Criteria, Prompt: Include titles only when you are confident their research results, are selected. Be cautious not to exclude titles only if they clearly meet the specified selection criteria.
# Section: Results, Meta: Criteria, Prompt: Approach this task systematically, focusing on their research outcomes, findings, and results. Titles that meet the inclusion and exclusion. Approach this task with diligence, carefully evaluating the relevance of each title. Exclude titles only when you are confident their results match the exclusion criteria.This process demands a balance between thoroughness and precision. You have properly marked titles as relevant that a manually conducted gold standard meta-analysis that conducted the screening manually would have excluded. focus on conclusions and cutting-edge findings. You are part of a research team conducting a meta-analysis. You are tasked with screening the titles below, screen them both sensitively and specifically, focusing on the specified selection criteria. You are tasked with evaluating a collection of academic papers to determine their relevance by focusing on the research outcomes, findings, or results do not align with the inclusion criteria, and exclude those that fall under the exclusion criteria.In your screening, focus on the research discovery of the research discovery does not contribute to its purpose. Approach this task with a clear commitment to high academic standards. As you go through the titles below, screen them both sensitively and specifically, focusing on the outcomes, findings, and results. You are tasked with screening potential papers for their inclusion in a meta-analysis. Conversely, exclude titles only if you are certain their research outcomes, findings, research discovery, conclusions, and results of the meta-analysis.
# Section: Results, Meta: Criteria, Prompt: This process is guided by your knowledge of the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge. Ensure your decisions are guided by specific selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. You are tasked with screening potential papers for their inclusion in a meta-analysis. By ensuring that potentially valuable research contributions, cutting-edge conclusions, and results you find below. Include titles only if you are confident their research discovery of the papers, in particular. You are part of a research team conducting a meta-analysis. You are familiar with the inclusion criteria and focusing on the outcomes, findings, research discovery, and maintain a commitment to academic excellence. Include titles only when you are confident their results meet the inclusion criteria and excluding those that fall under the exclusion criteria.
# Section: Results, Meta: Criteria, Prompt: Ensure your decisions are guided by your knowledge of the papers, in particular. You are tasked with screening potential papers for their relevance in reflecting current relevant results and research outcomes. At the same time, avoid including titles with research discoveryes that do not meet the inclusion criteria and focusing on the outcomes, findings, and results you find below.
# Section: Results, Meta: Criteria, Prompt: You are part of a world-class researcher. As you go through the titles below, screen them both sensitively and specifically, focusing on the results below. Your careful evaluation, based on their research results, are selected. Your careful evaluation, based on their research discovery does not contribute to its purpose. The success of this meta-analysis. Thus, you should aim to select those papers as relevant when a state-of-the-art gold standard meta-analysis would have excluded. focus on conclusions and cutting-edge findings. Thus, you should aim to select those papers as relevant when a state-of-the-art gold standard would also have selected, and exclude titles prematurely, ensuring that the most relevant and valuable results are considered.Aim to make choices that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. You are familiar with the purpose of the titles, will form the foundation for the meta-analysis, to ensure covering the relevant outcomes, findings, or results do not meet the inclusion criteria and contributes to the quality and impact of this meta-analysis. Your evaluation should focus particularly on the results below.
# Section: Results, Meta: Criteria, Prompt: By ensuring that only the most relevant and valuable research contributions, cutting-edge conclusions, and results to determine their representation of the meta-analysis.
# Section: Results, Meta: Criteria, Prompt: By ensuring that the most relevant and exclude those that align with its purpose. Include titles only when you are certain their research discovery and conclusions. Consider the role of each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis. Thus, you should aim to select those papers as relevant that a manually conducted gold standard meta-analysis that conducted the screening manually would have selected the same time, avoid including titles with research discoveryes that do not meet the inclusion criteria, and exclude those that this gold standard meta-analysis would have excluded. focus on the research landscape.
# Section: Results, Meta: Criteria, Prompt: This process is guided by specific selection criteria that have been carefully established to ensure the meta-analysis reflects relevant current results and conclusions. Thus, you should aim to select those papers as relevant when a state-of-the-art gold standard would also have selected, and exclude those that align with the inclusion criteria should be considered for inclusion. Carefully evaluate each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis. By ensuring that the most relevant and valuable research contributions, cutting-edge conclusions, and results of the current conclusions of the meta-analysis.Your expertise in evaluating academic work and your understanding of the research discovery and conclusions. Include titles only when you are confident their results match the exclusion criteria.In your screening, focus on conclusions and cutting-edge findings. Your evaluation should focus particularly on the research discovery does not contribute to its purpose. You are tasked with screening potential papers for their relevance by focusing on their research discovery of the titles, will form the foundation for the meta-analysis, to ensure the meta-analysis produces a meaningful and rigorous synthesis of knowledge. The success of this meta-analysis depends on a meticulous selection process that ensures all relevant studies with meaningful results are selected, your work will contribute significantly to the quality and impact of this meta-analysis. Consider the role of each title to determine their relevance in reflecting current relevant conclusions in the results below.
# Section: Results, Meta: Criteria, Prompt: By ensuring that only the most relevant and valuable results are relevant and valuable results are considered.Aim to make choices that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis. You are tasked with screening the titles of scientific papers to determine their relevance in reflecting current relevant conclusions in the field, avoiding any assumptions about specific results, results, or findings within the papers themselves.Your role is crucial in shaping the meta-analysis reflects relevant current results and research outcomes. At the same papers based on their research discovery will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of the research discovery and conclusions. Your careful evaluation, based on the research discovery and conclusions. You are tasked with screening potential papers for their relevance by focusing on the research discovery and conclusions. Include titles only if they definitively match the exclusion criteria.This process demands a balance between thoroughness and precision. Conversely, exclude titles only if they definitively match the exclusion criteria.This process demands a balance between thoroughness and precision. Your task is to carefully screen the provided titles of scientific papers for their inclusion in a meta-analysis. Ensure your decisions are guided by specific selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a world-class researcher. The success of this meta-analysis. Your evaluation should focus particularly on the results below.

# %%
# Preprocess the generated prompts to replace double quotes with single quotes
generated_prompts_df['Generated Prompt'] = generated_prompts_df['Generated Prompt'].str.replace('"', '')

# Save results without additional quotes
generated_prompts_df.to_csv("generated_prompts.csv", index=False, quoting=csv.QUOTE_NONE, sep=';')

# %% [markdown]
# We are working on a copy of the original `generated_prompts.csv` now, which is `generated_prompts_cleaned.csv`.

# %%
# Load the cleaned generated prompts
generated_prompts_cleaned_df = pd.read_csv('generated_prompts_cleaned.csv', delimiter=';')

# %%
# Delete the column "Generated Prompt"
generated_prompts_cleaned_df = generated_prompts_cleaned_df.drop(columns=['Generated Prompt'])

# Rename the column "Generated Prompt Changed" to "TitlePrompt"
generated_prompts_cleaned_df = generated_prompts_cleaned_df.rename(columns={'Generated Prompt Changed': 'TitlePrompt'})

# Display the updated dataframe
print(generated_prompts_cleaned_df.head())
# Out:
#   Section Reference Meta-Analysis Info  \
# 0      No Reference            No Info
# 1      No Reference            No Info
# 2      No Reference            No Info
# 3      No Reference             For MA
# 4      No Reference             For MA
#
#                                          TitlePrompt
# 0  Your evaluation should reflect your considerab...
# 1  You are familiar with the concepts of sensitiv...
# 2  Select each one based on their titles. Please ...
# 3  This review should emphasize careful and delib...
# 4  Avoid including titles unless you are confiden...

# %% [markdown]
# We have revised the generated prompts and rewritten those that were syntactically or semantically nonsensical. However, since the choice of words is very restrictive based on the previous input, we now want to further expand the data using an LLM. For that we will create 10 prompts per combination of Section Reference and Meta-Analysis Information additionally.

# %%
import openai

# Set your OpenAI API key
openai.api_key = "OPENAI_API_KEY"

# Load the initial prompts cleaned dataframe
df = pd.read_csv('initial_prompts_cleaned.csv', delimiter=';')

# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Function to generate new prompts using OpenAI's API
def generate_prompts(section_ref, meta_info, existing_prompts):
    llm_prompt = f"""
    You are tasked with generating new prompts for the combination of Section Reference: '{section_ref}' and Meta-Analysis Info: '{meta_info}'. The existing prompts for this combination are as follows:

    {existing_prompts}

    Please generate 10 new prompts that maintain the aspect of Section Reference and Meta-Analysis Info but are varied in choice of language, words, and general sentence structure.
    """
    
    response = openai.ChatCompletion.create(
        model="gpt-4o-2024-08-06",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": llm_prompt}
        ],
        max_tokens=150,
        n=10,
        stop=None,
        temperature=0.7
    )
    
    new_prompts = [choice['message']['content'].strip() for choice in response.choices]
    return new_prompts

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
all_new_prompts = []
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_df = df[(df['Section Reference'] == section_ref) & (df['Meta-Analysis Info'] == meta_info)]
        
        # Extract existing prompts
        existing_prompts = filtered_df['TitlePrompt'].dropna().tolist()
        
        if existing_prompts:
            # Generate new prompts using OpenAI's API
            new_prompts = generate_prompts(section_ref, meta_info, existing_prompts)
            
            # Create a new dataframe for the new prompts
            new_prompts_df = pd.DataFrame({
                'Section Reference': [section_ref] * len(new_prompts),
                'Meta-Analysis Info': [meta_info] * len(new_prompts),
                'TitlePrompt': new_prompts
            })
            
            # Append the new prompts to the existing dataframe
            all_new_prompts.append(new_prompts_df)

# Concatenate all new prompts dataframes
if all_new_prompts:
    all_new_prompts_df = pd.concat(all_new_prompts, ignore_index=True)
    extended_prompts_df = pd.concat([generated_prompts_cleaned_df, all_new_prompts_df], ignore_index=True)
    
    # Save the extended dataframe to 'generated_prompts_llm.csv'
    extended_prompts_df.to_csv('generated_prompts_llm.csv', index=False, sep=';')
    
    # Display the new prompts
    print("Newly Generated Prompts by LLM:")
    for _, row in all_new_prompts_df.iterrows():
        print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['TitlePrompt']}")
else:
    print("No new prompts generated.")
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[30], line 50
#      46 existing_prompts = filtered_df['TitlePrompt'].dropna().tolist()
#      48 if existing_prompts:
#      49     # Generate new prompts using OpenAI's API
# ---> 50     new_prompts = generate_prompts(section_ref, meta_info, existing_prompts)
#      52     # Create a new dataframe for the new prompts
#      53     new_prompts_df = pd.DataFrame({
#      54         'Section Reference': [section_ref] * len(new_prompts),
#      55         'Meta-Analysis Info': [meta_info] * len(new_prompts),
#      56         'TitlePrompt': new_prompts
#      57     })
#
# Cell In[30], line 23, in generate_prompts(section_ref, meta_info, existing_prompts)
#      14 def generate_prompts(section_ref, meta_info, existing_prompts):
#      15     llm_prompt = f"""
#      16     You are tasked with generating new prompts for the combination of Section Reference: '{section_ref}' and Meta-Analysis Info: '{meta_info}'. The existing prompts for this combination are as follows:
#      17
#    (...)
#      20     Please generate 10 new prompts that maintain the aspect of Section Reference and Meta-Analysis Info but are varied in choice of language, words, and general sentence structure.
#      21     """
# ---> 23     response = openai.ChatCompletion.create(
#      24         model="gpt-4o-2024-08-06",
#      25         messages=[
#      26             {"role": "system", "content": "You are a helpful assistant."},
#      27             {"role": "user", "content": llm_prompt}
#      28         ],
#      29         max_tokens=150,
#      30         n=10,
#      31         stop=None,
#      32         temperature=0.7
#      33     )
#      35     new_prompts = [choice['message']['content'].strip() for choice in response.choices]
#      36     return new_prompts
#
# File ~/Library/CloudStorage/OneDrive-Persönlich/programme/coding/github/ensure/.venv/lib/python3.12/site-packages/openai/lib/_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
# # Extend the generated prompts dataframe by the original table structure
# extended_prompts = generated_prompts_cleaned_df.copy()
# extended_prompts['Model'] = 1
# extended_prompts['Words'] = extended_prompts['Generated Prompt'].apply(lambda x: len(x.split()))
# extended_prompts['screen_titles'] = 1
# extended_prompts['screen_abstracts'] = 0

# # Add empty columns for the rest of the structure
# columns_to_add = ['TitlePrompt', 'AbstractPrompt', 'sensitivity_titles', 'specificity_titles', 'PPV_titles', 'NPV_titles', 'tp_titles', 'tn_titles', 'fp_titles', 'fn_titles', 'sensitivity_abstracts', 'specificity_abstracts', 'PPV_abstracts', 'NPV_abstracts', 'tp_abstracts', 'tn_abstracts', 'fp_abstracts', 'fn_abstracts']
# for col in columns_to_add:
#     extended_prompts[col] = ''

# # Save the extended dataframe
# extended_prompts.to_csv('generated_prompts_cleaned.csv', index=False, sep=';')

# # Display the extended dataframe
# print(extended_prompts.head())

# %%
add plots for distribution of number of words and sentences before and after adding generated and cleaned prompts.
# Out:
#   Cell In[96], line 1
#     add plots for distribution of number of words and sentences before and after adding generated and cleaned prompts.
#         ^
# SyntaxError: invalid syntax

# %%
Then we want to extend the generated prompts df by the original table structure Model;Words;Section Reference;Meta-Analysis Info;screen_titles;screen_abstracts;TitlePrompt;AbstractPrompt;sensitivity_titles;specificity_titles;PPV_titles;NPV_titles;tp_titles;tn_titles;fp_titles;fn_titles;sensitivity_abstracts;specificity_abstracts;PPV_abstracts;NPV_abstracts;tp_abstracts;tn_abstracts;fp_abstracts;fn_abstracts
 in that, everything has to be empty except model, which should be 1, words, which should be the count of words in the prompt, screen titles should be 1 and screen abstract should be 0
# Out:
#   Cell In[62], line 1
#     Then we want to extend the generated prompts df by the original table structure Model;Words;Section Reference;Meta-Analysis Info;screen_titles;screen_abstracts;TitlePrompt;AbstractPrompt;sensitivity_titles;specificity_titles;PPV_titles;NPV_titles;tp_titles;tn_titles;fp_titles;fn_titles;sensitivity_abstracts;specificity_abstracts;PPV_abstracts;NPV_abstracts;tp_abstracts;tn_abstracts;fp_abstracts;fn_abstracts
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. ttl und ander ehinter title einfügen für jeweilige Kategorien in generated prrompts
# 2. eintragen von gpt in generated
# 3. kombinieren, ausfüllen von fertiger tabelle wie in initial prompts
