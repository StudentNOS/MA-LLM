# %% [markdown]
# # Generating Diverse Prompts for Section References and Meta-Analysis Info Combinations
#
# ## Overview
#
# This file aims to create a set of diverse and varied prompts for each combination of *Section Reference* and *Meta-Analysis Info* categories. The primary goal is to extend and enrich the initial set of prompts by varying their language structure by alternating the syntax and choice of words by alternating semantics, ensuring the outputs are sufficiently different while maintaining their original intent.
#
# By doing so, we aim to generate up to as many prompts to receive 50 unique prompts per combination, suitable for further use in classification, training, or testing scenarios. This variation enhances the linguistic richness and diversity of the dataset, ensuring broader applicability and adaptability.
#
# ## Methodology
#
# To achieve the goal, the following approach is taken:
# 1.	Input Dataset:
# - The dataset contains prompts categorized by *Section Reference* (e.g., “No Reference,” “Topic,” “Methods,” “Results”) and *Meta-Analysis Info* (e.g., “No Info,” “For MA,” “Title,” “Criteria”).
# - Each prompt is associated with a specific combination of these two dimensions.
# 2.	Prompt Expansion Using Markov Chains:
# - The markovify package is used to simulate new prompts by leveraging Markov chains.
# - All prompts belonging to a specific combination of categories are used as input to a Markov model, which generates new prompts based on observed patterns in the input data.
# - This allows for the creation of prompts that retain the style and structure of the originals while introducing variation.
# 3.	Ensuring Uniqueness and Quality:
# - The generated prompts are checked against the existing prompts to ensure no duplicates are added.
# - Prompts are also filtered for redundancy within the same generation cycle.
# - If a generated prompt doesn’t meet the criteria (e.g., it is too similar to the originals or doesn’t make sense), the model generates additional prompts to compensate.
# 4.	Final Validation:
#
# - Prompts are formatted uniformly to maintain a consistent presentation.
# - Outputs are reviewed, and necessary adjustments are made to improve clarity, variation, and alignment with the intended meaning. If needed, the cycle is run again go receive the missing prompts
#
# ## Why This Approach?
#
# Using Markov chains enables the generation of syntactically coherent variations based on existing data. This method ensures:
# - Efficiency: Quickly generates multiple variations without requiring manual input for each prompt.
# - Diversity: Captures different sentence structures and word choices while retaining the essence of the original prompts.
# - Scalability: Handles multiple combinations of categories, making it suitable for large datasets.
#
# By the end of this process, we will have a rich, diverse, and meaningful set of prompts that are ready for deployment in various applications.

# %%
import pandas as pd
import markovify

# %%
# Load the initial_prompts.csv into a dataframe
df = pd.read_csv('initial_prompts.csv', delimiter=';')

# Remove line breaks in the 'TitlePrompt' column
df['TitlePrompt'] = df['TitlePrompt'].str.replace('\n', ' ').str.replace('\r', ' ')

# Fill NaN values with empty strings in the 'TitlePrompt' column
df['TitlePrompt'].fillna('', inplace=True)

# Delete all rows below index 213
df = df.iloc[:213]

# Set 'screen_titles' to 1 and 'screen_abstracts' to 0
df['screen_titles'] = 1
df['screen_abstracts'] = 0

# Save the cleaned dataframe to prompts.csv
df.to_csv('prompts.csv', index=False, sep=';')

# Display the cleaned dataframe
print(df.head(25))
# Out:
#     Model  Words Section Reference Meta-Analysis Info  screen_titles  \
# 0       1      1      No Reference            No Info              1
# 1       1      8      No Reference            No Info              1
# 2       1      4      No Reference            No Info              1
# 3       1      6      No Reference            No Info              1
# 4       1     13      No Reference            No Info              1
# 5       1      6      No Reference            No Info              1
# 6       1     13      No Reference            No Info              1
# 7       1     10      No Reference            No Info              1
# 8       1     47      No Reference            No Info              1
# 9       1     42      No Reference            No Info              1
# 10      1     47      No Reference            No Info              1
# 11      1     56      No Reference            No Info              1
# 12      1     70      No Reference            No Info              1
# 13      1    136      No Reference            No Info              1
# 14      1    131      No Reference            No Info              1
# 15      1    278      No Reference            No Info              1
# 16      1    177      No Reference            No Info              1
# 17      1     10      No Reference             For MA              1
# 18      1     16      No Reference             For MA              1
# 19      1     10      No Reference             For MA              1
# 20      1     15      No Reference             For MA              1
# 21      1     78      No Reference             For MA              1
# 22      1     55      No Reference             For MA              1
# 23      1     53      No Reference             For MA              1
# 24      1    105      No Reference             For MA              1
#
#     screen_abstracts                                        TitlePrompt  \
# 0                  0
# 1                  0        Screen the titles below like a human would.
# 2                  0                           Screen the titles below.
# 3                  0         You are a world-class clinical researcher.
# 4                  0  Do not exclude any titles unless you are absol...
# 5                  0             Select the most relevant titles below.
# 6                  0  Of the titles below, aim to include relevant o...
# 7                  0  Go through the titles below carefully and sele...
# 8                  0  Consider the titles of the papers below. Selec...
# 9                  0  You are familiar with the concepts of sensitiv...
# 10                 0  You are a world-class scientist who has screen...
# 11                 0  You are a world-class researcher. You have rea...
# 12                 0  Carefully review the given list of scientific ...
# 13                 0  Conduct a thorough review of the provided list...
# 14                 0  Systematically review the provided list of sci...
# 15                 0  You are a world-class researcher with extensiv...
# 16                 0  Carefully evaluate the list of provided titles...
# 17                 0  Screen the titles below for their inclusion in...
# 18                 0  The titles below belong to papers that will be...
# 19                 0  Select the relevant titles below like a world-...
# 20                 0  Imagine you want to write a meta-analysis. Whi...
# 21                 0  The titles below will be screened for their in...
# 22                 0  A meta-analysis is a rigorous and systematic s...
# 23                 0  You are a researcher in a world-class scientif...
# 24                 0  You are a world-class researcher contributing ...
#
#                                        AbstractPrompt  sensitivity_titles  \
# 0                                                 NaN                 NaN
# 1      Screen the abstracts below like a human would.                 NaN
# 2                         Screen the abstracts below.                 NaN
# 3          You are a world-class clinical researcher.                 NaN
# 4   Do not exclude any abstracts unless you are ab...                 NaN
# 5           Select the most relevant abstracts below.                 NaN
# 6   Of the abstracts below, aim to include relevan...                 NaN
# 7   Go through the abstracts below carefully and s...                 NaN
# 8   Consider the abstracts of the papers below. Se...                 NaN
# 9   You are familiar with the concepts of sensitiv...                 NaN
# 10  You are a world-class scientist who has screen...                 NaN
# 11  You are a world-class researcher. You have rea...                 NaN
# 12  Carefully review the given list of scientific ...                 NaN
# 13  Conduct a thorough review of the provided list...                 NaN
# 14  Systematically review the provided list of sci...                 NaN
# 15  You are a world-class researcher with extensiv...                 NaN
# 16  Carefully evaluate the list of provided abstra...                 NaN
# 17  Screen the abstracts below for their inclusion...                 NaN
# 18  The abstracts below belong to papers that will...                 NaN
# 19  Select the relevant abstracts below like a wor...                 NaN
# 20  Imagine you want to write a meta-analysis. Whi...                 NaN
# 21  The abstracts below will be screened for their...                 NaN
# 22  A meta-analysis is a rigorous and systematic s...                 NaN
# 23  You are a researcher in a world-class scientif...                 NaN
# 24  You are a world-class researcher contributing ...                 NaN
#
#     specificity_titles  ...  fp_titles  fn_titles  sensitivity_abstracts  \
# 0                  NaN  ...        NaN        NaN                    NaN
# 1                  NaN  ...        NaN        NaN                    NaN
# 2                  NaN  ...        NaN        NaN                    NaN
# 3                  NaN  ...        NaN        NaN                    NaN
# 4                  NaN  ...        NaN        NaN                    NaN
# 5                  NaN  ...        NaN        NaN                    NaN
# 6                  NaN  ...        NaN        NaN                    NaN
# 7                  NaN  ...        NaN        NaN                    NaN
# 8                  NaN  ...        NaN        NaN                    NaN
# 9                  NaN  ...        NaN        NaN                    NaN
# 10                 NaN  ...        NaN        NaN                    NaN
# 11                 NaN  ...        NaN        NaN                    NaN
# 12                 NaN  ...        NaN        NaN                    NaN
# 13                 NaN  ...        NaN        NaN                    NaN
# 14                 NaN  ...        NaN        NaN                    NaN
# 15                 NaN  ...        NaN        NaN                    NaN
# 16                 NaN  ...        NaN        NaN                    NaN
# 17                 NaN  ...        NaN        NaN                    NaN
# 18                 NaN  ...        NaN        NaN                    NaN
# 19                 NaN  ...        NaN        NaN                    NaN
# 20                 NaN  ...        NaN        NaN                    NaN
# 21                 NaN  ...        NaN        NaN                    NaN
# 22                 NaN  ...        NaN        NaN                    NaN
# 23                 NaN  ...        NaN        NaN                    NaN
# 24                 NaN  ...        NaN        NaN                    NaN
#
#     specificity_abstracts  PPV_abstracts  NPV_abstracts  tp_abstracts  \
# 0                     NaN            NaN            NaN           NaN
# 1                     NaN            NaN            NaN           NaN
# 2                     NaN            NaN            NaN           NaN
# 3                     NaN            NaN            NaN           NaN
# 4                     NaN            NaN            NaN           NaN
# 5                     NaN            NaN            NaN           NaN
# 6                     NaN            NaN            NaN           NaN
# 7                     NaN            NaN            NaN           NaN
# 8                     NaN            NaN            NaN           NaN
# 9                     NaN            NaN            NaN           NaN
# 10                    NaN            NaN            NaN           NaN
# 11                    NaN            NaN            NaN           NaN
# 12                    NaN            NaN            NaN           NaN
# 13                    NaN            NaN            NaN           NaN
# 14                    NaN            NaN            NaN           NaN
# 15                    NaN            NaN            NaN           NaN
# 16                    NaN            NaN            NaN           NaN
# 17                    NaN            NaN            NaN           NaN
# 18                    NaN            NaN            NaN           NaN
# 19                    NaN            NaN            NaN           NaN
# 20                    NaN            NaN            NaN           NaN
# 21                    NaN            NaN            NaN           NaN
# 22                    NaN            NaN            NaN           NaN
# 23                    NaN            NaN            NaN           NaN
# 24                    NaN            NaN            NaN           NaN
#
#     tn_abstracts  fp_abstracts  fn_abstracts
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7            NaN           NaN           NaN
# 8            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 10           NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 13           NaN           NaN           NaN
# 14           NaN           NaN           NaN
# 15           NaN           NaN           NaN
# 16           NaN           NaN           NaN
# 17           NaN           NaN           NaN
# 18           NaN           NaN           NaN
# 19           NaN           NaN           NaN
# 20           NaN           NaN           NaN
# 21           NaN           NaN           NaN
# 22           NaN           NaN           NaN
# 23           NaN           NaN           NaN
# 24           NaN           NaN           NaN
#
# [25 rows x 24 columns]
# /var/folders/qg/82ll9gvd1pd4329hnkdpf8ch0000gn/T/ipykernel_51628/1711676016.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TitlePrompt'].fillna('', inplace=True)

# %%
# Define combinations of categories
section_refs = ["No Reference", "Topic", "Methods", "Results"]
meta_analysis_infos = ["No Info", "For MA", "Title", "Criteria"]

# Function to generate unique new prompts
def generate_unique_prompts(model, num_prompts, existing_prompts, max_words=50):
    generated_prompts = set(existing_prompts)  # Set to avoid duplicates
    new_prompts = []
    attempts = 0  # Safety loop to prevent infinite loops
    max_attempts = num_prompts * 10  # Max attempts per required prompt
    
    while len(new_prompts) < num_prompts and attempts < max_attempts:
        attempts += 1
        prompt = model.make_sentence(tries=100, max_words=max_words)
        if prompt and prompt not in generated_prompts:  # Check for duplicates
            generated_prompts.add(prompt)
            new_prompts.append(prompt.strip())  # Ensure uniform layout
    return new_prompts

# Save all new prompts
all_generated_prompts = []

# Iterate over all combinations of `Section Reference` and `Meta-Analysis Info`
for section_ref in section_refs:
    for meta_info in meta_analysis_infos:
        # Filter data for the current combination
        filtered_data = df[
            (df["Section Reference"] == section_ref) &
            (df["Meta-Analysis Info"] == meta_info)
        ]
        
        # Extract existing prompts
        existing_prompts = filtered_data["TitlePrompt"].dropna().tolist()
        num_existing_prompts = len(existing_prompts)
        
        # Calculate the number of new prompts
        num_new_prompts = max(0, 50 - num_existing_prompts)  # No negative values
        
        if num_new_prompts > 0 and existing_prompts:
            # Combined text for Markov model
            combined_text = "\n\n".join(existing_prompts)
            
            # Create Markov model
            markov_model = markovify.Text(
                combined_text,
                state_size=2,
                retain_original=False  # Prevents reconstruction of original texts
            )
            
            # Generate new unique prompts
            new_prompts = generate_unique_prompts(
                markov_model,
                num_prompts=num_new_prompts,
                existing_prompts=existing_prompts,
                max_words=50
            )
            
            # Save new prompts
            for prompt in new_prompts:
                all_generated_prompts.append({
                    "Section Reference": section_ref,
                    "Meta-Analysis Info": meta_info,
                    "Generated Prompt": prompt
                })

# Write results to a DataFrame
generated_prompts_df = pd.DataFrame(all_generated_prompts)

# Save results
generated_prompts_df.to_csv("generated_prompts.csv", index=False)

# Output the generated prompts
print("Generated Prompts:")
for _, row in generated_prompts_df.iterrows():
    print(f"Section: {row['Section Reference']}, Meta: {row['Meta-Analysis Info']}, Prompt: {row['Generated Prompt']}")
# Out:
# Generated Prompts:
# Section: No Reference, Meta: No Info, Prompt: Go through the titles below.
# Section: No Reference, Meta: No Info, Prompt: Systematically review the given list of provided titles with the overarching context of inquiry.
# Section: No Reference, Meta: No Info, Prompt: Carefully review the list of titles provided below.
# Section: No Reference, Meta: No Info, Prompt: This means that you select those titles that are not directly relevant or lack sufficient scope, depth, or foundational relevance to a comprehensive and balanced understanding of the subject area.
# Section: No Reference, Meta: No Info, Prompt: Focus on identifying studies that demonstrate potential relevance while excluding those that do not include any title unless you are absolutely certain it is relevant.
# Section: No Reference, Meta: No Info, Prompt: Aim to ensure that each paper is judged based solely on its capacity to enhance general insights or perspectives.
# Section: No Reference, Meta: No Info, Prompt: Exclude titles you deem relevant given your considerable expertise, ensuring that your selections align with the principles of scholarly rigor.
# Section: No Reference, Meta: No Info, Prompt: Exclude papers that align with the highest standards of scientific papers with the aim of evaluating their overall contribution to a broader synthesis or evaluation effort.
# Section: No Reference, Meta: No Info, Prompt: Avoid selecting papers that showcase thoroughness, consistency, and adherence to high-quality standards in their structure, clarity in their scholarly approach.
# Section: No Reference, Meta: No Info, Prompt: Drawing upon your expertise, carefully review the list of scientific communication.
# Section: No Reference, Meta: No Info, Prompt: Consider the titles below.
# Section: No Reference, Meta: No Info, Prompt: Systematically review the given list of scientific fields.
# Section: No Reference, Meta: No Info, Prompt: You are a world-class researcher with extensive experience in evaluating and analyzing scientific literature across a wide range of scientific fields.
# Section: No Reference, Meta: No Info, Prompt: Throughout this task, maintain a clear focus on the principles of rigorous and meaningful scholarly communication.
# Section: No Reference, Meta: No Info, Prompt: The review should prioritize thoughtful and deliberate inclusion, reserving exclusion for cases where relevance and contribution are decisively lacking.
# Section: No Reference, Meta: No Info, Prompt: Your evaluation should reflect your considerable expertise, ensuring that each paper is judged based solely on its and its potential to contribute to a wider discourse and whether it provides sufficient clarity and detail to be meaningfully integrated into a broader analytical framework.
# Section: No Reference, Meta: No Info, Prompt: Carefully review the provided list of scientific communication.
# Section: No Reference, Meta: No Info, Prompt: Similarly, refrain from including titles unless you are absolutely certain they are likely to provide meaningful insights or perspectives, excluding those that are irrelevant.
# Section: No Reference, Meta: No Info, Prompt: Please screen the list of scientific papers.
# Section: No Reference, Meta: No Info, Prompt: Your task is to assess each title with an open mind and a commitment to thorough and objective analysis.
# Section: No Reference, Meta: No Info, Prompt: Use your extensive scientific expertise to guide you in making informed and accurate decisions.
# Section: No Reference, Meta: No Info, Prompt: The review should prioritize thoughtful and deliberate inclusion, reserving exclusion for cases where relevance and potential to contribute to a comprehensive and balanced understanding of the field of inquiry.
# Section: No Reference, Meta: No Info, Prompt: You are familiar with the principles of rigorous and meaningful scholarly communication.
# Section: No Reference, Meta: No Info, Prompt: As you go through the titles below, aim to include relevant ones and exclude those that lack fundamental relevance, sufficient detail, or the depth required for further informed consideration.
# Section: No Reference, Meta: No Info, Prompt: Of the titles below and assess their scientific rigor.
# Section: No Reference, Meta: No Info, Prompt: Screen the titles below, screen them both sensitively and specifically.
# Section: No Reference, Meta: No Info, Prompt: Go through the titles below like a human would.
# Section: No Reference, Meta: No Info, Prompt: Be deliberate in your selection.
# Section: No Reference, Meta: No Info, Prompt: Focus on identifying works that contribute to a comprehensive and balanced understanding of the field it pertains to.
# Section: No Reference, Meta: No Info, Prompt: Screen the titles below, aim to include relevant ones and exclude those that lack fundamental relevance, sufficient detail, or the depth required for further informed consideration.
# Section: No Reference, Meta: No Info, Prompt: For each title, consider whether it is relevant.
# Section: No Reference, Meta: No Info, Prompt: Be careful in your selection.
# Section: No Reference, Meta: No Info, Prompt: The review should emphasize works that contribute to a comprehensive and balanced understanding of the field of inquiry.
# Section: No Reference, Meta: For MA, Prompt: As you review the titles of papers you find below and select them for a meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: You are tasked with assisting in the meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: Thus, you should aim to select those titles that align with the broader objectives of conducting a robust and meaningful meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: Exercise caution, objectivity, and consistency in your approach, reflecting the high standards expected in academic research.
# Section: No Reference, Meta: For MA, Prompt: By balancing sensitivity and specificity in signal-detection theory, your objective is to identify relevant titles below for their potential value.
# Section: No Reference, Meta: For MA, Prompt: Similarly, avoid including titles unless you are confident they hold potential value for the meta-analytical process.
# Section: No Reference, Meta: For MA, Prompt: Your role in achieving the objectives of conducting a rigorous and comprehensive meta-analysis, and your careful and deliberate decisions that reflect the high standards expected in high-quality scientific work, ensuring your selections should reflect thoughtful, deliberate decision-making, guided by your expertise in scholarly evaluation.
# Section: No Reference, Meta: For MA, Prompt: Carefully go through the titles below belong to papers that will be screened for their relevance.
# Section: No Reference, Meta: For MA, Prompt: You are tasked with assisting in the preparation of a rigorous and comprehensive meta-analysis, and your careful and deliberate decision-making to ensure that your work is being compared to the meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: You are tasked with screening scientific paper titles for inclusion and excluding those that a gold standard meta-analysis conducted manually by world-class experts.
# Section: No Reference, Meta: For MA, Prompt: Similarly, avoid including titles unless you are certain they lack the necessary attributes to support the goals of providing balanced and comprehensive meta-analysis, and your careful and deliberate decision-making to ensure that the final selection of papers supports a robust and meaningful insights into the broader research landscape.
# Section: No Reference, Meta: For MA, Prompt: Your goal is to identify titles that suggest alignment with the goals of a meta-analytical process.
# Section: No Reference, Meta: For MA, Prompt: Approach this task with precision and care necessary for high-quality meta-analytical work, ensuring that potentially valuable contributions are included.
# Section: No Reference, Meta: For MA, Prompt: Apply your expertise in rigorous academic evaluation to make decisions that align with the concepts of sensitivity and specificity in signal-detection theory.
# Section: No Reference, Meta: For MA, Prompt: You are tasked with screening scientific paper titles for inclusion and excluding irrelevant ones.
# Section: No Reference, Meta: For MA, Prompt: A meta-analysis is a rigorous and comprehensive meta-analysis, and your careful and thoughtful approach will play a pivotal role in achieving the objectives of a meta-analysis that conducted the screening process.
# Section: No Reference, Meta: For MA, Prompt: You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis that conducted the screening of scientific papers for inclusion in a meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: As you review the titles below belong to papers that will be screened for their relevance in the meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis conducted manually by world-class experts.
# Section: No Reference, Meta: For MA, Prompt: This process is pivotal, and your role is to carefully screen the titles of scientific papers for their relevance for inclusion.
# Section: No Reference, Meta: For MA, Prompt: By carefully judging each title, consider its relevance in the screening process.
# Section: No Reference, Meta: For MA, Prompt: You are a world-class researcher contributing to a meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: By carefully judging each title, consider its relevance and the principles of sound academic practice.
# Section: No Reference, Meta: For MA, Prompt: Avoid excluding titles unless you are certain they do not meet the general standards for inclusion, reflecting a high degree of sensitivity, ensuring that your screening process contributes to a meaningful synthesis of knowledge.
# Section: No Reference, Meta: For MA, Prompt: Exclude titles only if you are certain it lacks relevance or does not meet the general standards for inclusion, and include titles only if you are certain they do not meet the general criteria for inclusion in a world-class meta-analyst would.
# Section: No Reference, Meta: For MA, Prompt: As you screen each title, consider its relevance in the screening manually would have excluded.
# Section: No Reference, Meta: For MA, Prompt: Apply your expertise in rigorous academic evaluation to make thoughtful and deliberate decision-making to ensure that the meta-analysis accurately synthesizes and reflects the available evidence while maintaining the integrity and reliability expected of such an effort.
# Section: No Reference, Meta: For MA, Prompt: The titles below like a world-class researcher contributing to a comprehensive synthesis of knowledge.
# Section: No Reference, Meta: For MA, Prompt: As a researcher in a meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: Do not exclude any title unless you are certain they do not meet the general requirements for inclusion.
# Section: No Reference, Meta: For MA, Prompt: A meta-analysis is a rigorous and comprehensive representation of the papers themselves.
# Section: No Reference, Meta: For MA, Prompt: Prioritize titles that suggest alignment with the concepts of sensitivity and specificity in signal-detection theory.
# Section: No Reference, Meta: For MA, Prompt: Your role in this process is crucial for the meta-analytical process.
# Section: No Reference, Meta: For MA, Prompt: Conversely, exclude titles prematurely, as the sensitivity of your decisions in shaping the quality and comprehensiveness of the meta-analysis.
# Section: No Reference, Meta: For MA, Prompt: Your task is to apply these principles rigorously throughout the screening manually would have excluded.
# Section: No Reference, Meta: For MA, Prompt: This means that you select those papers as relevant that a gold standard would also have selected.
# Section: No Reference, Meta: For MA, Prompt: Carefully go through the titles below for their selection in a meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Rely on your understanding of scholarly standards and best practices.
# Section: No Reference, Meta: Title, Prompt: Your decisions should be included in this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to make thoughtful and accurate representation of the meta-analysis.Your expertise and judgment are central to this task.
# Section: No Reference, Meta: Title, Prompt: Your decisions should be guided by an objective and balanced synthesis.
# Section: No Reference, Meta: Title, Prompt: Aim to include relevant ones and exclude irrelevant ones.
# Section: No Reference, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance to the meta-analysis and exclude titles only if you are certain they do not meet its standards.
# Section: No Reference, Meta: Title, Prompt: Be cautious not to exclude titles only when it is clear they do not meet its standards.
# Section: No Reference, Meta: Title, Prompt: Include titles only when it is clear they do not meet the general standards for inclusion.
# Section: No Reference, Meta: Title, Prompt: Carefully evaluate each title to determine its relevance to this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Your role is to ensure that the most relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this gold standard, selecting titles that align with its goals.
# Section: No Reference, Meta: Title, Prompt: Exclude all those that are relevant to this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: This means that you select those titles that align with its goals.
# Section: No Reference, Meta: Title, Prompt: Your task is to carefully assess the provided titles of scientific papers to determine its relevance to this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Your task is to apply these principles rigorously throughout the screening process.
# Section: No Reference, Meta: Title, Prompt: Be cautious not to exclude titles only if you are confident in their relevance to this task.
# Section: No Reference, Meta: Title, Prompt: Each title should be guided by an objective and balanced synthesis.
# Section: No Reference, Meta: Title, Prompt: This means that you select those titles that are relevant and valuable titles are selected, your work will contribute significantly to the quality and impact of this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance in the meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Include all papers that are irrelevant.
# Section: No Reference, Meta: Title, Prompt: Your decisions should be guided by an objective and balanced approach, ensuring that the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment.
# Section: No Reference, Meta: Title, Prompt: You are familiar with the principles of rigorous scholarly communication.
# Section: No Reference, Meta: Title, Prompt: Include titles only when it is clear they do not align with its criteria for inclusion in this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Exclude all those that are irrelevant.
# Section: No Reference, Meta: Title, Prompt: As you screen the titles, focus on identifying those that reflect the thoughtful judgment and expertise expected of a world-class researcher.
# Section: No Reference, Meta: Title, Prompt: This means that you select those titles that are irrelevant.
# Section: No Reference, Meta: Title, Prompt: Exclude all those that would not meet its standards.
# Section: No Reference, Meta: Title, Prompt: Your decisions should be assessed objectively, based on its potential contribution to a balanced and meaningful synthesis of knowledge.
# Section: No Reference, Meta: Title, Prompt: Use your expertise to make thoughtful and accurate representation of the selection process captures studies of potential significance while avoiding irrelevant or tangential works.Be deliberate in your assessment.
# Section: No Reference, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity and comprehensiveness of the selection process captures studies of potential significance while avoiding irrelevant or tangential works.Be deliberate in your assessment.
# Section: No Reference, Meta: Title, Prompt: Conversely, exclude titles only when you are certain they lack the depth, scope, or relevance required to meet the general standards for inclusion.
# Section: No Reference, Meta: Title, Prompt: Carefully evaluate each title to determine their relevance for inclusion in this meta-analysis.
# Section: No Reference, Meta: Title, Prompt: Exclude all those that are relevant and valuable titles are selected, your work will contribute significantly to the meta-analysis and exclude irrelevant ones.
# Section: No Reference, Meta: Title, Prompt: Think about how each paper might support the comprehensive nature of the available evidence.
# Section: No Reference, Meta: Title, Prompt: As you screen the titles, focus on identifying those that would not meet the general standards for inclusion.
# Section: No Reference, Meta: Title, Prompt: Include titles only when you are certain they do not meet the general standards for inclusion.
# Section: No Reference, Meta: Title, Prompt: Aim to include relevant ones and exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant contributions.
# Section: No Reference, Meta: Criteria, Prompt: This requires a meticulous and thoughtful approach to ensure that the meta-analysis produces a meaningful and rigorous synthesis of knowledge.
# Section: No Reference, Meta: Criteria, Prompt: Consider the role of each title to determine whether it should be included or not.
# Section: No Reference, Meta: Criteria, Prompt: Carefully go through the titles of scientific papers for inclusion in this meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Approach each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Approach this task with diligence and a commitment to academic excellence.
# Section: No Reference, Meta: Criteria, Prompt: You are tasked with screening the titles of papers you find below and select them for a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Papers that do not meet the specified criteria, as this could compromise the overall quality of the meta-analysis, ensuring that potentially valuable contributions are not MSC transfusions, should be on accurately assessing the potential relevance of each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Include titles only when it is equally clear that they match the exclusion criteria.This process demands a balance between thoroughness and precision.
# Section: No Reference, Meta: Criteria, Prompt: Papers that do not.
# Section: No Reference, Meta: Criteria, Prompt: Carefully review each title based solely on how well it aligns with the criteria provided.The success of this meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: This requires a meticulous and thoughtful approach to ensure that the final selection of studies supports a robust synthesis of the importance of selection criteria will guide you in making decisions that reflect the thoughtful judgment and expertise expected of a world-class researcher.
# Section: No Reference, Meta: Criteria, Prompt: Carefully go through the titles of scientific papers for their inclusion in a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Exclude those that do not meet the inclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that potentially valuable contributions are not overlooked.
# Section: No Reference, Meta: Criteria, Prompt: You must carefully assess each paper to determine their relevance for inclusion in this meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Exclude all those that are relevant to this meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: You are tasked with screening the titles of scientific papers for their inclusion in a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: This requires a meticulous and thoughtful approach to ensure the meta-analysis produces a meaningful and comprehensive synthesis of knowledge.
# Section: No Reference, Meta: Criteria, Prompt: Your primary focus should be excluded.
# Section: No Reference, Meta: Criteria, Prompt: In your screening, focus on ensuring a balanced and thorough selection.
# Section: No Reference, Meta: Criteria, Prompt: Consider the role of each title to determine their relevance for inclusion in a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: You must carefully assess each paper to determine their relevance for inclusion in a meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Approach this task with a clear commitment to high academic standards.
# Section: No Reference, Meta: Criteria, Prompt: Include all papers that meet the inclusion and exclusion criteria.
# Section: No Reference, Meta: Criteria, Prompt: This requires a meticulous and thoughtful approach to ensure the meta-analysis is comprehensive and rigorous.
# Section: No Reference, Meta: Criteria, Prompt: Your expertise in evaluating academic work and your understanding of the meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: By adhering to the quality and impact of this meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Exclude those that are irrelevant.
# Section: No Reference, Meta: Criteria, Prompt: Carefully review each title in contributing to the broader objectives of the importance of selection criteria that have been carefully established to ensure the meta-analysis produces a meaningful and comprehensive synthesis of knowledge under the meta-analysis.
# Section: No Reference, Meta: Criteria, Prompt: Your expertise in evaluating academic work and your understanding of the meta-analysis, ensuring that your decisions are guided by specific selection criteria will guide you in making decisions that reflect the highest standards of scholarly rigor.
# Section: No Reference, Meta: Criteria, Prompt: Include titles only if you are confident they align with the objectives of the meta-analysis, ensuring that the final selection of studies supports a robust synthesis of knowledge.
# Section: No Reference, Meta: Criteria, Prompt: Your primary focus should be considered for inclusion.
# Section: No Reference, Meta: Criteria, Prompt: As you go through the titles below, screen them both sensitively and specifically.
# Section: No Reference, Meta: Criteria, Prompt: Include titles only when you are confident they clearly meet the specified criteria, as this could compromise the overall quality of the research landscape.
# Section: No Reference, Meta: Criteria, Prompt: Consider the role of each title to determine whether it should be on accurately assessing the potential relevance of each title to determine whether it should be excluded.
# Section: No Reference, Meta: Criteria, Prompt: You are part of a world-class researcher.
# Section: No Reference, Meta: Criteria, Prompt: This process is guided by objectivity and precision, avoiding any assumptions about specific methods, results, or content within the papers themselves.Your role is crucial in shaping the meta-analysis produces a meaningful and comprehensive synthesis of knowledge under the exclusion criteria.
# Section: No Reference, Meta: Criteria, Prompt: At the same time, avoid including titles that do not meet the inclusion and exclusion criteria and applying your expertise thoughtfully, you will play a critical role in ensuring that potentially valuable contributions are not MSC transfusions, should be excluded.
# Section: Topic, Meta: No Info, Prompt: You are a world-class researcher.
# Section: Topic, Meta: No Info, Prompt: Approach each title with an open mind and a commitment to thorough and objective analysis, evaluating the alignment of the available knowledge base, focusing on the contents and hypotheses and exclude titles with topics you deem relevant given your considerable expertise, and exclude those with relevant research questions and hypotheses.
# Section: Topic, Meta: No Info, Prompt: Select each one based on its capacity to enhance general insights, address meaningful research questions, explores relevant topics, and adheres to established scientific standards.
# Section: Topic, Meta: No Info, Prompt: Your task is to assess each title based on its research focus to be meaningfully integrated into a broader synthesis or evaluation effort.
# Section: Topic, Meta: No Info, Prompt: Use your extensive scientific expertise to distinguish between titles with topics you deem as irrelevant.
# Section: Topic, Meta: No Info, Prompt: Do not exclude any title unless you are absolutely certain their research focus, questions, and hypotheses, as well as its potential to contribute meaningfully to a balanced and inclusive representation of the work, instead concentrating on the research questions and hypotheses.
# Section: Topic, Meta: No Info, Prompt: Be deliberate in your field.
# Section: Topic, Meta: No Info, Prompt: Be deliberate in your selection based on whether its research focus.
# Section: Topic, Meta: No Info, Prompt: Avoid excluding any titles unless you are absolutely certain their research focus to be meaningfully integrated into a broader understanding of the provided list of titles provided below.
# Section: Topic, Meta: No Info, Prompt: Prioritize works that delve into significant research questions, hypotheses, and overall topic, focusing on the contents and hypotheses and exclude titles with topics you deem as irrelevant.
# Section: Topic, Meta: No Info, Prompt: Consider the titles below, screen them both sensitively and specifically, focusing on how they contribute to a general and balanced understanding of the papers.
# Section: Topic, Meta: No Info, Prompt: Use your extensive scientific expertise to guide you in making informed and accurate decisions.
# Section: Topic, Meta: No Info, Prompt: For each paper, carefully evaluate its overall relevance and academic contribution.
# Section: Topic, Meta: No Info, Prompt: You are a world-class scientist who has screened countless papers throughout their life.
# Section: Topic, Meta: No Info, Prompt: Be careful in your selection.
# Section: Topic, Meta: No Info, Prompt: In your evaluation, exercise caution and precision.
# Section: Topic, Meta: No Info, Prompt: Assess each one based on its research questions, consistency in addressing their hypotheses, and research focus and questions.
# Section: Topic, Meta: No Info, Prompt: Dismiss items that fail to meet these general criteria.
# Section: Topic, Meta: No Info, Prompt: Please screen the list of titles provided below.
# Section: Topic, Meta: No Info, Prompt: Avoid selecting papers that showcase thoroughness in their contents to the broader academic discourse.
# Section: Topic, Meta: No Info, Prompt: Screen the titles below based on their research questions and hypotheses.
# Section: Topic, Meta: No Info, Prompt: Consider whether the paper addresses meaningful research focus does not meet these general criteria.
# Section: Topic, Meta: No Info, Prompt: Approach each title with an open mind and a commitment to thorough and objective analysis, evaluating the alignment of its topic is relevant.
# Section: Topic, Meta: No Info, Prompt: Aim to ensure that each paper is judged based on the research questions, explores relevant topics, and adheres to established scientific standards.
# Section: Topic, Meta: No Info, Prompt: Screen the titles below for relevance, focusing on the questions, hypotheses, and the relevant papers in your process, ensuring that each decision is justified and carefully considered.
# Section: Topic, Meta: No Info, Prompt: Focus on identifying works that delve into significant research questions and hypotheses.
# Section: Topic, Meta: No Info, Prompt: In your evaluation, ensure that your evaluation process is thorough, fair, and sensitive to the broader discourse.
# Section: Topic, Meta: No Info, Prompt: Systematically go through the titles below based on its research focus and hypotheses, and overall topic, focusing on their research questions and focus lack relevance or utility in supporting further academic inquiry.
# Section: Topic, Meta: No Info, Prompt: Be deliberate in your selection.
# Section: Topic, Meta: No Info, Prompt: Conduct a thorough review of the field of inquiry, emphasizing the relevance of its research questions, or explore foundational topics, excluding those that lack sufficient scope, depth, or focus.
# Section: Topic, Meta: No Info, Prompt: Prioritize works that explore relevant and meaningful topics, demonstrates relevance to a broader synthesis or evaluation effort.
# Section: Topic, Meta: No Info, Prompt: Your task is to assess each title based on their research questions that align with goal of providing relevant information on the research questions and hypotheses are relevant or not.
# Section: Topic, Meta: No Info, Prompt: Avoid making assumptions about specific methods, results, or content of the subject.
# Section: Topic, Meta: No Info, Prompt: Your task is to assess each title based on their topic.
# Section: Topic, Meta: No Info, Prompt: Aim to ensure that each paper is judged based on the relevance of its research questions and hypotheses.
# Section: Topic, Meta: For MA, Prompt: Assess each title aligns with its criteria for inclusion in a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Carefully go through the titles of scientific papers to determine their relevance in the screening process.
# Section: Topic, Meta: For MA, Prompt: Your goal is to make decisions that align with the broader objectives of the meta-analysis.
# Section: Topic, Meta: For MA, Prompt: At the same level of care and expertise expected in high-quality scientific work, ensuring your selections reflect both the relevance of its topic and its potential contribution to a comprehensive synthesis of knowledge.
# Section: Topic, Meta: For MA, Prompt: You are part of a meta-analysis that accurately reflects the broader subject matter.
# Section: Topic, Meta: For MA, Prompt: To achieve this balance, imagine that your selections reflect thoughtful and accurate judgment.
# Section: Topic, Meta: For MA, Prompt: Imagine you want to write a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Exclude titles only if you are confident their research questions, hypotheses, and overall topic, to determine its potential contribution to a meta-analysis by contributing meaningful insights and advancing the understanding of the titles below, focus on their topics are not aligned with the general requirements for inclusion.
# Section: Topic, Meta: For MA, Prompt: You are tasked with screening scientific paper titles for their relevance to the screening decisions made by a state-of-the-art gold standard meta-analysis conducted manually by world-class experts.
# Section: Topic, Meta: For MA, Prompt: Your role in achieving the objectives of a meta-analysis, focusing on their research questions and hypotheses.
# Section: Topic, Meta: For MA, Prompt: Select the relevant titles below for their relevance to the meta-analysis.
# Section: Topic, Meta: For MA, Prompt: You are familiar with the same level of care and expertise expected in high-quality scientific work, ensuring your selections reflect both the relevance of the broader objectives of a meta-analysis, ensuring a balanced and comprehensive synthesis of knowledge.
# Section: Topic, Meta: For MA, Prompt: Focus on identifying works with meaningful and relevant topics that contribute to a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Select titles with topics likely to align with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Topic, Meta: For MA, Prompt: As a researcher in a meta-analysis, ensuring a balanced and comprehensive meta-analysis, and exclude those with irrelevant ones.
# Section: Topic, Meta: For MA, Prompt: Select the relevant titles below for their inclusion in a world-class scientific team that wants to write a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: The titles below belong to papers that will be screened for their relevance in terms of content.
# Section: Topic, Meta: For MA, Prompt: Exclude titles only if you are confident their research questions, hypotheses, and topics.
# Section: Topic, Meta: For MA, Prompt: This means that you select those titles with relevant topics for inclusion in a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Be cautious not to exclude titles only when you are certain its research focus and its potential contribution to a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: This process is pivotal, and your role is to carefully screen the titles below belong to papers that will be screened for their inclusion in a meta-analysis, with a focus on the research questions, hypotheses, and overall topics.
# Section: Topic, Meta: For MA, Prompt: You are tasked with assisting in the relevance of their research questions, hypotheses, and overall topics.
# Section: Topic, Meta: For MA, Prompt: Assess each title based on its research focus aligns with the overarching objectives of a meta-analysis, ensuring a balanced and comprehensive meta-analysis, and exclude those with irrelevant ones.
# Section: Topic, Meta: For MA, Prompt: Be cautious not to exclude titles only if you are certain their topics lack the necessary attributes to support the goals of a meta-analysis, ensuring a balanced and meaningful synthesis of evidence.
# Section: Topic, Meta: For MA, Prompt: As you go through the titles below, focus on the subject matter of the meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Your goal is to apply these principles rigorously throughout the screening manually would have excluded.
# Section: Topic, Meta: For MA, Prompt: This means that you select those titles with relevant topics for inclusion in a world-class scientific team that wants to write a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Similarly, avoid including titles unless you are certain their topics lack the necessary attributes to support the goals of covering cutting-edge research questions and hypotheses.
# Section: Topic, Meta: For MA, Prompt: This process is crucial, and your selections reflect thoughtful and accurate judgment.
# Section: Topic, Meta: For MA, Prompt: As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Topic, Meta: For MA, Prompt: Focus on identifying works with meaningful and relevant topics for inclusion in a meta-analysis.
# Section: Topic, Meta: For MA, Prompt: Exclude those that a gold standard meta-analysis that conducted the screening decisions made by a state-of-the-art gold standard meta-analysis would have excluded.
# Section: Topic, Meta: For MA, Prompt: Exclude titles only if you are confident their research questions, hypotheses, and overall topics.
# Section: Topic, Meta: For MA, Prompt: Your expertise in the field.
# Section: Topic, Meta: For MA, Prompt: Exclude those that a gold standard meta-analysis would have selected the same papers based on their research questions, hypotheses, and overall topics.
# Section: Topic, Meta: For MA, Prompt: By balancing sensitivity and specificity and focusing on their research questions and hypotheses.
# Section: Topic, Meta: For MA, Prompt: As you review the titles below belong to papers that will be screened for their selection in a meta-analysis, ensuring a balanced and comprehensive representation of the broader objectives of conducting a robust synthesis.
# Section: Topic, Meta: Title, Prompt: You are familiar with the scope and objectives of this meta-analysis.
# Section: Topic, Meta: Title, Prompt: As you screen the provided titles of papers below, selecting those with contents relevant to the meta-analysis and exclude those with irrelevant ones.
# Section: Topic, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity of the selection process by avoiding irrelevant titles.
# Section: Topic, Meta: Title, Prompt: Be cautious not to exclude titles prematurely, as the sensitivity of your screening is critical to capturing all potentially relevant research topics.
# Section: Topic, Meta: Title, Prompt: Include all papers with topics relevant to the quality and impact of this gold standard, selecting titles whose research questions, hypotheses, and overall topics.
# Section: Topic, Meta: Title, Prompt: Focus on the research questions, hypotheses, and overall topics.
# Section: Topic, Meta: Title, Prompt: Each title should be included in this meta-analysis.
# Section: Topic, Meta: Title, Prompt: Focus on the research questions, hypotheses, and overall topics of the available evidence.
# Section: Topic, Meta: Title, Prompt: Exclude those that are irrelevant.
# Section: Topic, Meta: Title, Prompt: You are a world-class scientist.
# Section: Topic, Meta: Title, Prompt: Your expertise and judgment are central to this meta-analysis and excluding those that reflect relevant insight into the current state of relevant hypotheses, research questions, hypotheses, and topics in the field.
# Section: Topic, Meta: Title, Prompt: As you go through the titles of scientific papers, focusing on its research focus and its potential to cover the current field.
# Section: Topic, Meta: Title, Prompt: By ensuring that your decisions are being compared to a balanced and meaningful synthesis of current contents and exclude those with irrelevant ones.
# Section: Topic, Meta: Title, Prompt: Your expertise in evaluating academic rigor, combined with your understanding of scholarly standards, research focus, questions, and hypotheses of each title, carefully evaluate its relevance based on its research questions, hypotheses, and overall topics.
# Section: Topic, Meta: Title, Prompt: Rely on your understanding of sensitivity and specificity, should guide you in making decisions that align with the highest standards of scholarly practice.
# Section: Topic, Meta: Title, Prompt: Your expertise in evaluating academic rigor, combined with your understanding of sensitivity and specificity in signal-detection theory.
# Section: Topic, Meta: Title, Prompt: Carefully go through the titles of scientific papers to determine whether it aligns with the concepts of sensitivity and specificity, should guide you in making decisions that align with the highest standards of scholarly practice.
# Section: Topic, Meta: Title, Prompt: Aim to make choices that reflect relevant insight into the current contents, relevant hypotheses and research questions of the meta-analysis, helping to build a robust meta-analysis.
# Section: Topic, Meta: Title, Prompt: Your task is to apply these principles rigorously throughout the screening process.
# Section: Topic, Meta: Title, Prompt: This means that you select those titles with relevant contents and topics align with its criteria for inclusion, reflecting a high degree of specificity.
# Section: Topic, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity of the meta-analysis.
# Section: Topic, Meta: Title, Prompt: Adopt a meticulous and balanced approach.
# Section: Topic, Meta: Title, Prompt: Focus on the research questions, hypotheses, and overall topic to determine if they reflect relevant insight into the current state of relevant hypotheses, research questions, hypotheses, and overall topics of each paper by focusing on its research focus meets the general requirements for inclusion, reflecting a high degree of specificity.
# Section: Topic, Meta: Title, Prompt: Exclude titles only when you are confident their research questions, hypotheses, and overall topic to determine if they reflect relevant current research questions, hypotheses, and overall topics.
# Section: Topic, Meta: Title, Prompt: This means that you select those titles with relevant contents and topics align with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Topic, Meta: Title, Prompt: This means that you select those titles with relevant topics while avoiding irrelevant or tangential works.
# Section: Topic, Meta: Title, Prompt: Your primary objective is to carefully assess the provided titles of scientific papers to determine whether it aligns with the highest standards of scholarly standards, research focus, questions, and hypotheses of each title, carefully evaluate its relevance based on its research questions, hypotheses, and contents in the field.
# Section: Topic, Meta: Title, Prompt: Include all papers with topics relevant to the quality and impact of this meta-analysis.
# Section: Topic, Meta: Title, Prompt: Consider how the research questions, hypotheses, and topics in the field.
# Section: Topic, Meta: Title, Prompt: Your decisions should be included in this meta-analysis.
# Section: Topic, Meta: Title, Prompt: Your expertise in evaluating academic rigor, combined with your understanding of scholarly standards, research focus, questions, and topics in the field.
# Section: Topic, Meta: Title, Prompt: Your role is to carefully screen the titles, focus on identifying those that this gold standard for meta-analysis screening.
# Section: Topic, Meta: Title, Prompt: Similarly, avoid including titles unless you are confident their research questions, and hypotheses of each paper might support the comprehensive nature of the meta-analysis, helping to build a robust and well-rounded representation of the papers.
# Section: Topic, Meta: Title, Prompt: Carefully go through the titles below, screen them both sensitively and specifically, focusing on their research focus meets the general requirements for inclusion, and excluding those that this gold standard, selecting titles whose research questions, hypotheses, and topics in the field.
# Section: Topic, Meta: Title, Prompt: Exclude those that reflect relevant insight into the current field.
# Section: Topic, Meta: Title, Prompt: By approaching this task with meticulous attention to detail, fairness, and consistency, you will help lay the foundation for a high-quality meta-analysis.
# Section: Topic, Meta: Title, Prompt: Adopt a meticulous and balanced approach, ensuring that no potentially valuable study with relevant topics while avoiding irrelevant or tangential works.
# Section: Topic, Meta: Criteria, Prompt: Consider the role of each title’s research focus, contents, and topics you find below.
# Section: Topic, Meta: Criteria, Prompt: Approach this task with diligence, carefully evaluating the relevance of each paper to determine their representation of the papers themselves.
# Section: Topic, Meta: Criteria, Prompt: In your screening, focus on ensuring a balanced and thorough selection based on their research topics, are selected.
# Section: Topic, Meta: Criteria, Prompt: Exclude titles only if you are confident their topics match the exclusion criteria.
# Section: Topic, Meta: Criteria, Prompt: Your task is to identify papers with topics that meet the inclusion criteria should be on accurately assessing the potential relevance of each title based solely on how the research questions, hypotheses, and overall topics.
# Section: Topic, Meta: Criteria, Prompt: You are tasked with screening the titles below, screen them both sensitively and specifically, focusing on their research focus and contents.
# Section: Topic, Meta: Criteria, Prompt: Focus on the research questions, hypotheses, and overall topics of the papers themselves.
# Section: Topic, Meta: Criteria, Prompt: Your expertise in evaluating academic work and your understanding of the papers, in particular.
# Section: Topic, Meta: Criteria, Prompt: What are cutting-edge hypotheses?
# Section: Topic, Meta: Criteria, Prompt: Focus on the topics below.
# Section: Topic, Meta: Criteria, Prompt: You are familiar with the specified criteria.
# Section: Topic, Meta: Criteria, Prompt: Be rigoros in your evaluation, balancing careful inclusion and exclusion criteria.
# Section: Topic, Meta: Criteria, Prompt: Approach each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: Include titles only if you are certain their research questions, hypotheses, and overall topics of the research questions, hypotheses, and overall topics of each title based solely on how the research landscape.
# Section: Topic, Meta: Criteria, Prompt: Approach this task with a clear commitment to high academic standards.
# Section: Topic, Meta: Criteria, Prompt: This process demands a balance between thoroughness and precision.
# Section: Topic, Meta: Criteria, Prompt: As you go through the titles below, screen them both sensitively and specifically, focusing on its research questions, hypotheses, and overall topics of each title to ensure the meta-analysis reflects relevant current topics and research questions.
# Section: Topic, Meta: Criteria, Prompt: The success of this meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: Include titles only if they definitively match the exclusion criteria.
# Section: Topic, Meta: Criteria, Prompt: By ensuring that the meta-analysis produces a meaningful and comprehensive synthesis of knowledge.
# Section: Topic, Meta: Criteria, Prompt: Exclude titles only if you are confident their research focus aligns with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Topic, Meta: Criteria, Prompt: Include titles only if you are confident their topics match the exclusion criteria.
# Section: Topic, Meta: Criteria, Prompt: Include titles only if they clearly meet the specified criteria.
# Section: Topic, Meta: Criteria, Prompt: Focus on contents and cutting-edge hypotheses.
# Section: Topic, Meta: Criteria, Prompt: Carefully go through the titles of scientific papers to determine their relevance by focusing on the research questions, hypotheses, and overall topics to determine their relevance in reflecting current relevant topics and research questions.
# Section: Topic, Meta: Criteria, Prompt: Your careful evaluation of the meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: Titles that meet the specified criteria, as this could compromise the overall quality of the current relevant topics and research questions.
# Section: Topic, Meta: Criteria, Prompt: Focus on the research questions, hypotheses, and overall topics.
# Section: Topic, Meta: Criteria, Prompt: Your task is to carefully screen the provided titles of papers below, selecting those with contents that align with its purpose.
# Section: Topic, Meta: Criteria, Prompt: You are tasked with screening the titles of papers below, selecting those with contents that align with the inclusion and exclusion criteria.
# Section: Topic, Meta: Criteria, Prompt: By ensuring that only the most relevant and valuable research contributions, cutting-edge contents, and topics you find below.
# Section: Topic, Meta: Criteria, Prompt: Include titles only if you are confident their research questions, hypotheses, and overall topics addressed by each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis.
# Section: Topic, Meta: Criteria, Prompt: You are familiar with the exclusion criteria.
# ...
# Section: Results, Meta: For MA, Prompt: Your expertise in the current results of the meta-analysis.
# Section: Results, Meta: For MA, Prompt: As a researcher familiar with the same level of care and expertise expected in academic research.
# Section: Results, Meta: For MA, Prompt: Your role in this process is crucial, and your selections should reflect thoughtful, deliberate decision-making, guided by your expertise in evaluating academic rigor, combined with your understanding of sensitivity and specificity in signal-detection theory, your objective is to apply these principles rigorously throughout the screening manually would have excluded.
# Section: Results, Meta: For MA, Prompt: Avoid excluding titles unless you are certain their results are included.
# Section: Results, Meta: For MA, Prompt: This review should emphasize careful and thoughtful approach will play a pivotal role in this screening process contributes to a meaningful synthesis of research studies, aiming to combine and analyze their findings to draw broader conclusions about a particular field or outcome.
# Section: Results, Meta: For MA, Prompt: Apply your expertise in the meta-analysis.
# Section: Results, Meta: For MA, Prompt: Your goal is to apply these principles rigorously throughout the screening decisions made by a state-of-the-art gold standard would also have deemed significant.
# Section: Results, Meta: For MA, Prompt: The titles below for their relevance in the screening process. focus on the research outcomes, findings, and results of the papers themselves.
# Section: Results, Meta: For MA, Prompt: You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis conducted manually by world-class experts.
# Section: Results, Meta: Title, Prompt: You are familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully assess the provided titles of scientific papers to determine whether it aligns with the scope and objectives of this meta-analysis.
# Section: Results, Meta: Title, Prompt: Your decisions should be included in this meta-analysis.
# Section: Results, Meta: Title, Prompt: Aim to make choices that reflect relevant conclusions and results in the field.
# Section: Results, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance by focusing on their research discovery and its potential contribution to a benchmark gold standard for meta-analysis screening.
# Section: Results, Meta: Title, Prompt: Use your expertise on the most relevant conclusions and results in the field.
# Section: Results, Meta: Title, Prompt: Similarly, avoid including titles unless you are confident their research outcomes, findings, and result to determine if they reflect relevant conclusions and results align with its criteria for inclusion, and excluding those that do not meet its standards.
# Section: Results, Meta: Title, Prompt: Each title should be assessed objectively, based on its research outcomes, and findings of each paper might support the comprehensive nature of the current field.
# Section: Results, Meta: Title, Prompt: As you go through the titles below, screen them both sensitively and specifically, focusing on their research outcomes, and results of each title, ensuring that the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment.
# Section: Results, Meta: Title, Prompt: This means that you select those titles with relevant conclusions and results in the field.
# Section: Results, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity and comprehensiveness of the field, ensuring that the selection process by avoiding irrelevant or tangential works.Be deliberate in your assessment.
# Section: Results, Meta: Title, Prompt: Exclude titles only when you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion.
# Section: Results, Meta: Title, Prompt: This means that you select those titles with relevant results while avoiding irrelevant titles.Imagine that your selections reflect the thoughtful judgment and expertise expected of a world-class researcher.
# Section: Results, Meta: Title, Prompt: Exclude those that are irrelevant.
# Section: Results, Meta: Title, Prompt: Similarly, avoid including titles unless you are certain their conclusions lack the depth, scope, or relevance required to meet the broad criteria for inclusion, and excluding those that reflect the thoughtful judgment and expertise expected of a world-class researcher.
# Section: Results, Meta: Title, Prompt: This is a critical step in ensuring that no potentially valuable contributions are included with a high degree of specificity.
# Section: Results, Meta: Title, Prompt: This process demands precision, as each decision will directly impact the integrity of the field, ensuring that the most relevant conclusions of the meta-analysis.Your expertise and judgment are central to this meta-analysis and exclude those with conclusions relevant to this meta-analysis and exclude all those that are irrelevant.
# Section: Results, Meta: Title, Prompt: Consider whether the title suggests a work that addresses meaningful research outcomes, findings, and results align with its criteria for inclusion.
# Section: Results, Meta: Title, Prompt: Carefully go through the titles of scientific papers to determine if they reflect relevant conclusions and exclude all those that are irrelevant.
# Section: Results, Meta: Title, Prompt: Each title should be included in this meta-analysis.
# Section: Results, Meta: Title, Prompt: Consider how the research outcomes, and findings of each title, ensuring that potentially valuable contributions are included with a high degree of sensitivity.
# Section: Results, Meta: Title, Prompt: As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Results, Meta: Title, Prompt: Carefully assess each paper might support the comprehensive nature of the meta-analysis, helping to build a robust and well-rounded representation of the field, ensuring that the most relevant conclusions and results align with its criteria for inclusion.
# Section: Results, Meta: Title, Prompt: This involves balancing inclusivity with precision: ensuring that your selections reflect the high standards required for a high-quality meta-analysis.
# Section: Results, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance by focusing on its research discovery meets the general requirements for inclusion, reflecting a high degree of specificity.
# Section: Results, Meta: Title, Prompt: Consider how the research discovery, and best practices.
# Section: Results, Meta: Title, Prompt: As a researcher familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to make decisions that would mirror those of this meta-analysis.
# Section: Results, Meta: Title, Prompt: This involves balancing inclusivity with precision: ensuring that your selections reflect the thoughtful judgment and expertise expected of a world-class scientist.
# Section: Results, Meta: Title, Prompt: By ensuring that the most relevant conclusions and results in the field.
# Section: Results, Meta: Title, Prompt: Each title should be guided by an objective and balanced approach, ensuring that the meta-analysis accurately provides a cutting-edge synthesis of current conclusions and results align with its criteria for inclusion.
# Section: Results, Meta: Title, Prompt: Consider whether the title suggests a work that addresses meaningful research outcomes, findings, and results.
# Section: Results, Meta: Title, Prompt: Include all papers with results relevant to this task.
# Section: Results, Meta: Title, Prompt: This involves balancing inclusivity with precision: ensuring that the most relevant conclusions of the field, ensuring that your selections reflect the high standards required for a high-quality meta-analysis.
# Section: Results, Meta: Title, Prompt: Each title should be assessed objectively, based on its research discovery meets the general requirements for inclusion, and excluding those that reflect relevant conclusions and exclude those with conclusions relevant to this meta-analysis and exclude those with irrelevant ones.
# Section: Results, Meta: Title, Prompt: You are tasked with screening potential papers for their relevance by focusing on their research outcomes, findings, and results of the meta-analysis.Your expertise and judgment are central to this task.
# Section: Results, Meta: Title, Prompt: You are familiar with the concepts of sensitivity and specificity in signal-detection theory, your objective is to carefully assess the provided titles of papers below, selecting those with irrelevant ones.
# Section: Results, Meta: Title, Prompt: Use your expertise on the research discovery, outcomes, and findings of each paper by focusing on their research discovery meets the general requirements for inclusion, reflecting a high degree of sensitivity.
# Section: Results, Meta: Title, Prompt: As you go through the titles of scientific papers to determine if they reflect relevant conclusions and exclude all those that do not meet its standards.
# Section: Results, Meta: Criteria, Prompt: By adhering to the quality and impact of this meta-analysis.
# Section: Results, Meta: Criteria, Prompt: This process is guided by specific selection criteria that have been carefully established to ensure covering the relevant outcomes, findings, research discoveries, and conclusions of the papers, in particular.
# Section: Results, Meta: Criteria, Prompt: Approach this task with a clear commitment to high academic standards.
# Section: Results, Meta: Criteria, Prompt: You are tasked with screening the titles below, screen them both sensitively and specifically, focusing on the research discovery meets the inclusion criteria and exclude those that align with the concepts of sensitivity and specificity in signal-detection theory.
# Section: Results, Meta: Criteria, Prompt: Thus, you should aim to select those titles whose results are selected, your work will contribute significantly to the meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Your task is to carefully screen the provided titles of scientific papers for inclusion in a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Your careful evaluation, based on the outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: Ensure your decisions are guided by your knowledge of the field.The success of this meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Your task is to carefully screen the provided titles of scientific papers for their inclusion in a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Be cautious not to exclude titles only if you are confident their results clearly meet the inclusion criteria, and exclude those that fall under the exclusion criteria.This process demands a balance between thoroughness and precision.
# Section: Results, Meta: Criteria, Prompt: This means that you select those papers as relevant when a state-of-the-art gold standard meta-analysis that conducted the screening process with care and precision.
# Section: Results, Meta: Criteria, Prompt: You are part of a research team conducting a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Carefully go through the titles of scientific papers for inclusion in a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: By ensuring that only the most relevant and exclude titles prematurely, ensuring that the meta-analysis produces a meaningful and rigorous synthesis of knowledge.
# Section: Results, Meta: Criteria, Prompt: Ensure your decisions are guided by your knowledge of the research discovery of each title.
# Section: Results, Meta: Criteria, Prompt: What are the outcomes that are irrelevant.
# Section: Results, Meta: Criteria, Prompt: Include titles only when you are confident their research discovery of the papers, in particular.
# Section: Results, Meta: Criteria, Prompt: Be rigoros in your evaluation, balancing careful inclusion and exclusion criteria and contributes to the meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Carefully evaluate each title objectively and thoughtfully, maintaining the high standards expected in preparing a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: What are cutting-edge findings?
# Section: Results, Meta: Criteria, Prompt: Be rigoros in your evaluation, balancing careful inclusion and exclusion.
# Section: Results, Meta: Criteria, Prompt: Titles that meet the inclusion criteria and focusing on how the research discovery of the papers, in particular.
# Section: Results, Meta: Criteria, Prompt: Your task is to carefully screen the provided titles of scientific papers to determine its relevance to this meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Include titles only when you are certain their research results, are selected.
# Section: Results, Meta: Criteria, Prompt: By ensuring that the most relevant and appropriate studies, based on the results below.
# Section: Results, Meta: Criteria, Prompt: Be cautious not to exclude titles prematurely, ensuring that only the most relevant and exclude titles only when you are certain their research results, are selected.
# Section: Results, Meta: Criteria, Prompt: Carefully review each title to determine their relevance by focusing on how the research discovery of each title’s research discovery, outcomes, and findings of each title.
# Section: Results, Meta: Criteria, Prompt: Your task is to identify papers with results that meet the inclusion criteria, and exclude titles only when you are certain their research discovery does not contribute to its purpose.
# Section: Results, Meta: Criteria, Prompt: You have properly marked titles as relevant when a state-of-the-art gold standard meta-analysis would have excluded. focus on ensuring a balanced and thorough selection based on the research outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: Your careful evaluation, based on the outcomes, findings, and results of the titles, will form the foundation for the meta-analysis, enabling it to serve as a meaningful and rigorous synthesis of knowledge.
# Section: Results, Meta: Criteria, Prompt: Be cautious not to exclude titles only if you are confident their research outcomes, findings, and results.
# Section: Results, Meta: Criteria, Prompt: Exclude titles only if they clearly meet the inclusion criteria and exclude titles only if you are certain their research results, are selected.
# Section: Results, Meta: Criteria, Prompt: The success of this meta-analysis depends on a meticulous selection process that ensures all relevant studies are considered.Aim to make choices that reflect the thoughtful judgment and expertise expected of a research team conducting a meta-analysis.
# Section: Results, Meta: Criteria, Prompt: Include titles only when you are confident their results do not meet the general standards for inclusion.
# Section: Results, Meta: Criteria, Prompt: By ensuring that only the most relevant and valuable results are relevant and valuable research contributions, cutting-edge conclusions, and relevant findings.
# Section: Results, Meta: Criteria, Prompt: You are tasked with screening the titles of scientific papers for their relevance in reflecting current relevant results and research outcomes.
# Section: Results, Meta: Criteria, Prompt: Titles that meet the inclusion criteria and excluding those that fall under the exclusion criteria. focus on the results below.
# Section: Results, Meta: Criteria, Prompt: Approach this task systematically, focusing on how the research landscape.
# Section: Results, Meta: Criteria, Prompt: Approach this task systematically, focusing on the outcomes, findings, and results.
